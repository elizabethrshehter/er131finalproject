# %% [markdown]
# # ER131 Final Project (replace this with your project title)
# Fall 2019
#
# In this cell, give an alphabetical (by last name) list of student group members.  Beside each student's name, provide a description of each student's contribution to the project.

# %% [markdown]
# ## Basic Project Requirements (delete this markdown cell in your final submission)
#
# **How to use this notebook**:  This notebook is the template for your semester project.  Each markdown cell provides instructions on what to do in order to complete a successful project.  The cell you're reading right now is the only one you can delete from what you eventually hand in.  For the other cells:
# 1. You may replace the instructions in each cell with your own work but do not edit the cell titles (with the exception of the project title, above).
# 2. Follow the instructions in each section carefully.  For some sections you will enter only markdown text in the existing cells. For other sections, you'll accompany the markdown cells with additional code cells, and perhaps more markdown, before moving on to the next section.
#
# **Grading**.  You'll see point allocations listed in each of the section titles below.  In addition, there are other categories for points:
# 1. Visualization (10 points).  Plots should be well organized, legible, labelled, and well-suited for the question they are being used to answer or explore.
# 2. Clarity (5 points). Note that clarity also supports points elsewhere, because if we can't understand what you're explaining, we'll assume you didn't understand what you were doing and give points accordingly!
#
# For each Section or Category, we will give points according to the following percentage scale:
# 1. More than 90%:  work that is free of anything but superficial mistakes, and demonstrates creativity and / or a very deep understanding of what you are doing.
# 2. 80-90%: work without fundamental errors and demonstrates a basic understanding of what you're doing.
# 3. 60-80%: work with fundamental flaws in the analysis and / or conveys that you do not understand the basics of the work you are trying to do.
# 4. Below 60%: Work that is severely lacking or incomplete.
#
# Note that we distinguish *mistakes* from *"my idea didn't work"*.  Sometimes you don't know if you can actually do the thing you're trying to do and as you dig in you find that you can't.  That doesn't necessarily mean you made a mistake; it might just mean you needed more information.  We'll still give high marks to ambitious projects that "fail" at their stated objective, as long as that objective was clear and you demonstrate an understanding of what you were doing and why it didn't work.
#
# **Working in groups:**  We have the following requirements:
# 1. Projects must have at least one distinct quantitative question per student in the group.  Questions can and should be related, but they need to require distinct work efforts, and the interpretation and analysis should cover each question in detail.  If you have any doubt about whether your questions are distinct, consult with the instructors.
# 2. We use a sliding data requirements scale, see below.
#
# **Data requirements**:  Projects must use data from a minimum of $1+N_s$ different sources, where $N_s$ is the number of students in the group.  You should merge at least two data sets. </font>
#
# **Advice on Project Topics**:  We want you to do a project that relates to energy and environment topics.
#
# **Selecting a Project**: You have the choice of working on a project for a client or formulating your own project. Client project descriptions can be found in the "project" folder on Github.
#
# **Suggested data sets**: If you choose not to work on a client projets, here are some ideas for data starting points. You can definitely bring your own data to the table!
# 1. [Purple Air](https://www.purpleair.com) Instructions on how to download PurpleAir data are [here](https://docs.google.com/document/d/15ijz94dXJ-YAZLi9iZ_RaBwrZ4KtYeCy08goGBwnbCU/edit).
# 2. California Enviroscreen database.  Available [here].(https://oehha.ca.gov/calenviroscreen/report/calenviroscreen-30)
# 3. Several data sets available from the UC Irvine machine learning library:
#     1. [Forest Fires](https://archive.ics.uci.edu/ml/datasets/Forest+Fires)
#     4. [Climate](https://archive.ics.uci.edu/ml/datasets/Greenhouse+Gas+Observing+Network)
#     5. [Ozone](https://archive.ics.uci.edu/ml/datasets/Ozone+Level+Detection)
# 4. California Solar Initiative data (installed rooftop solar systems).  Available [here](https://www.californiasolarstatistics.ca.gov/data_downloads/).
# 5. World Bank Open Data, available [here](https://data.worldbank.org).
# 6. California ISO monitored emissions data, [here](http://www.caiso.com/TodaysOutlook/Pages/Emissions.aspx).
# 7. Energy Information Administration Residential Energy Consumption Survey, [here] (https://www.eia.gov/consumption/residential/data/2015/)
#
# **Dates**:
# You have the following due dates:
# 1. Thursday, October 3 (as part of homework 4): by this date you'll be expected to have formed groups of 2-3, identified your data sources, and defined a forecasting question. Feel free to use the lab time period in previous weeks to talk to potential group members, and to post on Piazza if you're looking for additional group members. The deliverable will be a question on homework 4 where you provide your group member names, data sources, and forecasting question.
# 1. Tuesday, December 17 (instead of final exam): This is when poster presentations will happen. Your deliverable is one printed poster for your group outlining the background behind your project, the questions explored, your data sources and choice of model, and results and discussion. A more detailed outline of the poster requirements will be posted later in the semester on Github.
# 1. Wednesday, December 18: Your Jupyter notebook and data should be submitted to bCourses (one submission per group).
#
# Throughout the semester, some of the homework assignments will include short questions designed to help you explore your project's data and analysis approach.
#
# Ok, now on to the project!

# %% [markdown]
# ## Abstract (5 points)
# Although this section comes first, you'll write it last.  It should be a ~250 word summary of your project.  1/3rd of the abstract should provide background, 1/3rd should explain what you did, and 1/3rd should explain what you learned.

# %% [markdown]
# ## Project Background (5 points)
# In this section you will describe relevant background for your project.  It should give enough information that a non-expert can understand in detail the history and / or context of the system or setting you wish to study, the need for quantitative analysis, and, broadly, what impact a quantitative analyses could have on the system.  Shoot for 500 words here.

# %% [markdown]
# ## Project Objective (5 points)
# In this section you will pose the central objective or objectives for your semester project.  Objectives should be extremely clear, well-defined and clearly cast as forecasting problems.
#
# Some example questions:
# 1. *"The purpose of this project is to train and evaluate different models to predict soil heavy metal contamination levels across the state of Louisiana, using a variety of features drawn from EPA, the US Census, and NAICS databases."* or
# 2. *"The purpose of this project is to train and evaluate different models to predict 1-minute generation from a UCSD solar PV site, up to 2 hours into the future, using historical data as well as basic weather forecast variables.*" or
# 3. *"The purpose of this project is to forecast daily emergency room visits for cardiac problems in 4 major US cities, using a majority of features including air quality forecasts, weather forecasts and seasonal variables."*
#
# You should reflect here on why it's important to answer these questions.  In most cases this will mean that you'll frame the answers to your questions as informing one or more *resource allocation* problems.  If you have done a good job of providing project background (in the cell above) then this reflection will be short and easy to write.
#
# **Comment on novelty:** You may find it hard to identify a project question that has *never* been answered before.  It's ok if you take inspiration from existing analyses.  However you shouldn't exactly reproduce someone else's analysis.  If you take inspiration from another analyses, you should still use different models, different data, and so on.

# %% [markdown]
# 1. Does a specific residential unit have air conditioning based on different features known about the unit?
#
# 2. How much AC electricity consumption is a residential unit likely to use based on different features known about the unit?
#
# 3. Out of the features in the model, are any of the demographic features more significant or less significant in predicting ownership of AC units in residential homes?

# %% [markdown]
# ## Input Data Description (5 points)
# Here you will provide an initial description of your data sets, including:
# 1. The origins of your data.  Where did you get the data?  How were the data collected from the original sources?
# 2. The structure, granularity, scope, temporality and faithfulness (SGSTF) of your data.  To discuss these attributes you should load the data into one or more data frames (so you'll start building code cells for the first time).  At a minimum, use some basic methods (`.head`, `.loc`, and so on) to provide support for the descriptions you provide for SGSTF.
#
# [Chapter 5](https://www.textbook.ds100.org/ch/05/eda_intro.html) of the DS100 textbook might be helpful for you in this section.

# %% [markdown]
# ## Data Cleaning (10 points)
# In this section you will walk through the data cleaning and merging process.  Explain how you make decisions to clean and merge the data.  Explain how you convince yourself that the data don't contain problems that will limit your ability to produce a meaningful analysis from them.
#
# [Chapter 4](https://www.textbook.ds100.org/ch/04/cleaning_intro.html) of the DS100 textbook might be helpful to you in this section.

# %%
import math
import numpy as np
import matplotlib
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd

import urllib
import os.path
from shutil import copyfile

# %%
# Install packages
# !pip install xlrd
# !pip install graphviz
# Out:
# Collecting xlrd
#   Using cached https://files.pythonhosted.org/packages/b0/16/63576a1a001752e34bf8ea62e367997530dc553b689356b9879339cf45a4/xlrd-1.2.0-py2.py3-none-any.whl
# Installing collected packages: xlrd
# Successfully installed xlrd-1.2.0
# You are using pip version 9.0.3, however version 19.3.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# Collecting graphviz
#   Using cached https://files.pythonhosted.org/packages/f5/74/dbed754c0abd63768d3a7a7b472da35b08ac442cf87d73d5850a6f32391e/graphviz-0.13.2-py2.py3-none-any.whl
# Installing collected packages: graphviz
# Successfully installed graphviz-0.13.2
# You are using pip version 9.0.3, however version 19.3.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %% [markdown]
# Paycool tells us whether or not they have air conditioning
#
# 1. 1 and 2 mean YES
# 2. 3 means NO
# 3. 97 means missing
#
# We can use this as our response variable for the first classification question

# %% [markdown]
# ![PAYCOOL](PAYCOOL_info.png 'PAYCOOL_info.png')

# %%
#read in data and select columns
surv_data = pd.read_csv('data/Survdata.csv')
surv_AC = surv_data[["DWLTYPE",
"OWNRENT",
"BUILTYR",
"SEASOCC",
"SQFT",
"EXTWLINS",
"ACEILINS",
"NGUTIL",
"PAYCOOL",
"CLCNTAGE",
"avginc",
"CTEVZON",
"CLCTLTYP",
"CMRNSET",
"CDAYSET",
"CEVNSET",
"CNITESET",
"NOROOMAC",
"ACTYP1",
"ACAGE1",
"CCADD",
"CCFUEL",
"EDUC",
"ETHNIC",
"HOHIND1",
"HOHASN1",
"HOHBLK1",
"HOHLAT1",
"HOHWHT1",
"HOHOTH1",
"INCOME",
"CZT24",
"caccnt",
"RACCNT",
"rescnt",
"HOHETH",
"cecfast",
"new_cac_uec"]]

# %%
#issue that there are a 100 more nans than originally were missing from their data

#drop rows with 97
survey_clean = surv_AC[surv_AC['PAYCOOL'] != 97]

#number of datapoints using for response variable
num_data = sum(survey_clean['PAYCOOL'] != 97)
           
#ask about this warning
survey_clean['PAYCOOL'] = np.where(survey_clean['PAYCOOL'] == 2, 1, survey_clean['PAYCOOL'])
survey_clean.head()

#drop all rows with NA values in feature columns
survey_clean = survey_clean.dropna()
# Out:
# /srv/app/venv/lib/python3.6/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # Remove the CWD from sys.path while we load stuff.

# %%
#load the column dictionary file: key for all the column names, what they mean 

coldict = pd.read_csv('data/coldict.csv')
coldict_clean = coldict[['Column Name', 'Notes']]
coldict_clean
# Out:
#     Column Name                                              Notes
# 0       DWLTYPE                                    type of housing
# 1       OWNRENT                           whether they own or rent
# 2       BUILTYR                               year residence built
# 3       SEASOCC                 permanent or partial year resident
# 4          SQFT                             square footage of home
# 5      EXTWLINS                 exterior (outside) walls insulated
# 6      ACEILINS                            attic/ceiling insulated
# 7          NUMI                                    how many people
# 8        NGUTIL                                           utility
# 9       PAYCOOL  pay for central air conditioning/cooling for y...
# 10      COOLING  type and how many central air conditioning/coo...
# 11          NaN                                           CTLACAGE
# 12          NaN                                           CTEVPAGE
# 13          NaN                                              HPAGE
# 14     CLCNTAGE                   age of central air conditioning
# 15       avginc                          average continuous income
# 16      CTEVZON  Primary Central Air Conditioning System is con...
# 17     CLCTLTYP               Thermostat type for main central air
# 18      CMRNSET                  AC thermostat setting in morning
# 19      CDAYSET                      AC thermostat setting in day
# 20      CEVNSET                   AC thermostat setting in evening
# 21     CNITESET                    AC thermostat setting in night
# 22     NOROOMAC                            No room air conditioner
# 23       ACTYP1                       Type room air conditioner 1
# 24       ACAGE1                      Age of room air conditioner 1
# 25        CCADD                             Added central cooling
# 26       CCFUEL                     Fuel for added central cooling
# 27         EDUC                     Education of head of household
# 28       ETHNIC                                   Primary language
# 29      HOHIND1             Head of household 1 is American Indian
# 30      HOHASN1                             Asian/Pacific Islander
# 31      HOHBLK1                                   African American
# 32      HOHLAT1                                    Hispanic/Latino
# 33      HOHWHT1                                          Caucasian
# 34      HOHOTH1                                              Other
# 35       INCOME                             household total income
# 36        CZT24                             title 24 climate zones
# 37       caccnt           Total number of central air conditioners
# 38       RACCNT              Total number of room air conditioners
# 39       rescnt                                total num residents
# 40       HOHETH                        Head of household ethnicity
# 41      cecfast                        Forecast climate zone (CEC)
# 42  new_cac_uec              Central Air Conditioning Electric UEC
# 43      cdd1-12  Cooling Degree-Days Using Reference Temp Month...
# 44     AcAn_kWh  Pre-normalized 12-month Average Usage – kHz – ...

# %% [markdown]
# ## Data Summary and Exploratory Data Analysis (10 points)
#
# In this section you should provide a tour through some of the basic trends and patterns in your data.  This includes providing initial plots to summarize the data, such as box plots, histograms, trends over time, scatter plots relating one variable or another.
#
# [Chapter 6](https://www.textbook.ds100.org/ch/06/viz_intro.html) of the DS100 textbook might be helpful for providing ideas for visualizations that describe your data.

# %%
x = survey_clean.groupby('INCOME').count().drop(97).index
height = survey_clean.groupby('INCOME').count().drop(97)['PAYCOOL']
plt.bar(x,height,align = 'center')
plt.xlabel('Income Bracket (Low to High)')
plt.ylabel('Number With AC Installed ')
plt.title('Relationship between Income and AC Installation')
# Out:
# Text(0.5, 1.0, 'Relationship between Income and AC Installation')

# %%
x = survey_clean.groupby('EDUC').count().drop(97).index
height = survey_clean.groupby('EDUC').count().drop(97)['PAYCOOL']
plt.bar(x,height,align = 'center')
plt.xlabel('Education level (Low to High)')
plt.ylabel('Number With AC Installed ')
plt.title('Relationship between Education and AC Installation')
# Out:
# Text(0.5, 1.0, 'Relationship between Education and AC Installation')

# %% [markdown]
# ## Forecasting and Prediction Modeling (25 points)
#
# This section is where the rubber meets the road.  In it you must:
# 1. Explore at least 3 prediction modeling approaches, ranging from the simple (e.g. linear regression, KNN) to the complex (e.g. SVM, random forests, Lasso).
# 2. Motivate all your modeling decisions.  This includes parameter choices (e.g., how many folds in k-fold cross validation, what time window you use for averaging your data) as well as model form (e.g., If you use regression trees, why?  If you include nonlinear features in a regression model, why?).
# 1. Carefully describe your cross validation and model selection process.  You should partition your data into training, testing and *validation* sets.
# 3. Evaluate your models' performance in terms of testing and validation error.  Do you see evidence of bias?  Where do you see evidence of variance?
# 4. Very carefully document your workflow.  We will be reading a lot of projects, so we need you to explain each basic step in your analysis.
# 5. Seek opportunities to write functions allow you to avoid doing things over and over, and that make your code more succinct and readable.

# %%
#PAYCOOL is our response column 
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import cross_val_score, train_test_split
from sklearn import tree

features = survey_clean.drop(columns = ['PAYCOOL','new_cac_uec','ACTYP1','CLCNTAGE','caccnt','RACCNT',
'CTEVZON',
'CLCTLTYP',
'CMRNSET',
'CDAYSET',
'CEVNSET',
'CNITESET',
'NOROOMAC',
'ACAGE1',
'CCADD',
'CCFUEL'])
target = survey_clean['PAYCOOL']

# split test set
X, X_test, y, y_test = train_test_split(features, target, random_state = 1, test_size = .2)

# split between train and validation sets
X_train, X_val, y_train, y_val = train_test_split(X, y, random_state = 1, test_size = 0.25)

#Build Decision Tree
first_tree = DecisionTreeClassifier()
first_tree.fit(X_train, y_train)

print("Number of features: {}".format(first_tree.tree_.n_features))
print("Number of nodes (internal and terminal): {}".format(first_tree.tree_.node_count), "\n")

train_score = first_tree.score(X_train, y_train)
val_score = first_tree.score(X_val, y_val)

print('Train Score: ', train_score)
print('Validation Score: ', val_score)
# Out:
# Number of features: 22
# Number of nodes (internal and terminal): 237
#
# Train Score:  1.0
# Validation Score:  0.9838920330866348

# %% [markdown]
# To view decision tree: [Webgraphviz](http://webgraphviz.com)

# %%
import graphviz
print(tree.export_graphviz(first_tree, feature_names=X.columns))
# Out:
# digraph Tree {
# node [shape=box] ;
# 0 [label="INCOME <= 7.5\ngini = 0.013\nsamples = 6888\nvalue = [6842, 46]"] ;
# 1 [label="CZT24 <= 6.5\ngini = 0.029\nsamples = 2329\nvalue = [2295, 34]"] ;
# 0 -> 1 [labeldistance=2.5, labelangle=45, headlabel="True"] ;
# 2 [label="NGUTIL <= 98.0\ngini = 0.104\nsamples = 237\nvalue = [224, 13]"] ;
# 1 -> 2 ;
# 3 [label="BUILTYR <= 54.5\ngini = 0.038\nsamples = 154\nvalue = [151, 3]"] ;
# 2 -> 3 ;
# 4 [label="DWLTYPE <= 51.5\ngini = 0.027\nsamples = 147\nvalue = [145, 2]"] ;
# 3 -> 4 ;
# 5 [label="avginc <= 10000.0\ngini = 0.014\nsamples = 140\nvalue = [139, 1]"] ;
# 4 -> 5 ;
# 6 [label="BUILTYR <= 6.5\ngini = 0.165\nsamples = 11\nvalue = [10, 1]"] ;
# 5 -> 6 ;
# 7 [label="ACEILINS <= 1.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]"] ;
# 6 -> 7 ;
# 8 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"] ;
# 7 -> 8 ;
# 9 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"] ;
# 7 -> 9 ;
# 10 [label="gini = 0.0\nsamples = 9\nvalue = [9, 0]"] ;
# 6 -> 10 ;
# 11 [label="gini = 0.0\nsamples = 129\nvalue = [129, 0]"] ;
# 5 -> 11 ;
# 12 [label="rescnt <= 1.5\ngini = 0.245\nsamples = 7\nvalue = [6, 1]"] ;
# 4 -> 12 ;
# 13 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"] ;
# 12 -> 13 ;
# 14 [label="gini = 0.0\nsamples = 6\nvalue = [6, 0]"] ;
# 12 -> 14 ;
# 15 [label="SQFT <= 50.5\ngini = 0.245\nsamples = 7\nvalue = [6, 1]"] ;
# 3 -> 15 ;
# 16 [label="HOHETH <= 3.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]"] ;
# 15 -> 16 ;
# 17 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"] ;
# 16 -> 17 ;
# 18 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"] ;
# 16 -> 18 ;
# 19 [label="gini = 0.0\nsamples = 5\nvalue = [5, 0]"] ;
# 15 -> 19 ;
# 20 [label="BUILTYR <= 4.5\ngini = 0.212\nsamples = 83\nvalue = [73, 10]"] ;
# 2 -> 20 ;
# 21 [label="EXTWLINS <= 50.0\ngini = 0.361\nsamples = 38\nvalue = [29, 9]"] ;
# 20 -> 21 ;
# 22 [label="EDUC <= 5.5\ngini = 0.264\nsamples = 32\nvalue = [27, 5]"] ;
# 21 -> 22 ;
# 23 [label="OWNRENT <= 1.5\ngini = 0.074\nsamples = 26\nvalue = [25, 1]"] ;
# 22 -> 23 ;
# 24 [label="gini = 0.0\nsamples = 19\nvalue = [19, 0]"] ;
# 23 -> 24 ;
# 25 [label="rescnt <= 1.5\ngini = 0.245\nsamples = 7\nvalue = [6, 1]"] ;
# 23 -> 25 ;
# 26 [label="cecfast <= 4.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]"] ;
# 25 -> 26 ;
# 27 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"] ;
# 26 -> 27 ;
# 28 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"] ;
# 26 -> 28 ;
# 29 [label="gini = 0.0\nsamples = 5\nvalue = [5, 0]"] ;
# 25 -> 29 ;
# 30 [label="ACEILINS <= 1.5\ngini = 0.444\nsamples = 6\nvalue = [2, 4]"] ;
# 22 -> 30 ;
# 31 [label="gini = 0.0\nsamples = 4\nvalue = [0, 4]"] ;
# 30 -> 31 ;
# 32 [label="gini = 0.0\nsamples = 2\nvalue = [2, 0]"] ;
# 30 -> 32 ;
# 33 [label="INCOME <= 3.5\ngini = 0.444\nsamples = 6\nvalue = [2, 4]"] ;
# 21 -> 33 ;
# 34 [label="gini = 0.0\nsamples = 3\nvalue = [0, 3]"] ;
# 33 -> 34 ;
# 35 [label="EDUC <= 4.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]"] ;
# 33 -> 35 ;
# 36 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"] ;
# 35 -> 36 ;
# 37 [label="gini = 0.0\nsamples = 2\nvalue = [2, 0]"] ;
# 35 -> 37 ;
# 38 [label="EDUC <= 5.5\ngini = 0.043\nsamples = 45\nvalue = [44, 1]"] ;
# 20 -> 38 ;
# 39 [label="gini = 0.0\nsamples = 38\nvalue = [38, 0]"] ;
# 38 -> 39 ;
# 40 [label="EXTWLINS <= 1.5\ngini = 0.245\nsamples = 7\nvalue = [6, 1]"] ;
# 38 -> 40 ;
# 41 [label="cecfast <= 9.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]"] ;
# 40 -> 41 ;
# 42 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"] ;
# 41 -> 42 ;
# 43 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"] ;
# 41 -> 43 ;
# 44 [label="gini = 0.0\nsamples = 5\nvalue = [5, 0]"] ;
# 40 -> 44 ;
# 45 [label="HOHWHT1 <= 0.5\ngini = 0.02\nsamples = 2092\nvalue = [2071, 21]"] ;
# 1 -> 45 ;
# 46 [label="ACEILINS <= 1.5\ngini = 0.043\nsamples = 775\nvalue = [758, 17]"] ;
# 45 -> 46 ;
# 47 [label="rescnt <= 60.5\ngini = 0.014\nsamples = 424\nvalue = [421, 3]"] ;
# 46 -> 47 ;
# 48 [label="EDUC <= 1.5\ngini = 0.01\nsamples = 418\nvalue = [416, 2]"] ;
# 47 -> 48 ;
# 49 [label="CZT24 <= 8.5\ngini = 0.121\nsamples = 31\nvalue = [29, 2]"] ;
# 48 -> 49 ;
# 50 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"] ;
# 49 -> 50 ;
# 51 [label="NGUTIL <= 98.0\ngini = 0.064\nsamples = 30\nvalue = [29, 1]"] ;
# 49 -> 51 ;
# 52 [label="gini = 0.0\nsamples = 27\nvalue = [27, 0]"] ;
# 51 -> 52 ;
# 53 [label="DWLTYPE <= 3.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]"] ;
# 51 -> 53 ;
# 54 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"] ;
# 53 -> 54 ;
# 55 [label="gini = 0.0\nsamples = 2\nvalue = [2, 0]"] ;
# 53 -> 55 ;
# 56 [label="gini = 0.0\nsamples = 387\nvalue = [387, 0]"] ;
# 48 -> 56 ;
# 57 [label="BUILTYR <= 54.5\ngini = 0.278\nsamples = 6\nvalue = [5, 1]"] ;
# 47 -> 57 ;
# 58 [label="gini = 0.0\nsamples = 5\nvalue = [5, 0]"] ;
# 57 -> 58 ;
# 59 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"] ;
# 57 -> 59 ;
# 60 [label="EXTWLINS <= 2.5\ngini = 0.077\nsamples = 351\nvalue = [337, 14]"] ;
# 46 -> 60 ;
# 61 [label="BUILTYR <= 1.5\ngini = 0.037\nsamples = 161\nvalue = [158, 3]"] ;
# 60 -> 61 ;
# 62 [label="HOHETH <= 3.5\ngini = 0.245\nsamples = 7\nvalue = [6, 1]"] ;
# 61 -> 62 ;
# 63 [label="gini = 0.0\nsamples = 5\nvalue = [5, 0]"] ;
# 62 -> 63 ;
# 64 [label="EDUC <= 4.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]"] ;
# 62 -> 64 ;
# 65 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"] ;
# 64 -> 65 ;
# 66 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"] ;
# 64 -> 66 ;
# 67 [label="INCOME <= 3.5\ngini = 0.026\nsamples = 154\nvalue = [152, 2]"] ;
# 61 -> 67 ;
# 68 [label="gini = 0.0\nsamples = 84\nvalue = [84, 0]"] ;
# 67 -> 68 ;
# 69 [label="DWLTYPE <= 2.5\ngini = 0.056\nsamples = 70\nvalue = [68, 2]"] ;
# 67 -> 69 ;
# 70 [label="gini = 0.0\nsamples = 40\nvalue = [40, 0]"] ;
# 69 -> 70 ;
# 71 [label="SQFT <= 52.5\ngini = 0.124\nsamples = 30\nvalue = [28, 2]"] ;
# 69 -> 71 ;
# 72 [label="cecfast <= 3.5\ngini = 0.071\nsamples = 27\nvalue = [26, 1]"] ;
# 71 -> 72 ;
# 73 [label="rescnt <= 2.5\ngini = 0.375\nsamples = 4\nvalue = [3, 1]"] ;
# 72 -> 73 ;
# 74 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"] ;
# 73 -> 74 ;
# 75 [label="gini = 0.0\nsamples = 3\nvalue = [3, 0]"] ;
# 73 -> 75 ;
# 76 [label="gini = 0.0\nsamples = 23\nvalue = [23, 0]"] ;
# 72 -> 76 ;
# 77 [label="cecfast <= 10.0\ngini = 0.444\nsamples = 3\nvalue = [2, 1]"] ;
# 71 -> 77 ;
# 78 [label="gini = 0.0\nsamples = 2\nvalue = [2, 0]"] ;
# 77 -> 78 ;
# 79 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"] ;
# 77 -> 79 ;
# 80 [label="cecfast <= 2.5\ngini = 0.109\nsamples = 190\nvalue = [179, 11]"] ;
# 60 -> 80 ;
# 81 [label="HOHETH <= 2.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]"] ;
# 80 -> 81 ;
# 82 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"] ;
# 81 -> 82 ;
# 83 [label="gini = 0.0\nsamples = 2\nvalue = [2, 0]"] ;
# 81 -> 83 ;
# 84 [label="DWLTYPE <= 2.5\ngini = 0.101\nsamples = 187\nvalue = [177, 10]"] ;
# 80 -> 84 ;
# 85 [label="SQFT <= 5.5\ngini = 0.16\nsamples = 80\nvalue = [73, 7]"] ;
# 84 -> 85 ;
# 86 [label="cecfast <= 11.5\ngini = 0.34\nsamples = 23\nvalue = [18, 5]"] ;
# 85 -> 86 ;
# 87 [label="avginc <= 41250.0\ngini = 0.255\nsamples = 20\nvalue = [17, 3]"] ;
# 86 -> 87 ;
# 88 [label="NGUTIL <= 3.5\ngini = 0.188\nsamples = 19\nvalue = [17, 2]"] ;
# 87 -> 88 ;
# 89 [label="gini = 0.0\nsamples = 13\nvalue = [13, 0]"] ;
# 88 -> 89 ;
# 90 [label="CZT24 <= 8.5\ngini = 0.444\nsamples = 6\nvalue = [4, 2]"] ;
# 88 -> 90 ;
# 91 [label="HOHETH <= 5.0\ngini = 0.444\nsamples = 3\nvalue = [1, 2]"] ;
# 90 -> 91 ;
# 92 [label="gini = 0.0\nsamples = 2\nvalue = [0, 2]"] ;
# 91 -> 92 ;
# 93 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"] ;
# 91 -> 93 ;
# 94 [label="gini = 0.0\nsamples = 3\nvalue = [3, 0]"] ;
# 90 -> 94 ;
# 95 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"] ;
# 87 -> 95 ;
# 96 [label="cecfast <= 12.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]"] ;
# 86 -> 96 ;
# 97 [label="gini = 0.0\nsamples = 2\nvalue = [0, 2]"] ;
# 96 -> 97 ;
# 98 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"] ;
# 96 -> 98 ;
# 99 [label="NGUTIL <= 98.0\ngini = 0.068\nsamples = 57\nvalue = [55, 2]"] ;
# 85 -> 99 ;
# 100 [label="rescnt <= 8.5\ngini = 0.036\nsamples = 55\nvalue = [54, 1]"] ;
# 99 -> 100 ;
# 101 [label="gini = 0.0\nsamples = 48\nvalue = [48, 0]"] ;
# 100 -> 101 ;
# 102 [label="rescnt <= 11.0\ngini = 0.245\nsamples = 7\nvalue = [6, 1]"] ;
# 100 -> 102 ;
# 103 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"] ;
# 102 -> 103 ;
# 104 [label="gini = 0.0\nsamples = 6\nvalue = [6, 0]"] ;
# 102 -> 104 ;
# 105 [label="cecfast <= 9.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]"] ;
# 99 -> 105 ;
# 106 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"] ;
# 105 -> 106 ;
# 107 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"] ;
# 105 -> 107 ;
# 108 [label="DWLTYPE <= 4.5\ngini = 0.055\nsamples = 107\nvalue = [104, 3]"] ;
# 84 -> 108 ;
# 109 [label="EDUC <= 2.5\ngini = 0.022\nsamples = 88\nvalue = [87, 1]"] ;
# 108 -> 109 ;
# 110 [label="BUILTYR <= 54.5\ngini = 0.1\nsamples = 19\nvalue = [18, 1]"] ;
# 109 -> 110 ;
# 111 [label="gini = 0.0\nsamples = 13\nvalue = [13, 0]"] ;
# 110 -> 111 ;
# 112 [label="HOHLAT1 <= 0.5\ngini = 0.278\nsamples = 6\nvalue = [5, 1]"] ;
# 110 -> 112 ;
# 113 [label="gini = 0.0\nsamples = 4\nvalue = [4, 0]"] ;
# 112 -> 113 ;
# 114 [label="avginc <= 21250.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]"] ;
# 112 -> 114 ;
# 115 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"] ;
# 114 -> 115 ;
# 116 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"] ;
# 114 -> 116 ;
# 117 [label="gini = 0.0\nsamples = 69\nvalue = [69, 0]"] ;
# 109 -> 117 ;
# 118 [label="SQFT <= 4.5\ngini = 0.188\nsamples = 19\nvalue = [17, 2]"] ;
# 108 -> 118 ;
# 119 [label="BUILTYR <= 3.5\ngini = 0.444\nsamples = 6\nvalue = [4, 2]"] ;
# 118 -> 119 ;
# 120 [label="gini = 0.0\nsamples = 3\nvalue = [3, 0]"] ;
# 119 -> 120 ;
# 121 [label="ETHNIC <= 3.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]"] ;
# 119 -> 121 ;
# 122 [label="gini = 0.0\nsamples = 2\nvalue = [0, 2]"] ;
# 121 -> 122 ;
# 123 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"] ;
# 121 -> 123 ;
# 124 [label="gini = 0.0\nsamples = 13\nvalue = [13, 0]"] ;
# 118 -> 124 ;
# 125 [label="CZT24 <= 7.5\ngini = 0.006\nsamples = 1317\nvalue = [1313, 4]"] ;
# 45 -> 125 ;
# 126 [label="rescnt <= 53.0\ngini = 0.049\nsamples = 79\nvalue = [77, 2]"] ;
# 125 -> 126 ;
# 127 [label="SQFT <= 8.5\ngini = 0.025\nsamples = 78\nvalue = [77, 1]"] ;
# 126 -> 127 ;
# 128 [label="gini = 0.0\nsamples = 71\nvalue = [71, 0]"] ;
# 127 -> 128 ;
# 129 [label="EDUC <= 5.5\ngini = 0.245\nsamples = 7\nvalue = [6, 1]"] ;
# 127 -> 129 ;
# 130 [label="gini = 0.0\nsamples = 6\nvalue = [6, 0]"] ;
# 129 -> 130 ;
# 131 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"] ;
# 129 -> 131 ;
# 132 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"] ;
# 126 -> 132 ;
# 133 [label="avginc <= 10000.0\ngini = 0.003\nsamples = 1238\nvalue = [1236, 2]"] ;
# 125 -> 133 ;
# 134 [label="NGUTIL <= 1.5\ngini = 0.023\nsamples = 87\nvalue = [86, 1]"] ;
# 133 -> 134 ;
# 135 [label="cecfast <= 3.5\ngini = 0.117\nsamples = 16\nvalue = [15, 1]"] ;
# 134 -> 135 ;
# 136 [label="gini = 0.0\nsamples = 13\nvalue = [13, 0]"] ;
# 135 -> 136 ;
# 137 [label="SQFT <= 5.0\ngini = 0.444\nsamples = 3\nvalue = [2, 1]"] ;
# 135 -> 137 ;
# 138 [label="gini = 0.0\nsamples = 2\nvalue = [2, 0]"] ;
# 137 -> 138 ;
# 139 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"] ;
# 137 -> 139 ;
# 140 [label="gini = 0.0\nsamples = 71\nvalue = [71, 0]"] ;
# 134 -> 140 ;
# 141 [label="SQFT <= 3.5\ngini = 0.002\nsamples = 1151\nvalue = [1150, 1]"] ;
# 133 -> 141 ;
# 142 [label="INCOME <= 6.5\ngini = 0.021\nsamples = 95\nvalue = [94, 1]"] ;
# 141 -> 142 ;
# 143 [label="gini = 0.0\nsamples = 87\nvalue = [87, 0]"] ;
# 142 -> 143 ;
# 144 [label="NGUTIL <= 98.0\ngini = 0.219\nsamples = 8\nvalue = [7, 1]"] ;
# 142 -> 144 ;
# 145 [label="gini = 0.0\nsamples = 7\nvalue = [7, 0]"] ;
# 144 -> 145 ;
# 146 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"] ;
# 144 -> 146 ;
# 147 [label="gini = 0.0\nsamples = 1056\nvalue = [1056, 0]"] ;
# 141 -> 147 ;
# 148 [label="HOHETH <= 1.5\ngini = 0.005\nsamples = 4559\nvalue = [4547, 12]"] ;
# 0 -> 148 [labeldistance=2.5, labelangle=-45, headlabel="False"] ;
# 149 [label="avginc <= 54872.402\ngini = 0.062\nsamples = 31\nvalue = [30, 1]"] ;
# 148 -> 149 ;
# 150 [label="CZT24 <= 7.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]"] ;
# 149 -> 150 ;
# 151 [label="gini = 0.0\nsamples = 2\nvalue = [2, 0]"] ;
# 150 -> 151 ;
# 152 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"] ;
# 150 -> 152 ;
# 153 [label="gini = 0.0\nsamples = 28\nvalue = [28, 0]"] ;
# 149 -> 153 ;
# 154 [label="DWLTYPE <= 3.5\ngini = 0.005\nsamples = 4528\nvalue = [4517, 11]"] ;
# 148 -> 154 ;
# 155 [label="SQFT <= 10.5\ngini = 0.003\nsamples = 3786\nvalue = [3781, 5]"] ;
# 154 -> 155 ;
# 156 [label="BUILTYR <= 54.5\ngini = 0.002\nsamples = 3590\nvalue = [3587, 3]"] ;
# 155 -> 156 ;
# 157 [label="rescnt <= 4.5\ngini = 0.001\nsamples = 3503\nvalue = [3501, 2]"] ;
# 156 -> 157 ;
# 158 [label="gini = 0.0\nsamples = 3103\nvalue = [3103, 0]"] ;
# 157 -> 158 ;
# 159 [label="EXTWLINS <= 1.5\ngini = 0.01\nsamples = 400\nvalue = [398, 2]"] ;
# 157 -> 159 ;
# 160 [label="gini = 0.0\nsamples = 259\nvalue = [259, 0]"] ;
# 159 -> 160 ;
# 161 [label="cecfast <= 12.5\ngini = 0.028\nsamples = 141\nvalue = [139, 2]"] ;
# 159 -> 161 ;
# 162 [label="CZT24 <= 7.0\ngini = 0.015\nsamples = 130\nvalue = [129, 1]"] ;
# 161 -> 162 ;
# 163 [label="HOHWHT1 <= 0.5\ngini = 0.091\nsamples = 21\nvalue = [20, 1]"] ;
# 162 -> 163 ;
# 164 [label="gini = 0.0\nsamples = 14\nvalue = [14, 0]"] ;
# 163 -> 164 ;
# 165 [label="cecfast <= 6.5\ngini = 0.245\nsamples = 7\nvalue = [6, 1]"] ;
# 163 -> 165 ;
# 166 [label="gini = 0.0\nsamples = 4\nvalue = [4, 0]"] ;
# 165 -> 166 ;
# 167 [label="SQFT <= 8.0\ngini = 0.444\nsamples = 3\nvalue = [2, 1]"] ;
# 165 -> 167 ;
# 168 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"] ;
# 167 -> 168 ;
# 169 [label="gini = 0.0\nsamples = 2\nvalue = [2, 0]"] ;
# 167 -> 169 ;
# 170 [label="gini = 0.0\nsamples = 109\nvalue = [109, 0]"] ;
# 162 -> 170 ;
# 171 [label="INCOME <= 10.5\ngini = 0.165\nsamples = 11\nvalue = [10, 1]"] ;
# 161 -> 171 ;
# 172 [label="avginc <= 77500.0\ngini = 0.444\nsamples = 3\nvalue = [2, 1]"] ;
# 171 -> 172 ;
# 173 [label="gini = 0.0\nsamples = 2\nvalue = [2, 0]"] ;
# 172 -> 173 ;
# 174 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"] ;
# 172 -> 174 ;
# 175 [label="gini = 0.0\nsamples = 8\nvalue = [8, 0]"] ;
# 171 -> 175 ;
# 176 [label="INCOME <= 8.5\ngini = 0.023\nsamples = 87\nvalue = [86, 1]"] ;
# 156 -> 176 ;
# 177 [label="CZT24 <= 7.5\ngini = 0.32\nsamples = 5\nvalue = [4, 1]"] ;
# 176 -> 177 ;
# 178 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"] ;
# 177 -> 178 ;
# 179 [label="gini = 0.0\nsamples = 4\nvalue = [4, 0]"] ;
# 177 -> 179 ;
# 180 [label="gini = 0.0\nsamples = 82\nvalue = [82, 0]"] ;
# 176 -> 180 ;
# 181 [label="BUILTYR <= 1.5\ngini = 0.02\nsamples = 196\nvalue = [194, 2]"] ;
# 155 -> 181 ;
# 182 [label="ACEILINS <= 49.5\ngini = 0.18\nsamples = 10\nvalue = [9, 1]"] ;
# 181 -> 182 ;
# 183 [label="gini = 0.0\nsamples = 9\nvalue = [9, 0]"] ;
# 182 -> 183 ;
# 184 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"] ;
# 182 -> 184 ;
# 185 [label="cecfast <= 12.5\ngini = 0.011\nsamples = 186\nvalue = [185, 1]"] ;
# 181 -> 185 ;
# 186 [label="gini = 0.0\nsamples = 145\nvalue = [145, 0]"] ;
# 185 -> 186 ;
# 187 [label="EDUC <= 5.5\ngini = 0.048\nsamples = 41\nvalue = [40, 1]"] ;
# 185 -> 187 ;
# 188 [label="gini = 0.0\nsamples = 23\nvalue = [23, 0]"] ;
# 187 -> 188 ;
# 189 [label="BUILTYR <= 10.5\ngini = 0.105\nsamples = 18\nvalue = [17, 1]"] ;
# 187 -> 189 ;
# 190 [label="gini = 0.0\nsamples = 9\nvalue = [9, 0]"] ;
# 189 -> 190 ;
# 191 [label="BUILTYR <= 11.5\ngini = 0.198\nsamples = 9\nvalue = [8, 1]"] ;
# 189 -> 191 ;
# 192 [label="HOHASN1 <= 0.5\ngini = 0.375\nsamples = 4\nvalue = [3, 1]"] ;
# 191 -> 192 ;
# 193 [label="SQFT <= 11.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]"] ;
# 192 -> 193 ;
# 194 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"] ;
# 193 -> 194 ;
# 195 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"] ;
# 193 -> 195 ;
# 196 [label="gini = 0.0\nsamples = 2\nvalue = [2, 0]"] ;
# 192 -> 196 ;
# 197 [label="gini = 0.0\nsamples = 5\nvalue = [5, 0]"] ;
# 191 -> 197 ;
# 198 [label="CZT24 <= 9.5\ngini = 0.016\nsamples = 742\nvalue = [736, 6]"] ;
# 154 -> 198 ;
# 199 [label="BUILTYR <= 5.5\ngini = 0.027\nsamples = 440\nvalue = [434, 6]"] ;
# 198 -> 199 ;
# 200 [label="rescnt <= 5.5\ngini = 0.053\nsamples = 146\nvalue = [142, 4]"] ;
# 199 -> 200 ;
# 201 [label="DWLTYPE <= 51.5\ngini = 0.043\nsamples = 135\nvalue = [132, 3]"] ;
# 200 -> 201 ;
# 202 [label="DWLTYPE <= 5.0\ngini = 0.076\nsamples = 76\nvalue = [73, 3]"] ;
# 201 -> 202 ;
# 203 [label="EDUC <= 4.5\ngini = 0.053\nsamples = 74\nvalue = [72, 2]"] ;
# 202 -> 203 ;
# 204 [label="rescnt <= 1.5\ngini = 0.133\nsamples = 28\nvalue = [26, 2]"] ;
# 203 -> 204 ;
# 205 [label="gini = 0.0\nsamples = 13\nvalue = [13, 0]"] ;
# 204 -> 205 ;
# 206 [label="cecfast <= 11.5\ngini = 0.231\nsamples = 15\nvalue = [13, 2]"] ;
# 204 -> 206 ;
# 207 [label="INCOME <= 54.0\ngini = 0.142\nsamples = 13\nvalue = [12, 1]"] ;
# 206 -> 207 ;
# 208 [label="gini = 0.0\nsamples = 11\nvalue = [11, 0]"] ;
# 207 -> 208 ;
# 209 [label="BUILTYR <= 4.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]"] ;
# 207 -> 209 ;
# 210 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"] ;
# 209 -> 210 ;
# 211 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"] ;
# 209 -> 211 ;
# 212 [label="ETHNIC <= 2.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]"] ;
# 206 -> 212 ;
# 213 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"] ;
# 212 -> 213 ;
# 214 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"] ;
# 212 -> 214 ;
# 215 [label="gini = 0.0\nsamples = 46\nvalue = [46, 0]"] ;
# 203 -> 215 ;
# 216 [label="rescnt <= 3.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]"] ;
# 202 -> 216 ;
# 217 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"] ;
# 216 -> 217 ;
# 218 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"] ;
# 216 -> 218 ;
# 219 [label="gini = 0.0\nsamples = 59\nvalue = [59, 0]"] ;
# 201 -> 219 ;
# 220 [label="avginc <= 61250.0\ngini = 0.165\nsamples = 11\nvalue = [10, 1]"] ;
# 200 -> 220 ;
# 221 [label="HOHWHT1 <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]"] ;
# 220 -> 221 ;
# 222 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"] ;
# 221 -> 222 ;
# 223 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"] ;
# 221 -> 223 ;
# 224 [label="gini = 0.0\nsamples = 9\nvalue = [9, 0]"] ;
# 220 -> 224 ;
# 225 [label="EDUC <= 3.5\ngini = 0.014\nsamples = 294\nvalue = [292, 2]"] ;
# 199 -> 225 ;
# 226 [label="cecfast <= 4.5\ngini = 0.153\nsamples = 12\nvalue = [11, 1]"] ;
# 225 -> 226 ;
# 227 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"] ;
# 226 -> 227 ;
# 228 [label="gini = 0.0\nsamples = 11\nvalue = [11, 0]"] ;
# 226 -> 228 ;
# 229 [label="NGUTIL <= 98.0\ngini = 0.007\nsamples = 282\nvalue = [281, 1]"] ;
# 225 -> 229 ;
# 230 [label="gini = 0.0\nsamples = 252\nvalue = [252, 0]"] ;
# 229 -> 230 ;
# 231 [label="CZT24 <= 8.5\ngini = 0.064\nsamples = 30\nvalue = [29, 1]"] ;
# 229 -> 231 ;
# 232 [label="gini = 0.0\nsamples = 28\nvalue = [28, 0]"] ;
# 231 -> 232 ;
# 233 [label="rescnt <= 1.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]"] ;
# 231 -> 233 ;
# 234 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"] ;
# 233 -> 234 ;
# 235 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"] ;
# 233 -> 235 ;
# 236 [label="gini = 0.0\nsamples = 302\nvalue = [302, 0]"] ;
# 198 -> 236 ;
# }

# %%
#Feature Importance Table
pd.DataFrame({'Feature': X.columns, 'Importance': first_tree.feature_importances_}).sort_values(by = 'Importance',ascending = False)
# Out:
#      Feature  Importance
# 21   cecfast    0.125871
# 19    rescnt    0.114765
# 9       EDUC    0.096783
# 18     CZT24    0.088565
# 2    BUILTYR    0.088145
# 4       SQFT    0.078443
# 6   ACEILINS    0.064344
# 8     avginc    0.059752
# 7     NGUTIL    0.059312
# 20    HOHETH    0.048539
# 17    INCOME    0.041299
# 5   EXTWLINS    0.039967
# 0    DWLTYPE    0.036791
# 10    ETHNIC    0.025533
# 15   HOHWHT1    0.016840
# 14   HOHLAT1    0.007295
# 12   HOHASN1    0.005471
# 1    OWNRENT    0.002285
# 13   HOHBLK1    0.000000
# 16   HOHOTH1    0.000000
# 3    SEASOCC    0.000000
# 11   HOHIND1    0.000000

# %%
from sklearn.model_selection import RandomizedSearchCV
from scipy.stats import randint

param_dist = {'max_leaf_nodes': randint(3, 100),
              'max_features': randint(2, 22),
              'max_depth': randint(1, 10)}

rnd_search = RandomizedSearchCV(first_tree, param_distributions=param_dist, 
                                cv=10, n_iter=200, random_state = 2)
rnd_search.fit(X_train, y_train)

print(rnd_search.best_score_) 
print(rnd_search.best_params_)
# Out:
# 0.993321718931475
# {'max_depth': 2, 'max_features': 13, 'max_leaf_nodes': 88}

# %%
#New Decision Tree with tuned parameters from cross validation
opt_tree = DecisionTreeClassifier(max_depth= 2, max_features= 13, max_leaf_nodes= 88)
opt_tree.fit(X_train, y_train)

print("Number of features: {}".format(opt_tree.tree_.n_features))
print("Number of nodes (internal and terminal): {}".format(opt_tree.tree_.node_count), "\n")

train_score = opt_tree.score(X_train, y_train)
val_score = opt_tree.score(X_val, y_val)

print('Train Score: ', train_score)
print('Validation Score: ', val_score)
# Out:
# Number of features: 22
# Number of nodes (internal and terminal): 7
#
# Train Score:  0.993321718931475
# Validation Score:  0.9934697431432303

# %%
#View tree
import graphviz
print(tree.export_graphviz(opt_tree, feature_names=X.columns))
# Out:
# digraph Tree {
# node [shape=box] ;
# 0 [label="NGUTIL <= 98.0\ngini = 0.013\nsamples = 6888\nvalue = [6842, 46]"] ;
# 1 [label="INCOME <= 1.5\ngini = 0.01\nsamples = 6109\nvalue = [6079, 30]"] ;
# 0 -> 1 [labeldistance=2.5, labelangle=45, headlabel="True"] ;
# 5 [label="gini = 0.061\nsamples = 190\nvalue = [184, 6]"] ;
# 1 -> 5 ;
# 6 [label="gini = 0.008\nsamples = 5919\nvalue = [5895, 24]"] ;
# 1 -> 6 ;
# 2 [label="CZT24 <= 6.5\ngini = 0.04\nsamples = 779\nvalue = [763, 16]"] ;
# 0 -> 2 [labeldistance=2.5, labelangle=-45, headlabel="False"] ;
# 3 [label="gini = 0.125\nsamples = 179\nvalue = [167, 12]"] ;
# 2 -> 3 ;
# 4 [label="gini = 0.013\nsamples = 600\nvalue = [596, 4]"] ;
# 2 -> 4 ;
# }

# %%
#Optimized Single Tree Feature Importance
feature_importance = opt_tree.feature_importances_
feature_importance = feature_importance / feature_importance.max()
rf_feat = pd.DataFrame({'Feature':X_train.columns, 'Importance':feature_importance}).sort_values(by = 'Importance',ascending = False)
rf_feat.head()
# Out:
#     Feature  Importance
# 18    CZT24    1.000000
# 7    NGUTIL    0.335813
# 17   INCOME    0.277535
# 0   DWLTYPE    0.000000
# 12  HOHASN1    0.000000

# %%
# Bagging
from sklearn.ensemble import BaggingClassifier

bag_tree = BaggingClassifier()
bag_tree.fit(X_train, y_train)

bag_train_score = bag_tree.score(X_train, y_train)
bag_val_score = bag_tree.score(X_val, y_val)

print('Train Score: ', bag_train_score)
print('Validation Score: ', bag_val_score)
# Out:
# Train Score:  0.9976771196283392
# Validation Score:  0.9925990422289943

# %%
#Random Forest
from sklearn.ensemble import RandomForestClassifier

rf_tree = RandomForestClassifier()
rf_tree.fit(X_train, y_train)

rf_train_score = rf_tree.score(X_train, y_train)
rf_val_score = rf_tree.score(X_val, y_val)

print('Train Score: ', rf_train_score)
print('Validation Score: ', rf_val_score)
# Out:
# Train Score:  0.9976771196283392
# Validation Score:  0.9930343926861123
# /srv/app/venv/lib/python3.6/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)

# %%
#tuning hyperparameters
param_dist = {#'learning_rate': randint(1, 5),
              'max_leaf_nodes': randint(3, 100),
              'max_features': randint(2, 22),
              'max_depth': randint(1, 10),
              'min_samples_leaf': randint(1, 30)}

rnd_rf_search = RandomizedSearchCV(rf_tree, param_distributions=param_dist, 
                                cv=10, n_iter=50, random_state = 1)

rnd_rf_search.fit(X_train, y_train)

print(rnd_rf_search.best_params_)
# Out:
# {'max_depth': 6, 'max_features': 13, 'max_leaf_nodes': 15, 'min_samples_leaf': 9}

# %%
#tuned random forest

rf_opt_tree = RandomForestClassifier(max_depth = 6, max_features = 13, max_leaf_nodes = 15, min_samples_leaf = 9)
rf_opt_tree.fit(X_train, y_train)

rf_train_score = rf_opt_tree.score(X_train, y_train)
rf_val_score = rf_opt_tree.score(X_val, y_val)

print('Train Score: ', rf_train_score)
print('Validation Score: ', rf_val_score)

y_pred = rf_opt_tree.predict(X_test)
y_pred


from sklearn.metrics import classification_report, confusion_matrix  
print(confusion_matrix(y_test,y_pred))  
print(classification_report(y_test,y_pred))
# Out:
# Train Score:  0.993321718931475
# Validation Score:  0.9934697431432303
# [[2273    0]
#  [  24    0]]
#               precision    recall  f1-score   support
#
#            1       0.99      1.00      0.99      2273
#            3       0.00      0.00      0.00        24
#
#     accuracy                           0.99      2297
#    macro avg       0.49      0.50      0.50      2297
# weighted avg       0.98      0.99      0.98      2297
# /srv/app/venv/lib/python3.6/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /srv/app/venv/lib/python3.6/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
#Random Forest Feature Importance
feature_importance = rf_opt_tree.feature_importances_
feature_importance = feature_importance / feature_importance.max()
rf_feat = pd.DataFrame({'Feature':X_train.columns, 'Importance':feature_importance}).sort_values(by = 'Importance',ascending = False)
rf_feat.head()
# Out:
#     Feature  Importance
# 2   BUILTYR    1.000000
# 18    CZT24    0.965851
# 17   INCOME    0.621947
# 19   rescnt    0.465171
# 8    avginc    0.347039

# %%
plt.figure(figsize=(8, 7.5))
plt.barh(width=rf_feat.Importance, y=rf_feat.Feature);
plt.title('Feature Importance (Random Forest)')
# Out:
# Text(0.5, 1.0, 'Feature Importance (Random Forest)')

# %%
models = [first_tree, opt_tree, bag_tree, rf_tree, rf_opt_tree]
for i in models:
    print('Test Score: ', i.score(X_test, y_test))
# Out:
# Test Score:  0.9799738789725729
# Test Score:  0.9895515890291685
# Test Score:  0.9873748367435786
# Test Score:  0.9895515890291685
# Test Score:  0.9895515890291685

# %%
def fit_model(Model, X_train, X_test, y_train, y_test, alpha = 1):
    """
    This function fits a model of type Model to the data in the training set of X and y, and finds the MSE on the test set
    Inputs: 
        Model (sklearn model): the type of sklearn model with which to fit the data - LinearRegression, Ridge, or Lasso
        X_train: the set of features used to train the model
        y_train: the set of response variable observations used to train the model
        X_test: the set of features used to test the model
        y_test: the set of response variable observations used to test the model
        alpha: the penalty parameter, to be used with Ridge and Lasso models only
    """    
    model = Model(alpha = alpha)
        
    model.fit(X_train, y_train)
    mse = mean_squared_error(y_test, model.predict(X_test))
    coef = model.coef_.flatten()
    
    return mse, coef

# %%
#MSE values from Ridge and Lasso 
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.metrics import mean_squared_error

# possible solution

Models = [Ridge, Lasso] # list of models

# list that will hold MSE values - each element corresponds to a model in Models
mse_all = np.zeros(len(Models))

# initialize array that will hold coefficients - each column corresponds to a model in Models
coef_all = np.zeros((X_train.shape[1], len(Models)))

for Model, i in zip(Models, np.arange(len(Models))):
    mse_all[i], coef_all[:,i] = fit_model(Model, X_train, X_test, y_train, y_test)
print(coef_all, mse_all)
# Out:
# [[ 1.07600589e-04  0.00000000e+00]
#  [-2.34906854e-04 -0.00000000e+00]
#  [ 5.90350264e-05  0.00000000e+00]
#  [-9.46861240e-05 -0.00000000e+00]
#  [-2.10252371e-05  0.00000000e+00]
#  [ 3.36395181e-05  0.00000000e+00]
#  [ 9.89801931e-05  0.00000000e+00]
#  [ 2.46875161e-04  0.00000000e+00]
#  [-1.73112860e-07 -1.91910604e-07]
#  [-1.90602660e-04 -0.00000000e+00]
#  [-9.95840639e-05 -0.00000000e+00]
#  [-1.25416062e-03  0.00000000e+00]
#  [-2.59336122e-02 -0.00000000e+00]
#  [-7.22339974e-03  0.00000000e+00]
#  [-3.67638685e-04  0.00000000e+00]
#  [-1.33830617e-02 -0.00000000e+00]
#  [-8.60971944e-03 -0.00000000e+00]
#  [-8.49011047e-05 -0.00000000e+00]
#  [-3.14098534e-03 -0.00000000e+00]
#  [ 7.16422708e-04  0.00000000e+00]
#  [-2.05266115e-03 -0.00000000e+00]
#  [ 3.59282475e-04  0.00000000e+00]] [0.04117012 0.04118424]

# %%
#Next steps: optimize alpha, try regression model for AC electricity use, k fold CV, KNN & compare regression models
#ask salma about MSE values/ feature importance to make sure things are ok

# %%
#SVM Model
from sklearn.svm import SVC

clf = SVC()

clf.fit(X_train, y_train.values.ravel())

y_pred = clf.predict(X_test)
print(confusion_matrix(y_test,y_pred))  
print(classification_report(y_test,y_pred))
# Out:
# /srv/app/venv/lib/python3.6/site-packages/sklearn/svm/base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# [[2273    0]
#  [  24    0]]
#               precision    recall  f1-score   support
#
#            1       0.99      1.00      0.99      2273
#            3       0.00      0.00      0.00        24
#
#     accuracy                           0.99      2297
#    macro avg       0.49      0.50      0.50      2297
# weighted avg       0.98      0.99      0.98      2297
# /srv/app/venv/lib/python3.6/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
X = 
y = 
sk_model = linear_model.LinearRegression()
sk_fit = sk_model.fit(X,y)
# Out:
#   File "<ipython-input-26-23ac4aff3892>", line 1
#     X =
#         ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## Interpretation and Conclusions (20 points)
# In this section you must relate your modeling and forecasting results to your original research question.  You must
# 1. What do the answers mean? What advice would you give a decision maker on the basis of your results?  How might they allocate their resources differently with the results of your model?  Why should the reader care about your results?
# 2. Discuss caveats and / or reasons your results might be flawed.  No model is perfect, and understanding a model's imperfections is extremely important for the purpose of knowing how to interpret your results.  Often, we know the model output is wrong but we can assign a direction for its bias.  This helps to understand whether or not your answers are conservative.
#
# Shoot for 500-1000 words for this section.
