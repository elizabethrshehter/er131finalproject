# %% [markdown]
# # ER131 Final Project (replace this with your project title)
# Fall 2019
#
# In this cell, give an alphabetical (by last name) list of student group members.  Beside each student's name, provide a description of each student's contribution to the project.

# %% [markdown]
# ## Basic Project Requirements (delete this markdown cell in your final submission)
#
# **How to use this notebook**:  This notebook is the template for your semester project.  Each markdown cell provides instructions on what to do in order to complete a successful project.  The cell you're reading right now is the only one you can delete from what you eventually hand in.  For the other cells:
# 1. You may replace the instructions in each cell with your own work but do not edit the cell titles (with the exception of the project title, above).
# 2. Follow the instructions in each section carefully.  For some sections you will enter only markdown text in the existing cells. For other sections, you'll accompany the markdown cells with additional code cells, and perhaps more markdown, before moving on to the next section.
#
# **Grading**.  You'll see point allocations listed in each of the section titles below.  In addition, there are other categories for points:
# 1. Visualization (10 points).  Plots should be well organized, legible, labelled, and well-suited for the question they are being used to answer or explore.
# 2. Clarity (5 points). Note that clarity also supports points elsewhere, because if we can't understand what you're explaining, we'll assume you didn't understand what you were doing and give points accordingly!
#
# For each Section or Category, we will give points according to the following percentage scale:
# 1. More than 90%:  work that is free of anything but superficial mistakes, and demonstrates creativity and / or a very deep understanding of what you are doing.
# 2. 80-90%: work without fundamental errors and demonstrates a basic understanding of what you're doing.
# 3. 60-80%: work with fundamental flaws in the analysis and / or conveys that you do not understand the basics of the work you are trying to do.
# 4. Below 60%: Work that is severely lacking or incomplete.
#
# Note that we distinguish *mistakes* from *"my idea didn't work"*.  Sometimes you don't know if you can actually do the thing you're trying to do and as you dig in you find that you can't.  That doesn't necessarily mean you made a mistake; it might just mean you needed more information.  We'll still give high marks to ambitious projects that "fail" at their stated objective, as long as that objective was clear and you demonstrate an understanding of what you were doing and why it didn't work.
#
# **Working in groups:**  We have the following requirements:
# 1. Projects must have at least one distinct quantitative question per student in the group.  Questions can and should be related, but they need to require distinct work efforts, and the interpretation and analysis should cover each question in detail.  If you have any doubt about whether your questions are distinct, consult with the instructors.
# 2. We use a sliding data requirements scale, see below.
#
# **Data requirements**:  Projects must use data from a minimum of $1+N_s$ different sources, where $N_s$ is the number of students in the group.  You should merge at least two data sets. </font>
#
# **Advice on Project Topics**:  We want you to do a project that relates to energy and environment topics.
#
# **Selecting a Project**: You have the choice of working on a project for a client or formulating your own project. Client project descriptions can be found in the "project" folder on Github.
#
# **Suggested data sets**: If you choose not to work on a client projets, here are some ideas for data starting points. You can definitely bring your own data to the table!
# 1. [Purple Air](https://www.purpleair.com) Instructions on how to download PurpleAir data are [here](https://docs.google.com/document/d/15ijz94dXJ-YAZLi9iZ_RaBwrZ4KtYeCy08goGBwnbCU/edit).
# 2. California Enviroscreen database.  Available [here].(https://oehha.ca.gov/calenviroscreen/report/calenviroscreen-30)
# 3. Several data sets available from the UC Irvine machine learning library:
#     1. [Forest Fires](https://archive.ics.uci.edu/ml/datasets/Forest+Fires)
#     4. [Climate](https://archive.ics.uci.edu/ml/datasets/Greenhouse+Gas+Observing+Network)
#     5. [Ozone](https://archive.ics.uci.edu/ml/datasets/Ozone+Level+Detection)
# 4. California Solar Initiative data (installed rooftop solar systems).  Available [here](https://www.californiasolarstatistics.ca.gov/data_downloads/).
# 5. World Bank Open Data, available [here](https://data.worldbank.org).
# 6. California ISO monitored emissions data, [here](http://www.caiso.com/TodaysOutlook/Pages/Emissions.aspx).
# 7. Energy Information Administration Residential Energy Consumption Survey, [here] (https://www.eia.gov/consumption/residential/data/2015/)
#
# **Dates**:
# You have the following due dates:
# 1. Thursday, October 3 (as part of homework 4): by this date you'll be expected to have formed groups of 2-3, identified your data sources, and defined a forecasting question. Feel free to use the lab time period in previous weeks to talk to potential group members, and to post on Piazza if you're looking for additional group members. The deliverable will be a question on homework 4 where you provide your group member names, data sources, and forecasting question.
# 1. Tuesday, December 17 (instead of final exam): This is when poster presentations will happen. Your deliverable is one printed poster for your group outlining the background behind your project, the questions explored, your data sources and choice of model, and results and discussion. A more detailed outline of the poster requirements will be posted later in the semester on Github.
# 1. Wednesday, December 18: Your Jupyter notebook and data should be submitted to bCourses (one submission per group).
#
# Throughout the semester, some of the homework assignments will include short questions designed to help you explore your project's data and analysis approach.
#
# Ok, now on to the project!

# %% [markdown]
# ## Abstract (5 points)
# Although this section comes first, you'll write it last.  It should be a ~250 word summary of your project.  1/3rd of the abstract should provide background, 1/3rd should explain what you did, and 1/3rd should explain what you learned.

# %% [markdown]
# ## Project Background (5 points)
# In this section you will describe relevant background for your project.  It should give enough information that a non-expert can understand in detail the history and / or context of the system or setting you wish to study, the need for quantitative analysis, and, broadly, what impact a quantitative analyses could have on the system.  Shoot for 500 words here.

# %% [markdown]
# ## Project Objective (5 points)
# In this section you will pose the central objective or objectives for your semester project.  Objectives should be extremely clear, well-defined and clearly cast as forecasting problems.
#
# Some example questions:
# 1. *"The purpose of this project is to train and evaluate different models to predict soil heavy metal contamination levels across the state of Louisiana, using a variety of features drawn from EPA, the US Census, and NAICS databases."* or
# 2. *"The purpose of this project is to train and evaluate different models to predict 1-minute generation from a UCSD solar PV site, up to 2 hours into the future, using historical data as well as basic weather forecast variables.*" or
# 3. *"The purpose of this project is to forecast daily emergency room visits for cardiac problems in 4 major US cities, using a majority of features including air quality forecasts, weather forecasts and seasonal variables."*
#
# You should reflect here on why it's important to answer these questions.  In most cases this will mean that you'll frame the answers to your questions as informing one or more *resource allocation* problems.  If you have done a good job of providing project background (in the cell above) then this reflection will be short and easy to write.
#
# **Comment on novelty:** You may find it hard to identify a project question that has *never* been answered before.  It's ok if you take inspiration from existing analyses.  However you shouldn't exactly reproduce someone else's analysis.  If you take inspiration from another analyses, you should still use different models, different data, and so on.

# %% [markdown]
# 1. Does a specific residential unit have air conditioning based on different features known about the unit?
#
# 2. How much AC electricity consumption is a residential unit likely to use based on different features known about the unit?
#
# 3. Out of the features in the model, are any of the demographic features more significant or less significant in predicting ownership of AC units in residential homes?

# %% [markdown]
# ## Input Data Description (5 points)
# Here you will provide an initial description of your data sets, including:
# 1. The origins of your data.  Where did you get the data?  How were the data collected from the original sources?
# 2. The structure, granularity, scope, temporality and faithfulness (SGSTF) of your data.  To discuss these attributes you should load the data into one or more data frames (so you'll start building code cells for the first time).  At a minimum, use some basic methods (`.head`, `.loc`, and so on) to provide support for the descriptions you provide for SGSTF.
#
# [Chapter 5](https://www.textbook.ds100.org/ch/05/eda_intro.html) of the DS100 textbook might be helpful for you in this section.

# %% [markdown]
# ## Data Cleaning (10 points)
# In this section you will walk through the data cleaning and merging process.  Explain how you make decisions to clean and merge the data.  Explain how you convince yourself that the data don't contain problems that will limit your ability to produce a meaningful analysis from them.
#
# [Chapter 4](https://www.textbook.ds100.org/ch/04/cleaning_intro.html) of the DS100 textbook might be helpful to you in this section.

# %%
import math
import numpy as np
import matplotlib 
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import cross_val_score, train_test_split
from sklearn import tree


import urllib
import os.path
from shutil import copyfile

# %%
# Install packages
# !pip install xlrd
# !pip install graphviz
# Out:
# Requirement already satisfied: xlrd in /srv/app/venv/lib/python3.6/site-packages
# You are using pip version 9.0.3, however version 19.3.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# Requirement already satisfied: graphviz in /srv/app/venv/lib/python3.6/site-packages
# You are using pip version 9.0.3, however version 19.3.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %% [markdown]
# Paycool tells us whether or not they have air conditioning
#
# 1. 1 and 2 mean YES
# 2. 3 means NO
# 3. 97 means missing
#
# We can use this as our response variable for the first classification question

# %% [markdown]
# ![PAYCOOL](PAYCOOL_info.png 'PAYCOOL_info.png')

# %%
#read in data and select columns
surv_data = pd.read_csv('Survdata.csv')

# %%
#selecting all columns that somehow relate to AC
surv_AC = surv_data[["DWLTYPE",
"OWNRENT",
"BUILTYR",
"SEASOCC",
"SQFT",
"EXTWLINS",
"ACEILINS",
"NGUTIL",
"PAYCOOL",
"CLCNTAGE",
"avginc",
"CTEVZON",
"CLCTLTYP",
"CMRNSET",
"CDAYSET",
"CEVNSET",
"CNITESET",
"NOROOMAC",
"ACTYP1",
"ACAGE1",
"CCADD",
"CCFUEL",
"EDUC",
"ETHNIC",
"HOHIND1",
"HOHASN1",
"HOHBLK1",
"HOHLAT1",
"HOHWHT1",
"HOHOTH1",
"INCOME",
"CZT24",
"caccnt",
"RACCNT",
"rescnt",
"HOHETH",
"cecfast",
"new_cac_uec"]]

#Dropping additional columns that directly indicate AC and therefore aren't useful to predict on 
surv_AC = surv_AC.drop(columns= ['new_cac_uec','ACTYP1','CLCNTAGE','caccnt','RACCNT', 'CTEVZON',
'CLCTLTYP',
'CMRNSET',
'CDAYSET',
'CEVNSET',
'CNITESET',
'NOROOMAC',
'ACAGE1',
'CCADD',
'CCFUEL'])

# %%
#issue that there are a 100 more nans than originally were missing from their data

#drop rows with 97
survey_clean = surv_AC[surv_AC['PAYCOOL'] != 97]

#number of datapoints using for response variable
num_data = sum(survey_clean['PAYCOOL'] != 97)
           
#ask about this warning
survey_clean['PAYCOOL'] = np.where(survey_clean['PAYCOOL'] == 2, 1, survey_clean['PAYCOOL'])

#check which columns contain Nans, we don't want to drop all rows containing Nans because that will reduce our dataset sample significantly
survey_clean.isna().any()

survey_clean = survey_clean.fillna(0).astype(int)

survey_clean.head()
# Out:
# /srv/app/venv/lib/python3.6/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # Remove the CWD from sys.path while we load stuff.
#    DWLTYPE  OWNRENT  BUILTYR  SEASOCC  SQFT  EXTWLINS  ACEILINS  NGUTIL  \
# 0        2        1        7        1     4         1         1       2
# 1        1        1        3        1     6         2         1       2
# 2        1        1        4        1     5         2         1       2
# 3        1        1        5        1     7         1         2       2
# 4        1        2        1        1     4        97        97       2
#
#    PAYCOOL  avginc   ...     HOHASN1  HOHBLK1  HOHLAT1  HOHWHT1  HOHOTH1  \
# 0        1   32500   ...           0        0        0        1        0
# 1        3   32500   ...           0        0        0        1        0
# 2        3   32500   ...           0        0        0        1        0
# 3        1   87500   ...           0        0        0        1        0
# 4        1   55000   ...           0        0        0        1        0
#
#    INCOME  CZT24  rescnt  HOHETH  cecfast
# 0       5     10       1       5       13
# 1       5     10       1       5       13
# 2       5     10       1       5       13
# 3      10      7       2       5       13
# 4       8      7       2       5       13
#
# [5 rows x 23 columns]

# %%
#load the column dictionary file: key for all the column names, what they mean 
coldict = pd.read_csv('coldict.csv')
coldict_clean = coldict[['Column Name', 'Notes']]
coldict_clean.columns = ['Feature', 'Definition']
coldict_clean.head()
# Out:
#    Feature                          Definition
# 0  DWLTYPE                     type of housing
# 1  OWNRENT            whether they own or rent
# 2  BUILTYR                year residence built
# 3  SEASOCC  permanent or partial year resident
# 4     SQFT              square footage of home

# %% [markdown]
# ### Exploring PM2.5 Concentrations By Climate Zone (CZT24) and Zipcode in Cal Enviro Screen ####

# %%
ces = pd.read_csv('ces.csv') #read in the Cal Enviro Screen Data 
cztozip = pd.read_csv('climatezonesbyzip.csv') #read in Climate Zone by Zipcode from energy.ca.gov

# %%
cztozip.columns = ['ZIP', 'CZT24']
czwithzip = cztozip.groupby('CZT24')['ZIP'].apply(list).to_frame()

# %%
pm25byzip = ces[['ZIP', 'PM2.5']]
pm25byzip = pm25byzip.groupby(['ZIP']).mean()

# %%
# add zipcode column to surv_AC by climate zone
surv_AC_withzip = surv_AC.merge(czwithzip, how = 'left', on = 'CZT24')

# %% [markdown]
# ## Data Summary and Exploratory Data Analysis (10 points)
#
# In this section you should provide a tour through some of the basic trends and patterns in your data.  This includes providing initial plots to summarize the data, such as box plots, histograms, trends over time, scatter plots relating one variable or another.
#
# [Chapter 6](https://www.textbook.ds100.org/ch/06/viz_intro.html) of the DS100 textbook might be helpful for providing ideas for visualizations that describe your data.

# %%
x = survey_clean.groupby('INCOME').count().drop(97).index
height = survey_clean.groupby('INCOME').count().drop(97)['PAYCOOL']

#plt.bar(x,height,align = 'center')

sns.barplot(x, height,palette = "muted")
plt.xlabel('Income Bracket (Low to High)')
plt.ylabel('AC Units Installed ')
plt.title('Relationship between Income and AC Installation')
plt.show()

# %%
x = survey_clean.groupby('EDUC').count().drop(97).index
height = survey_clean.groupby('EDUC').count().drop(97)['PAYCOOL']
#plt.bar(x,height,align = 'center')

sns.barplot(x, height,palette = "muted")
plt.xlabel('Education level (Low to High)')
plt.ylabel('Number With AC Installed ')
plt.title('Relationship between Education and AC Installation')
plt.show()

# %% [markdown]
# ## Forecasting and Prediction Modeling (25 points)
#
# This section is where the rubber meets the road.  In it you must:
# 1. Explore at least 3 prediction modeling approaches, ranging from the simple (e.g. linear regression, KNN) to the complex (e.g. SVM, random forests, Lasso).
# 2. Motivate all your modeling decisions.  This includes parameter choices (e.g., how many folds in k-fold cross validation, what time window you use for averaging your data) as well as model form (e.g., If you use regression trees, why?  If you include nonlinear features in a regression model, why?).
# 1. Carefully describe your cross validation and model selection process.  You should partition your data into training, testing and *validation* sets.
# 3. Evaluate your models' performance in terms of testing and validation error.  Do you see evidence of bias?  Where do you see evidence of variance?
# 4. Very carefully document your workflow.  We will be reading a lot of projects, so we need you to explain each basic step in your analysis.
# 5. Seek opportunities to write functions allow you to avoid doing things over and over, and that make your code more succinct and readable.

# %%
#functions for all the models we will be using

def BuildDecisionTree(X_train, X_val, y_train, y_val):
    first_tree = DecisionTreeClassifier()
    first_tree.fit(X_train, y_train)

    print("Number of features: {}".format(first_tree.tree_.n_features))
    print("Number of nodes (internal and terminal): {}".format(first_tree.tree_.node_count), "\n")

    train_score = first_tree.score(X_train, y_train)
    val_score = first_tree.score(X_val, y_val)

    print('Train Score: ', train_score)
    print('Validation Score: ', val_score)
    
    return first_tree

def TunedDecisionTree(X_train, X_val, y_train, y_val, max_depth, max_features, max_leaf_nodes):
    opt_tree = DecisionTreeClassifier(max_depth=max_depth, max_features=max_features, max_leaf_nodes=max_leaf_nodes)
    opt_tree.fit(X_train, y_train)

    print("Number of features: {}".format(opt_tree.tree_.n_features))
    print("Number of nodes (internal and terminal): {}".format(opt_tree.tree_.node_count), "\n")

    train_score = opt_tree.score(X_train, y_train)
    val_score = opt_tree.score(X_val, y_val)

    print('Train Score: ', train_score)
    print('Validation Score: ', val_score)
    return opt_tree

def BaggingTree(X_train, X_val, y_train, y_val):

    from sklearn.ensemble import BaggingClassifier

    bag_tree = BaggingClassifier()
    bag_tree.fit(X_train, y_train)

    bag_train_score = bag_tree.score(X_train, y_train)
    bag_val_score = bag_tree.score(X_val, y_val)

    print('Train Score: ', bag_train_score)
    print('Validation Score: ', bag_val_score)
   
    return bag_tree

def RandomForest(X_train, X_val, y_train, y_val):

    from sklearn.ensemble import RandomForestClassifier

    rf_tree = RandomForestClassifier()
    rf_tree.fit(X_train, y_train)

    rf_train_score = rf_tree.score(X_train, y_train)
    rf_val_score = rf_tree.score(X_val, y_val)

    print('Train Score: ', rf_train_score)
    print('Validation Score: ', rf_val_score)
    return rf_tree

def opt_RandomForest(X_train, X_val, y_train, y_val, max_depth, max_features, max_leaf_nodes,min_samples_leaf):

    rf_opt_tree = RandomForestClassifier(max_depth = max_depth, max_features = max_features, max_leaf_nodes = max_leaf_nodes, min_samples_leaf = min_samples_leaf)
    rf_opt_tree.fit(X_train, y_train)

    rf_train_score = rf_opt_tree.score(X_train, y_train)
    rf_val_score = rf_opt_tree.score(X_val, y_val)

    print('Train Score: ', rf_train_score)
    print('Validation Score: ', rf_val_score)

    return rf_opt_tree

def ConfusionMatrix(rf_opt_tree, X_test, y_test):
    from sklearn.metrics import classification_report, confusion_matrix 
    y_pred = rf_opt_tree.predict(X_test)
    print(confusion_matrix(y_test, y_pred))  
    print(classification_report(y_test,y_pred)) 

def ModelTestScores(X_test, y_test, first_tree, opt_tree, bag_tree, rf_tree, rf_opt_tree):
    models = [first_tree, opt_tree, bag_tree, rf_tree, rf_opt_tree]
    for i in models:
        print('Test Score: ', i.score(X_test, y_test))
    return

# %%
#PAYCOOL is our response column 

features = survey_clean.drop(columns = ['PAYCOOL'])
target = survey_clean['PAYCOOL']

# split test set
X, X_test, y, y_test = train_test_split(features, target, random_state = 1, test_size = .2)

# split between train and validation sets
X_train, X_val, y_train, y_val = train_test_split(X, y, random_state = 1, test_size = 0.25)

# %%
#Build Decision Tree
first_tree = DecisionTreeClassifier()
first_tree.fit(X_train, y_train)

print("Number of features: {}".format(first_tree.tree_.n_features))
print("Number of nodes (internal and terminal): {}".format(first_tree.tree_.node_count), "\n")

train_score = first_tree.score(X_train, y_train)
val_score = first_tree.score(X_val, y_val)

print('Train Score: ', train_score)
print('Validation Score: ', val_score)
# Out:
# Number of features: 22
# Number of nodes (internal and terminal): 6855
#
# Train Score:  0.9985712341815213
# Validation Score:  0.6938775510204082

# %% [markdown]
# To view decision tree: [Webgraphviz](http://webgraphviz.com)

# %%
import graphviz
print(tree.export_graphviz(first_tree, feature_names=X.columns))
# Out:
# digraph Tree {
# node [shape=box] ;
# 0 [label="CZT24 <= 7.5\ngini = 0.486\nsamples = 14698\nvalue = [8565, 6133]"] ;
# 1 [label="BUILTYR <= 5.5\ngini = 0.437\nsamples = 5691\nvalue = [1835, 3856]"] ;
# 0 -> 1 [labeldistance=2.5, labelangle=45, headlabel="True"] ;
# 2 [label="CZT24 <= 3.5\ngini = 0.348\nsamples = 3181\nvalue = [715, 2466]"] ;
# 1 -> 2 ;
# 3 [label="CZT24 <= 2.5\ngini = 0.234\nsamples = 1139\nvalue = [154, 985]"] ;
# 2 -> 3 ;
# 4 [label="DWLTYPE <= 1.5\ngini = 0.38\nsamples = 243\nvalue = [62, 181]"] ;
# 3 -> 4 ;
# 5 [label="BUILTYR <= 3.5\ngini = 0.311\nsamples = 166\nvalue = [32, 134]"] ;
# 4 -> 5 ;
# 6 [label="SQFT <= 9.5\ngini = 0.194\nsamples = 92\nvalue = [10, 82]"] ;
# 5 -> 6 ;
# 7 [label="avginc <= 18750.0\ngini = 0.148\nsamples = 87\nvalue = [7, 80]"] ;
# 6 -> 7 ;
# 8 [label="EXTWLINS <= 2.5\ngini = 0.444\nsamples = 9\nvalue = [3, 6]"] ;
# 7 -> 8 ;
# 9 [label="BUILTYR <= 2.0\ngini = 0.48\nsamples = 5\nvalue = [3, 2]"] ;
# 8 -> 9 ;
# 10 [label="SQFT <= 8.0\ngini = 0.444\nsamples = 3\nvalue = [1, 2]"] ;
# 9 -> 10 ;
# 11 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"] ;
# 10 -> 11 ;
# 12 [label="NGUTIL <= 50.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]"] ;
# 10 -> 12 ;
# 13 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"] ;
# 12 -> 13 ;
# 14 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"] ;
# 12 -> 14 ;
# 15 [label="gini = 0.0\nsamples = 2\nvalue = [2, 0]"] ;
# 9 -> 15 ;
# 16 [label="gini = 0.0\nsamples = 4\nvalue = [0, 4]"] ;
# 8 -> 16 ;
# 17 [label="SQFT <= 4.5\ngini = 0.097\nsamples = 78\nvalue = [4, 74]"] ;
# 7 -> 17 ;
# 18 [label="EXTWLINS <= 2.5\ngini = 0.26\nsamples = 13\nvalue = [2, 11]"] ;
# 17 -> 18 ;
# 19 [label="gini = 0.0\nsamples = 7\nvalue = [0, 7]"] ;
# 18 -> 19 ;
# 20 [label="INCOME <= 7.5\ngini = 0.444\nsamples = 6\nvalue = [2, 4]"] ;
# 18 -> 20 ;
# 21 [label="gini = 0.0\nsamples = 4\nvalue = [0, 4]"] ;
# 20 -> 21 ;
# 22 [label="gini = 0.0\nsamples = 2\nvalue = [2, 0]"] ;
# 20 -> 22 ;
# 23 [label="SQFT <= 6.5\ngini = 0.06\nsamples = 65\nvalue = [2, 63]"] ;
# 17 -> 23 ;
# 24 [label="gini = 0.0\nsamples = 32\nvalue = [0, 32]"] ;
# 23 -> 24 ;
# 25 [label="EDUC <= 4.5\ngini = 0.114\nsamples = 33\nvalue = [2, 31]"] ;
# 23 -> 25 ;
# 26 [label="cecfast <= 4.5\ngini = 0.278\nsamples = 6\nvalue = [1, 5]"] ;
# 25 -> 26 ;
# 27 [label="gini = 0.0\nsamples = 5\nvalue = [0, 5]"] ;
# 26 -> 27 ;
# 28 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"] ;
# 26 -> 28 ;
# 29 [label="CZT24 <= 1.5\ngini = 0.071\nsamples = 27\nvalue = [1, 26]"] ;
# 25 -> 29 ;
# 30 [label="BUILTYR <= 1.5\ngini = 0.18\nsamples = 10\nvalue = [1, 9]"] ;
# 29 -> 30 ;
# 31 [label="EXTWLINS <= 1.5\ngini = 0.375\nsamples = 4\nvalue = [1, 3]"] ;
# 30 -> 31 ;
# 32 [label="gini = 0.0\nsamples = 3\nvalue = [0, 3]"] ;
# 31 -> 32 ;
# 33 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"] ;
# 31 -> 33 ;
# 34 [label="gini = 0.0\nsamples = 6\nvalue = [0, 6]"] ;
# 30 -> 34 ;
# 35 [label="gini = 0.0\nsamples = 17\nvalue = [0, 17]"] ;
# 29 -> 35 ;
# 36 [label="cecfast <= 4.5\ngini = 0.48\nsamples = 5\nvalue = [3, 2]"] ;
# 6 -> 36 ;
# 37 [label="gini = 0.0\nsamples = 2\nvalue = [2, 0]"] ;
# 36 -> 37 ;
# 38 [label="ACEILINS <= 1.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]"] ;
# 36 -> 38 ;
# 39 [label="rescnt <= 4.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]"] ;
# 38 -> 39 ;
# 40 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"] ;
# 39 -> 40 ;
# 41 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"] ;
# 39 -> 41 ;
# 42 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"] ;
# 38 -> 42 ;
# 43 [label="avginc <= 10000.0\ngini = 0.418\nsamples = 74\nvalue = [22, 52]"] ;
# 5 -> 43 ;
# 44 [label="gini = 0.0\nsamples = 2\nvalue = [2, 0]"] ;
# 43 -> 44 ;
# 45 [label="OWNRENT <= 49.5\ngini = 0.401\nsamples = 72\nvalue = [20, 52]"] ;
# 43 -> 45 ;
# 46 [label="EDUC <= 5.5\ngini = 0.382\nsamples = 70\nvalue = [18, 52]"] ;
# 45 -> 46 ;
# 47 [label="HOHIND1 <= 0.5\ngini = 0.431\nsamples = 51\nvalue = [16, 35]"] ;
# 46 -> 47 ;
# 48 [label="CZT24 <= 1.5\ngini = 0.454\nsamples = 46\nvalue = [16, 30]"] ;
# 47 -> 48 ;
# 49 [label="gini = 0.0\nsamples = 4\nvalue = [0, 4]"] ;
# 48 -> 49 ;
# 50 [label="cecfast <= 2.5\ngini = 0.472\nsamples = 42\nvalue = [16, 26]"] ;
# 48 -> 50 ;
# 51 [label="EDUC <= 4.5\ngini = 0.48\nsamples = 10\nvalue = [6, 4]"] ;
# 50 -> 51 ;
# 52 [label="rescnt <= 2.5\ngini = 0.375\nsamples = 4\nvalue = [1, 3]"] ;
# 51 -> 52 ;
# 53 [label="gini = 0.0\nsamples = 2\nvalue = [0, 2]"] ;
# 52 -> 53 ;
# 54 [label="rescnt <= 4.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]"] ;
# 52 -> 54 ;
# 55 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"] ;
# 54 -> 55 ;
# 56 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"] ;
# 54 -> 56 ;
# 57 [label="BUILTYR <= 4.5\ngini = 0.278\nsamples = 6\nvalue = [5, 1]"] ;
# 51 -> 57 ;
# 58 [label="gini = 0.0\nsamples = 4\nvalue = [4, 0]"] ;
# 57 -> 58 ;
# 59 [label="avginc <= 23750.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]"] ;
# 57 -> 59 ;
# 60 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"] ;
# 59 -> 60 ;
# 61 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"] ;
# 59 -> 61 ;
# 62 [label="avginc <= 106250.0\ngini = 0.43\nsamples = 32\nvalue = [10, 22]"] ;
# 50 -> 62 ;
# 63 [label="rescnt <= 5.0\ngini = 0.365\nsamples = 25\nvalue = [6, 19]"] ;
# 62 -> 63 ;
# 64 [label="EDUC <= 3.5\ngini = 0.245\nsamples = 21\nvalue = [3, 18]"] ;
# 63 -> 64 ;
# 65 [label="ACEILINS <= 49.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]"] ;
# 64 -> 65 ;
# 66 [label="gini = 0.0\nsamples = 2\nvalue = [2, 0]"] ;
# 65 -> 66 ;
# 67 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"] ;
# 65 -> 67 ;
# 68 [label="HOHETH <= 3.0\ngini = 0.105\nsamples = 18\nvalue = [1, 17]"] ;
# 64 -> 68 ;
# 69 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"] ;
# 68 -> 69 ;
# 70 [label="gini = 0.0\nsamples = 17\nvalue = [0, 17]"] ;
# 68 -> 70 ;
# 71 [label="HOHASN1 <= 0.5\ngini = 0.375\nsamples = 4\nvalue = [3, 1]"] ;
# 63 -> 71 ;
# 72 [label="gini = 0.0\nsamples = 3\nvalue = [3, 0]"] ;
# 71 -> 72 ;
# 73 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"] ;
# 71 -> 73 ;
# 74 [label="ACEILINS <= 1.5\ngini = 0.49\nsamples = 7\nvalue = [4, 3]"] ;
# 62 -> 74 ;
# 75 [label="EXTWLINS <= 2.5\ngini = 0.32\nsamples = 5\nvalue = [4, 1]"] ;
# 74 -> 75 ;
# 76 [label="gini = 0.0\nsamples = 4\nvalue = [4, 0]"] ;
# 75 -> 76 ;
# 77 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"] ;
# 75 -> 77 ;
# 78 [label="gini = 0.0\nsamples = 2\nvalue = [0, 2]"] ;
# 74 -> 78 ;
# 79 [label="gini = 0.0\nsamples = 5\nvalue = [0, 5]"] ;
# 47 -> 79 ;
# 80 [label="SEASOCC <= 49.0\ngini = 0.188\nsamples = 19\nvalue = [2, 17]"] ;
# 46 -> 80 ;
# 81 [label="rescnt <= 2.5\ngini = 0.105\nsamples = 18\nvalue = [1, 17]"] ;
# 80 -> 81 ;
# 82 [label="gini = 0.0\nsamples = 14\nvalue = [0, 14]"] ;
# 81 -> 82 ;
# 83 [label="cecfast <= 4.5\ngini = 0.375\nsamples = 4\nvalue = [1, 3]"] ;
# 81 -> 83 ;
# 84 [label="gini = 0.0\nsamples = 2\nvalue = [0, 2]"] ;
# 83 -> 84 ;
# 85 [label="EXTWLINS <= 2.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]"] ;
# 83 -> 85 ;
# 86 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"] ;
# 85 -> 86 ;
# 87 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"] ;
# 85 -> 87 ;
# 88 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"] ;
# 80 -> 88 ;
# 89 [label="gini = 0.0\nsamples = 2\nvalue = [2, 0]"] ;
# 45 -> 89 ;
# 90 [label="CZT24 <= 1.5\ngini = 0.476\nsamples = 77\nvalue = [30, 47]"] ;
# 4 -> 90 ;
# 91 [label="gini = 0.0\nsamples = 10\nvalue = [0, 10]"] ;
# 90 -> 91 ;
# 92 [label="cecfast <= 4.5\ngini = 0.495\nsamples = 67\nvalue = [30, 37]"] ;
# 90 -> 92 ;
# 93 [label="BUILTYR <= 4.5\ngini = 0.499\nsamples = 50\nvalue = [26, 24]"] ;
# 92 -> 93 ;
# 94 [label="EDUC <= 4.5\ngini = 0.49\nsamples = 35\nvalue = [15, 20]"] ;
# 93 -> 94 ;
# 95 [label="DWLTYPE <= 2.5\ngini = 0.375\nsamples = 20\nvalue = [5, 15]"] ;
# 94 -> 95 ;
# 96 [label="gini = 0.0\nsamples = 3\nvalue = [3, 0]"] ;
# 95 -> 96 ;
# 97 [label="DWLTYPE <= 51.0\ngini = 0.208\nsamples = 17\nvalue = [2, 15]"] ;
# 95 -> 97 ;
# 98 [label="avginc <= 2500.0\ngini = 0.124\nsamples = 15\nvalue = [1, 14]"] ;
# 97 -> 98 ;
# 99 [label="ACEILINS <= 1.5\ngini = 0.32\nsamples = 5\nvalue = [1, 4]"] ;
# 98 -> 99 ;
# 100 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"] ;
# 99 -> 100 ;
# 101 [label="gini = 0.0\nsamples = 4\nvalue = [0, 4]"] ;
# 99 -> 101 ;
# 102 [label="gini = 0.0\nsamples = 10\nvalue = [0, 10]"] ;
# 98 -> 102 ;
# 103 [label="INCOME <= 6.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]"] ;
# 97 -> 103 ;
# 104 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"] ;
# 103 -> 104 ;
# 105 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"] ;
# 103 -> 105 ;
# 106 [label="HOHWHT1 <= 0.5\ngini = 0.444\nsamples = 15\nvalue = [10, 5]"] ;
# 94 -> 106 ;
# 107 [label="gini = 0.0\nsamples = 2\nvalue = [0, 2]"] ;
# 106 -> 107 ;
# 108 [label="NGUTIL <= 50.0\ngini = 0.355\nsamples = 13\nvalue = [10, 3]"] ;
# 106 -> 108 ;
# 109 [label="gini = 0.0\nsamples = 7\nvalue = [7, 0]"] ;
# 108 -> 109 ;
# 110 [label="SQFT <= 2.5\ngini = 0.5\nsamples = 6\nvalue = [3, 3]"] ;
# 108 -> 110 ;
# 111 [label="gini = 0.0\nsamples = 3\nvalue = [3, 0]"] ;
# 110 -> 111 ;
# 112 [label="gini = 0.0\nsamples = 3\nvalue = [0, 3]"] ;
# 110 -> 112 ;
# 113 [label="HOHETH <= 5.5\ngini = 0.391\nsamples = 15\nvalue = [11, 4]"] ;
# 93 -> 113 ;
# 114 [label="SQFT <= 52.0\ngini = 0.18\nsamples = 10\nvalue = [9, 1]"] ;
# 113 -> 114 ;
# 115 [label="gini = 0.0\nsamples = 9\nvalue = [9, 0]"] ;
# 114 -> 115 ;
# 116 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"] ;
# 114 -> 116 ;
# 117 [label="avginc <= 37239.5\ngini = 0.48\nsamples = 5\nvalue = [2, 3]"] ;
# 113 -> 117 ;
# 118 [label="EXTWLINS <= 1.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]"] ;
# 117 -> 118 ;
# 119 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"] ;
# 118 -> 119 ;
# 120 [label="gini = 0.0\nsamples = 2\nvalue = [2, 0]"] ;
# 118 -> 120 ;
# 121 [label="gini = 0.0\nsamples = 2\nvalue = [0, 2]"] ;
# 117 -> 121 ;
# 122 [label="ACEILINS <= 1.5\ngini = 0.36\nsamples = 17\nvalue = [4, 13]"] ;
# 92 -> 122 ;
# 123 [label="avginc <= 106250.0\ngini = 0.48\nsamples = 5\nvalue = [3, 2]"] ;
# 122 -> 123 ;
# 124 [label="gini = 0.0\nsamples = 3\nvalue = [3, 0]"] ;
# 123 -> 124 ;
# 125 [label="gini = 0.0\nsamples = 2\nvalue = [0, 2]"] ;
# 123 -> 125 ;
# 126 [label="EXTWLINS <= 2.5\ngini = 0.153\nsamples = 12\nvalue = [1, 11]"] ;
# 122 -> 126 ;
# 127 [label="SQFT <= 5.5\ngini = 0.375\nsamples = 4\nvalue = [1, 3]"] ;
# 126 -> 127 ;
# 128 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"] ;
# 127 -> 128 ;
# 129 [label="gini = 0.0\nsamples = 3\nvalue = [0, 3]"] ;
# 127 -> 129 ;
# 130 [label="gini = 0.0\nsamples = 8\nvalue = [0, 8]"] ;
# 126 -> 130 ;
# 131 [label="BUILTYR <= 2.5\ngini = 0.184\nsamples = 896\nvalue = [92, 804]"] ;
# 3 -> 131 ;
# 132 [label="avginc <= 10000.0\ngini = 0.12\nsamples = 438\nvalue = [28, 410]"] ;
# 131 -> 132 ;
# 133 [label="ACEILINS <= 49.5\ngini = 0.256\nsamples = 53\nvalue = [8, 45]"] ;
# 132 -> 133 ;
# 134 [label="SQFT <= 3.5\ngini = 0.124\nsamples = 45\nvalue = [3, 42]"] ;
# 133 -> 134 ;
# 135 [label="rescnt <= 3.0\ngini = 0.266\nsamples = 19\nvalue = [3, 16]"] ;
# 134 -> 135 ;
# 136 [label="HOHBLK1 <= 0.5\ngini = 0.198\nsamples = 18\nvalue = [2, 16]"] ;
# 135 -> 136 ;
# 137 [label="INCOME <= 5.0\ngini = 0.111\nsamples = 17\nvalue = [1, 16]"] ;
# 136 -> 137 ;
# 138 [label="gini = 0.0\nsamples = 11\nvalue = [0, 11]"] ;
# 137 -> 138 ;
# 139 [label="INCOME <= 6.5\ngini = 0.278\nsamples = 6\nvalue = [1, 5]"] ;
# 137 -> 139 ;
# 140 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"] ;
# 139 -> 140 ;
# 141 [label="gini = 0.0\nsamples = 5\nvalue = [0, 5]"] ;
# 139 -> 141 ;
# 142 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"] ;
# 136 -> 142 ;
# 143 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"] ;
# 135 -> 143 ;
# 144 [label="gini = 0.0\nsamples = 26\nvalue = [0, 26]"] ;
# 134 -> 144 ;
# 145 [label="DWLTYPE <= 3.5\ngini = 0.469\nsamples = 8\nvalue = [5, 3]"] ;
# 133 -> 145 ;
# 146 [label="rescnt <= 1.5\ngini = 0.375\nsamples = 4\nvalue = [1, 3]"] ;
# 145 -> 146 ;
# 147 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"] ;
# 146 -> 147 ;
# 148 [label="gini = 0.0\nsamples = 3\nvalue = [0, 3]"] ;
# 146 -> 148 ;
# 149 [label="gini = 0.0\nsamples = 4\nvalue = [4, 0]"] ;
# 145 -> 149 ;
# 150 [label="BUILTYR <= 1.5\ngini = 0.098\nsamples = 385\nvalue = [20, 365]"] ;
# 132 -> 150 ;
# 151 [label="avginc <= 87404.5\ngini = 0.066\nsamples = 265\nvalue = [9, 256]"] ;
# 150 -> 151 ;
# 152 [label="NGUTIL <= 98.0\ngini = 0.014\nsamples = 137\nvalue = [1, 136]"] ;
# 151 -> 152 ;
# 153 [label="gini = 0.0\nsamples = 125\nvalue = [0, 125]"] ;
# 152 -> 153 ;
# 154 [label="HOHWHT1 <= 0.5\ngini = 0.153\nsamples = 12\nvalue = [1, 11]"] ;
# 152 -> 154 ;
# 155 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"] ;
# 154 -> 155 ;
# 156 [label="gini = 0.0\nsamples = 11\nvalue = [0, 11]"] ;
# 154 -> 156 ;
# 157 [label="DWLTYPE <= 51.5\ngini = 0.117\nsamples = 128\nvalue = [8, 120]"] ;
# 151 -> 157 ;
# 158 [label="HOHETH <= 6.5\ngini = 0.094\nsamples = 122\nvalue = [6, 116]"] ;
# 157 -> 158 ;
# 159 [label="HOHLAT1 <= 0.5\ngini = 0.08\nsamples = 120\nvalue = [5, 115]"] ;
# 158 -> 159 ;
# 160 [label="EDUC <= 4.5\ngini = 0.053\nsamples = 111\nvalue = [3, 108]"] ;
# 159 -> 160 ;
# 161 [label="SQFT <= 6.5\ngini = 0.278\nsamples = 6\nvalue = [1, 5]"] ;
# 160 -> 161 ;
# 162 [label="gini = 0.0\nsamples = 5\nvalue = [0, 5]"] ;
# 161 -> 162 ;
# 163 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"] ;
# 161 -> 163 ;
# 164 [label="SQFT <= 7.5\ngini = 0.037\nsamples = 105\nvalue = [2, 103]"] ;
# 160 -> 164 ;
# 165 [label="gini = 0.0\nsamples = 72\nvalue = [0, 72]"] ;
# 164 -> 165 ;
# 166 [label="avginc <= 92062.5\ngini = 0.114\nsamples = 33\nvalue = [2, 31]"] ;
# 164 -> 166 ;
# 167 [label="EXTWLINS <= 2.5\ngini = 0.375\nsamples = 4\nvalue = [1, 3]"] ;
# 166 -> 167 ;
# 168 [label="gini = 0.0\nsamples = 3\nvalue = [0, 3]"] ;
# 167 -> 168 ;
# 169 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"] ;
# 167 -> 169 ;
# 170 [label="EDUC <= 5.5\ngini = 0.067\nsamples = 29\nvalue = [1, 28]"] ;
# 166 -> 170 ;
# 171 [label="rescnt <= 2.5\ngini = 0.32\nsamples = 5\nvalue = [1, 4]"] ;
# 170 -> 171 ;
# 172 [label="gini = 0.0\nsamples = 2\nvalue = [0, 2]"] ;
# 171 -> 172 ;
# 173 [label="rescnt <= 3.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]"] ;
# 171 -> 173 ;
# 174 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"] ;
# 173 -> 174 ;
# 175 [label="gini = 0.0\nsamples = 2\nvalue = [0, 2]"] ;
# 173 -> 175 ;
# 176 [label="gini = 0.0\nsamples = 24\nvalue = [0, 24]"] ;
# 170 -> 176 ;
# 177 [label="INCOME <= 11.5\ngini = 0.346\nsamples = 9\nvalue = [2, 7]"] ;
# 159 -> 177 ;
# 178 [label="SQFT <= 5.5\ngini = 0.5\nsamples = 4\nvalue = [2, 2]"] ;
# 177 -> 178 ;
# 179 [label="gini = 0.0\nsamples = 2\nvalue = [2, 0]"] ;
# 178 -> 179 ;
# 180 [label="gini = 0.0\nsamples = 2\nvalue = [0, 2]"] ;
# 178 -> 180 ;
# 181 [label="gini = 0.0\nsamples = 5\nvalue = [0, 5]"] ;
# 177 -> 181 ;
# 182 [label="EXTWLINS <= 2.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]"] ;
# 158 -> 182 ;
# 183 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"] ;
# 182 -> 183 ;
# 184 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"] ;
# 182 -> 184 ;
# 185 [label="avginc <= 106250.0\ngini = 0.444\nsamples = 6\nvalue = [2, 4]"] ;
# 157 -> 185 ;
# 186 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"] ;
# 185 -> 186 ;
# 187 [label="rescnt <= 1.5\ngini = 0.32\nsamples = 5\nvalue = [1, 4]"] ;
# 185 -> 187 ;
# 188 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"] ;
# 187 -> 188 ;
# 189 [label="gini = 0.0\nsamples = 4\nvalue = [0, 4]"] ;
# 187 -> 189 ;
# 190 [label="OWNRENT <= 1.5\ngini = 0.167\nsamples = 120\nvalue = [11, 109]"] ;
# 150 -> 190 ;
# 191 [label="avginc <= 41250.0\ngini = 0.196\nsamples = 100\nvalue = [11, 89]"] ;
# 190 -> 191 ;
# 192 [label="INCOME <= 4.5\ngini = 0.32\nsamples = 20\nvalue = [4, 16]"] ;
# 191 -> 192 ;
# 193 [label="gini = 0.0\nsamples = 12\nvalue = [0, 12]"] ;
# 192 -> 193 ;
# 194 [label="ETHNIC <= 1.5\ngini = 0.5\nsamples = 8\nvalue = [4, 4]"] ;
# 192 -> 194 ;
# 195 [label="rescnt <= 1.5\ngini = 0.32\nsamples = 5\nvalue = [4, 1]"] ;
# 194 -> 195 ;
# 196 [label="gini = 0.0\nsamples = 3\nvalue = [3, 0]"] ;
# 195 -> 196 ;
# 197 [label="HOHASN1 <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]"] ;
# 195 -> 197 ;
# 198 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"] ;
# 197 -> 198 ;
# 199 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"] ;
# 197 -> 199 ;
# 200 [label="gini = 0.0\nsamples = 3\nvalue = [0, 3]"] ;
# 194 -> 200 ;
# 201 [label="DWLTYPE <= 51.5\ngini = 0.16\nsamples = 80\nvalue = [7, 73]"] ;
# 191 -> 201 ;
# 202 [label="avginc <= 150000.0\ngini = 0.131\nsamples = 71\nvalue = [5, 66]"] ;
# 201 -> 202 ;
# 203 [label="HOHETH <= 2.5\ngini = 0.073\nsamples = 53\nvalue = [2, 51]"] ;
# 202 -> 203 ;
# 204 [label="rescnt <= 1.5\ngini = 0.298\nsamples = 11\nvalue = [2, 9]"] ;
# 203 -> 204 ;
# 205 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"] ;
# 204 -> 205 ;
# 206 [label="SQFT <= 5.5\ngini = 0.18\nsamples = 10\nvalue = [1, 9]"] ;
# 204 -> 206 ;
# 207 [label="HOHOTH1 <= 48.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]"] ;
# 206 -> 207 ;
# 208 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"] ;
# 207 -> 208 ;
# 209 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"] ;
# 207 -> 209 ;
# 210 [label="gini = 0.0\nsamples = 8\nvalue = [0, 8]"] ;
# 206 -> 210 ;
# 211 [label="gini = 0.0\nsamples = 42\nvalue = [0, 42]"] ;
# 203 -> 211 ;
# 212 [label="ACEILINS <= 49.0\ngini = 0.278\nsamples = 18\nvalue = [3, 15]"] ;
# 202 -> 212 ;
# 213 [label="EXTWLINS <= 1.5\ngini = 0.219\nsamples = 16\nvalue = [2, 14]"] ;
# 212 -> 213 ;
# 214 [label="gini = 0.0\nsamples = 8\nvalue = [0, 8]"] ;
# 213 -> 214 ;
# 215 [label="cecfast <= 4.5\ngini = 0.375\nsamples = 8\nvalue = [2, 6]"] ;
# 213 -> 215 ;
# 216 [label="gini = 0.0\nsamples = 2\nvalue = [0, 2]"] ;
# 215 -> 216 ;
# 217 [label="SQFT <= 9.0\ngini = 0.444\nsamples = 6\nvalue = [2, 4]"] ;
# 215 -> 217 ;
# 218 [label="EDUC <= 5.5\ngini = 0.32\nsamples = 5\nvalue = [1, 4]"] ;
# 217 -> 218 ;
# 219 [label="EDUC <= 4.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]"] ;
# 218 -> 219 ;
# 220 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"] ;
# 219 -> 220 ;
# 221 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"] ;
# 219 -> 221 ;
# 222 [label="gini = 0.0\nsamples = 3\nvalue = [0, 3]"] ;
# 218 -> 222 ;
# 223 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"] ;
# 217 -> 223 ;
# 224 [label="SQFT <= 7.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]"] ;
# 212 -> 224 ;
# 225 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"] ;
# 224 -> 225 ;
# 226 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"] ;
# 224 -> 226 ;
# 227 [label="EXTWLINS <= 2.0\ngini = 0.346\nsamples = 9\nvalue = [2, 7]"] ;
# 201 -> 227 ;
# 228 [label="gini = 0.0\nsamples = 3\nvalue = [0, 3]"] ;
# 227 -> 228 ;
# 229 [label="INCOME <= 8.5\ngini = 0.444\nsamples = 6\nvalue = [2, 4]"] ;
# 227 -> 229 ;
# 230 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"] ;
# 229 -> 230 ;
# 231 [label="avginc <= 70518.5\ngini = 0.32\nsamples = 5\nvalue = [1, 4]"] ;
# 229 -> 231 ;
# 232 [label="gini = 0.0\nsamples = 3\nvalue = [0, 3]"] ;
# 231 -> 232 ;
# 233 [label="rescnt <= 1.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]"] ;
# 231 -> 233 ;
# 234 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"] ;
# 233 -> 234 ;
# 235 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"] ;
# 233 -> 235 ;
# 236 [label="gini = 0.0\nsamples = 20\nvalue = [0, 20]"] ;
# 190 -> 236 ;
# 237 [label="EXTWLINS <= 2.5\ngini = 0.24\nsamples = 458\nvalue = [64, 394]"] ;
# 131 -> 237 ;
# 238 [label="DWLTYPE <= 4.5\ngini = 0.299\nsamples = 235\nvalue = [43, 192]"] ;
# 237 -> 238 ;
# 239 [label="SQFT <= 6.5\ngini = 0.271\nsamples = 210\nvalue = [34, 176]"] ;
# 238 -> 239 ;
# 240 [label="EDUC <= 4.5\ngini = 0.19\nsamples = 113\nvalue = [12, 101]"] ;
# 239 -> 240 ;
# 241 [label="avginc <= 35000.0\ngini = 0.375\nsamples = 40\nvalue = [10, 30]"] ;
# 240 -> 241 ;
# 242 [label="DWLTYPE <= 1.5\ngini = 0.133\nsamples = 14\nvalue = [1, 13]"] ;
# 241 -> 242 ;
# 243 [label="avginc <= 25000.0\ngini = 0.32\nsamples = 5\nvalue = [1, 4]"] ;
# 242 -> 243 ;
# 244 [label="gini = 0.0\nsamples = 3\nvalue = [0, 3]"] ;
# 243 -> 244 ;
# 245 [label="HOHWHT1 <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]"] ;
# 243 -> 245 ;
# 246 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"] ;
# 245 -> 246 ;
# 247 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"] ;
# 245 -> 247 ;
# 248 [label="gini = 0.0\nsamples = 9\nvalue = [0, 9]"] ;
# 242 -> 248 ;
# 249 [label="HOHLAT1 <= 0.5\ngini = 0.453\nsamples = 26\nvalue = [9, 17]"] ;
# 241 -> 249 ;
# 250 [label="ETHNIC <= 1.5\ngini = 0.386\nsamples = 23\nvalue = [6, 17]"] ;
# 249 -> 250 ;
# 251 [label="ACEILINS <= 49.5\ngini = 0.351\nsamples = 22\nvalue = [5, 17]"] ;
# 250 -> 251 ;
# 252 [label="HOHETH <= 2.5\ngini = 0.266\nsamples = 19\nvalue = [3, 16]"] ;
# 251 -> 252 ;
# 253 [label="BUILTYR <= 4.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]"] ;
# 252 -> 253 ;
# 254 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"] ;
# 253 -> 254 ;
# 255 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"] ;
# 253 -> 255 ;
# 256 [label="EXTWLINS <= 1.5\ngini = 0.208\nsamples = 17\nvalue = [2, 15]"] ;
# 252 -> 256 ;
# 257 [label="rescnt <= 1.5\ngini = 0.375\nsamples = 8\nvalue = [2, 6]"] ;
# 256 -> 257 ;
# 258 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"] ;
# 257 -> 258 ;
# 259 [label="rescnt <= 2.5\ngini = 0.245\nsamples = 7\nvalue = [1, 6]"] ;
# 257 -> 259 ;
# 260 [label="gini = 0.0\nsamples = 3\nvalue = [0, 3]"] ;
# 259 -> 260 ;
# 261 [label="rescnt <= 3.5\ngini = 0.375\nsamples = 4\nvalue = [1, 3]"] ;
# 259 -> 261 ;
# 262 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"] ;
# 261 -> 262 ;
# 263 [label="gini = 0.0\nsamples = 3\nvalue = [0, 3]"] ;
# 261 -> 263 ;
# 264 [label="gini = 0.0\nsamples = 9\nvalue = [0, 9]"] ;
# 256 -> 264 ;
# 265 [label="HOHASN1 <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]"] ;
# 251 -> 265 ;
# 266 [label="gini = 0.0\nsamples = 2\nvalue = [2, 0]"] ;
# 265 -> 266 ;
# 267 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"] ;
# 265 -> 267 ;
# 268 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"] ;
# 250 -> 268 ;
# 269 [label="gini = 0.0\nsamples = 3\nvalue = [3, 0]"] ;
# 249 -> 269 ;
# 270 [label="INCOME <= 2.5\ngini = 0.053\nsamples = 73\nvalue = [2, 71]"] ;
# 240 -> 270 ;
# 271 [label="avginc <= 10000.0\ngini = 0.245\nsamples = 7\nvalue = [1, 6]"] ;
# 270 -> 271 ;
# 272 [label="gini = 0.0\nsamples = 4\nvalue = [0, 4]"] ;
# 271 -> 272 ;
# 273 [label="HOHETH <= 3.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]"] ;
# 271 -> 273 ;
# 274 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"] ;
# 273 -> 274 ;
# 275 [label="BUILTYR <= 4.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]"] ;
# 273 -> 275 ;
# 276 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"] ;
# 275 -> 276 ;
# 277 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"] ;
# 275 -> 277 ;
# 278 [label="BUILTYR <= 4.5\ngini = 0.03\nsamples = 66\nvalue = [1, 65]"] ;
# 270 -> 278 ;
# 279 [label="gini = 0.0\nsamples = 54\nvalue = [0, 54]"] ;
# 278 -> 279 ;
# 280 [label="DWLTYPE <= 2.0\ngini = 0.153\nsamples = 12\nvalue = [1, 11]"] ;
# 278 -> 280 ;
# 281 [label="EDUC <= 5.5\ngini = 0.375\nsamples = 4\nvalue = [1, 3]"] ;
# 280 -> 281 ;
# 282 [label="gini = 0.0\nsamples = 3\nvalue = [0, 3]"] ;
# 281 -> 282 ;
# 283 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"] ;
# 281 -> 283 ;
# 284 [label="gini = 0.0\nsamples = 8\nvalue = [0, 8]"] ;
# 280 -> 284 ;
# 285 [label="DWLTYPE <= 1.5\ngini = 0.351\nsamples = 97\nvalue = [22, 75]"] ;
# 239 -> 285 ;
# 286 [label="HOHBLK1 <= 0.5\ngini = 0.323\nsamples = 89\nvalue = [18, 71]"] ;
# 285 -> 286 ;
# 287 [label="BUILTYR <= 3.5\ngini = 0.293\nsamples = 84\nvalue = [15, 69]"] ;
# 286 -> 287 ;
# 288 [label="SQFT <= 7.5\ngini = 0.394\nsamples = 37\nvalue = [10, 27]"] ;
# 287 -> 288 ;
# 289 [label="avginc <= 150000.0\ngini = 0.198\nsamples = 18\nvalue = [2, 16]"] ;
# 288 -> 289 ;
# 290 [label="EDUC <= 3.5\ngini = 0.111\nsamples = 17\nvalue = [1, 16]"] ;
# 289 -> 290 ;
# 291 [label="HOHLAT1 <= 0.5\ngini = 0.32\nsamples = 5\nvalue = [1, 4]"] ;
# 290 -> 291 ;
# 292 [label="NGUTIL <= 50.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]"] ;
# 291 -> 292 ;
# 293 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"] ;
# 292 -> 293 ;
# 294 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"] ;
# 292 -> 294 ;
# 295 [label="gini = 0.0\nsamples = 3\nvalue = [0, 3]"] ;
# 291 -> 295 ;
# 296 [label="gini = 0.0\nsamples = 12\nvalue = [0, 12]"] ;
# 290 -> 296 ;
# 297 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"] ;
# 289 -> 297 ;
# 298 [label="SQFT <= 10.5\ngini = 0.488\nsamples = 19\nvalue = [8, 11]"] ;
# 288 -> 298 ;
# 299 [label="INCOME <= 4.5\ngini = 0.498\nsamples = 15\nvalue = [8, 7]"] ;
# 298 -> 299 ;
# 300 [label="gini = 0.0\nsamples = 2\nvalue = [2, 0]"] ;
# 299 -> 300 ;
# 301 [label="EXTWLINS <= 1.5\ngini = 0.497\nsamples = 13\nvalue = [6, 7]"] ;
# 299 -> 301 ;
# 302 [label="rescnt <= 2.5\ngini = 0.469\nsamples = 8\nvalue = [5, 3]"] ;
# 301 -> 302 ;
# 303 [label="SQFT <= 8.5\ngini = 0.48\nsamples = 5\nvalue = [2, 3]"] ;
# 302 -> 303 ;
# 304 [label="gini = 0.0\nsamples = 2\nvalue = [0, 2]"] ;
# 303 -> 304 ;
# 305 [label="EDUC <= 4.0\ngini = 0.444\nsamples = 3\nvalue = [2, 1]"] ;
# 303 -> 305 ;
# 306 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"] ;
# 305 -> 306 ;
# 307 [label="gini = 0.0\nsamples = 2\nvalue = [2, 0]"] ;
# 305 -> 307 ;
# 308 [label="gini = 0.0\nsamples = 3\nvalue = [3, 0]"] ;
# 302 -> 308 ;
# 309 [label="HOHETH <= 3.0\ngini = 0.32\nsamples = 5\nvalue = [1, 4]"] ;
# 301 -> 309 ;
# 310 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"] ;
# 309 -> 310 ;
# 311 [label="gini = 0.0\nsamples = 4\nvalue = [0, 4]"] ;
# 309 -> 311 ;
# 312 [label="gini = 0.0\nsamples = 4\nvalue = [0, 4]"] ;
# 298 -> 312 ;
# 313 [label="avginc <= 57337.5\ngini = 0.19\nsamples = 47\nvalue = [5, 42]"] ;
# 287 -> 313 ;
# 314 [label="avginc <= 50000.0\ngini = 0.337\nsamples = 14\nvalue = [3, 11]"] ;
# 313 -> 314 ;
# 315 [label="HOHASN1 <= 0.5\ngini = 0.198\nsamples = 9\nvalue = [1, 8]"] ;
# 314 -> 315 ;
# 316 [label="gini = 0.0\nsamples = 8\nvalue = [0, 8]"] ;
# 315 -> 316 ;
# 317 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"] ;
# 315 -> 317 ;
# 318 [label="HOHASN1 <= 0.5\ngini = 0.48\nsamples = 5\nvalue = [2, 3]"] ;
# 314 -> 318 ;
# 319 [label="rescnt <= 3.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]"] ;
# 318 -> 319 ;
# 320 [label="gini = 0.0\nsamples = 2\nvalue = [2, 0]"] ;
# 319 -> 320 ;
# 321 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"] ;
# 319 -> 321 ;
# 322 [label="gini = 0.0\nsamples = 2\nvalue = [0, 2]"] ;
# 318 -> 322 ;
# 323 [label="EDUC <= 5.5\ngini = 0.114\nsamples = 33\nvalue = [2, 31]"] ;
# 313 -> 323 ;
# 324 [label="gini = 0.0\nsamples = 16\nvalue = [0, 16]"] ;
# 323 -> 324 ;
# 325 [label="INCOME <= 54.5\ngini = 0.208\nsamples = 17\nvalue = [2, 15]"] ;
# 323 -> 325 ;
# 326 [label="avginc <= 150000.0\ngini = 0.124\nsamples = 15\nvalue = [1, 14]"] ;
# 325 -> 326 ;
# 327 [label="gini = 0.0\nsamples = 9\nvalue = [0, 9]"] ;
# 326 -> 327 ;
# 328 [label="EXTWLINS <= 1.5\ngini = 0.278\nsamples = 6\nvalue = [1, 5]"] ;
# 326 -> 328 ;
# 329 [label="gini = 0.0\nsamples = 4\nvalue = [0, 4]"] ;
# 328 -> 329 ;
# 330 [label="SQFT <= 7.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]"] ;
# 328 -> 330 ;
# 331 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"] ;
# 330 -> 331 ;
# 332 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"] ;
# 330 -> 332 ;
# 333 [label="rescnt <= 2.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]"] ;
# 325 -> 333 ;
# 334 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"] ;
# 333 -> 334 ;
# 335 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"] ;
# 333 -> 335 ;
# 336 [label="rescnt <= 2.5\ngini = 0.48\nsamples = 5\nvalue = [3, 2]"] ;
# 286 -> 336 ;
# 337 [label="avginc <= 46250.0\ngini = 0.444\nsamples = 3\nvalue = [1, 2]"] ;
# 336 -> 337 ;
# 338 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"] ;
# 337 -> 338 ;
# 339 [label="gini = 0.0\nsamples = 2\nvalue = [0, 2]"] ;
# 337 -> 339 ;
# 340 [label="gini = 0.0\nsamples = 2\nvalue = [2, 0]"] ;
# 336 -> 340 ;
# 341 [label="OWNRENT <= 1.5\ngini = 0.5\nsamples = 8\nvalue = [4, 4]"] ;
# 285 -> 341 ;
# 342 [label="gini = 0.0\nsamples = 3\nvalue = [3, 0]"] ;
# 341 -> 342 ;
# 343 [label="BUILTYR <= 3.5\ngini = 0.32\nsamples = 5\nvalue = [1, 4]"] ;
# 341 -> 343 ;
# 344 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"] ;
# 343 -> 344 ;
# 345 [label="gini = 0.0\nsamples = 4\nvalue = [0, 4]"] ;
# 343 -> 345 ;
# 346 [label="avginc <= 80518.5\ngini = 0.461\nsamples = 25\nvalue = [9, 16]"] ;
# 238 -> 346 ;
# 347 [label="DWLTYPE <= 5.5\ngini = 0.346\nsamples = 18\nvalue = [4, 14]"] ;
# 346 -> 347 ;
# 348 [label="SQFT <= 5.5\ngini = 0.48\nsamples = 5\nvalue = [3, 2]"] ;
# 347 -> 348 ;
# 349 [label="EDUC <= 3.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]"] ;
# 348 -> 349 ;
# 350 [label="gini = 0.0\nsamples = 2\nvalue = [0, 2]"] ;
# 349 -> 350 ;
# 351 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"] ;
# 349 -> 351 ;
# 352 [label="gini = 0.0\nsamples = 2\nvalue = [2, 0]"] ;
# 348 -> 352 ;
# 353 [label="BUILTYR <= 3.5\ngini = 0.142\nsamples = 13\nvalue = [1, 12]"] ;
# 347 -> 353 ;
# 354 [label="gini = 0.0\nsamples = 9\nvalue = [0, 9]"] ;
# 353 -> 354 ;
# 355 [label="SQFT <= 6.0\ngini = 0.375\nsamples = 4\nvalue = [1, 3]"] ;
# 353 -> 355 ;
# 356 [label="gini = 0.0\nsamples = 2\nvalue = [0, 2]"] ;
# 355 -> 356 ;
# 357 [label="SQFT <= 7.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]"] ;
# 355 -> 357 ;
# 358 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"] ;
# 357 -> 358 ;
# 359 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"] ;
# 357 -> 359 ;
# 360 [label="HOHIND1 <= 0.5\ngini = 0.408\nsamples = 7\nvalue = [5, 2]"] ;
# 346 -> 360 ;
# 361 [label="ACEILINS <= 49.0\ngini = 0.278\nsamples = 6\nvalue = [5, 1]"] ;
# 360 -> 361 ;
# 362 [label="gini = 0.0\nsamples = 4\nvalue = [4, 0]"] ;
# 361 -> 362 ;
# 363 [label="EDUC <= 5.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]"] ;
# 361 -> 363 ;
# 364 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"] ;
# 363 -> 364 ;
# 365 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"] ;
# 363 -> 365 ;
# 366 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"] ;
# 360 -> 366 ;
# 367 [label="SQFT <= 1.5\ngini = 0.171\nsamples = 223\nvalue = [21, 202]"] ;
# 237 -> 367 ;
# 368 [label="gini = 0.0\nsamples = 2\nvalue = [2, 0]"] ;
# 367 -> 368 ;
# 369 [label="avginc <= 27950.5\ngini = 0.157\nsamples = 221\nvalue = [19, 202]"] ;
# 367 -> 369 ;
# 370 [label="INCOME <= 8.5\ngini = 0.293\nsamples = 56\nvalue = [10, 46]"] ;
# 369 -> 370 ;
# 371 [label="HOHBLK1 <= 0.5\ngini = 0.215\nsamples = 49\nvalue = [6, 43]"] ;
# 370 -> 371 ;
# 372 [label="OWNRENT <= 1.5\ngini = 0.13\nsamples = 43\nvalue = [3, 40]"] ;
# 371 -> 372 ;
# 373 [label="gini = 0.0\nsamples = 27\nvalue = [0, 27]"] ;
# 372 -> 373 ;
# 374 [label="EDUC <= 3.5\ngini = 0.305\nsamples = 16\nvalue = [3, 13]"] ;
# 372 -> 374 ;
# 375 [label="BUILTYR <= 4.5\ngini = 0.48\nsamples = 5\nvalue = [3, 2]"] ;
# 374 -> 375 ;
# 376 [label="gini = 0.0\nsamples = 3\nvalue = [3, 0]"] ;
# 375 -> 376 ;
# 377 [label="gini = 0.0\nsamples = 2\nvalue = [0, 2]"] ;
# 375 -> 377 ;
# 378 [label="gini = 0.0\nsamples = 11\nvalue = [0, 11]"] ;
# 374 -> 378 ;
# 379 [label="EDUC <= 4.5\ngini = 0.5\nsamples = 6\nvalue = [3, 3]"] ;
# 371 -> 379 ;
# 380 [label="gini = 0.0\nsamples = 3\nvalue = [3, 0]"] ;
# 379 -> 380 ;
# 381 [label="gini = 0.0\nsamples = 3\nvalue = [0, 3]"] ;
# 379 -> 381 ;
# 382 [label="OWNRENT <= 1.5\ngini = 0.49\nsamples = 7\nvalue = [4, 3]"] ;
# 370 -> 382 ;
# 383 [label="gini = 0.0\nsamples = 3\nvalue = [3, 0]"] ;
# 382 -> 383 ;
# 384 [label="INCOME <= 9.5\ngini = 0.375\nsamples = 4\nvalue = [1, 3]"] ;
# 382 -> 384 ;
# 385 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"] ;
# 384 -> 385 ;
# 386 [label="gini = 0.0\nsamples = 3\nvalue = [0, 3]"] ;
# 384 -> 386 ;
# 387 [label="INCOME <= 11.5\ngini = 0.103\nsamples = 165\nvalue = [9, 156]"] ;
# 369 -> 387 ;
# 388 [label="ETHNIC <= 3.5\ngini = 0.049\nsamples = 119\nvalue = [3, 116]"] ;
# 387 -> 388 ;
# 389 [label="cecfast <= 4.5\ngini = 0.034\nsamples = 116\nvalue = [2, 114]"] ;
# 388 -> 389 ;
# 390 [label="SQFT <= 7.5\ngini = 0.153\nsamples = 12\nvalue = [1, 11]"] ;
# 389 -> 390 ;
# 391 [label="gini = 0.0\nsamples = 9\nvalue = [0, 9]"] ;
# 390 -> 391 ;
# 392 [label="DWLTYPE <= 2.0\ngini = 0.444\nsamples = 3\nvalue = [1, 2]"] ;
# 390 -> 392 ;
# 393 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"] ;
# 392 -> 393 ;
# 394 [label="gini = 0.0\nsamples = 2\nvalue = [0, 2]"] ;
# 392 -> 394 ;
# 395 [label="NGUTIL <= 98.0\ngini = 0.019\nsamples = 104\nvalue = [1, 103]"] ;
# 389 -> 395 ;
# 396 [label="gini = 0.0\nsamples = 93\nvalue = [0, 93]"] ;
# 395 -> 396 ;
# 397 [label="avginc <= 106250.0\ngini = 0.165\nsamples = 11\nvalue = [1, 10]"] ;
# 395 -> 397 ;
# 398 [label="gini = 0.0\nsamples = 8\nvalue = [0, 8]"] ;
# 397 -> 398 ;
# 399 [label="OWNRENT <= 1.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]"] ;
# 397 -> 399 ;
# 400 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"] ;
# 399 -> 400 ;
# 401 [label="gini = 0.0\nsamples = 2\nvalue = [0, 2]"] ;
# 399 -> 401 ;
# 402 [label="EDUC <= 4.0\ngini = 0.444\nsamples = 3\nvalue = [1, 2]"] ;
# 388 -> 402 ;
# 403 [label="gini = 0.0\nsamples = 2\nvalue = [0, 2]"] ;
# 402 -> 403 ;
# 404 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"] ;
# 402 -> 404 ;
# 405 [label="SQFT <= 6.5\ngini = 0.227\nsamples = 46\nvalue = [6, 40]"] ;
# 387 -> 405 ;
# 406 [label="gini = 0.0\nsamples = 18\nvalue = [0, 18]"] ;
# 405 -> 406 ;
# 407 [label="EDUC <= 3.5\ngini = 0.337\nsamples = 28\nvalue = [6, 22]"] ;
# 405 -> 407 ;
# 408 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"] ;
# 407 -> 408 ;
# 409 [label="SQFT <= 8.5\ngini = 0.302\nsamples = 27\nvalue = [5, 22]"] ;
# 407 -> 409 ;
# 410 [label="ACEILINS <= 49.5\ngini = 0.401\nsamples = 18\nvalue = [5, 13]"] ;
# 409 -> 410 ;
# 411 [label="avginc <= 63424.5\ngini = 0.32\nsamples = 15\nvalue = [3, 12]"] ;
# 410 -> 411 ;
# 412 [label="BUILTYR <= 3.5\ngini = 0.5\nsamples = 4\nvalue = [2, 2]"] ;
# 411 -> 412 ;
# 413 [label="gini = 0.0\nsamples = 2\nvalue = [2, 0]"] ;
# 412 -> 413 ;
# 414 [label="gini = 0.0\nsamples = 2\nvalue = [0, 2]"] ;
# 412 -> 414 ;
# 415 [label="rescnt <= 3.5\ngini = 0.165\nsamples = 11\nvalue = [1, 10]"] ;
# 411 -> 415 ;
# 416 [label="gini = 0.0\nsamples = 6\nvalue = [0, 6]"] ;
# 415 -> 416 ;
# 417 [label="rescnt <= 4.5\ngini = 0.32\nsamples = 5\nvalue = [1, 4]"] ;
# 415 -> 417 ;
# 418 [label="avginc <= 127657.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]"] ;
# 417 -> 418 ;
# 419 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"] ;
# 418 -> 419 ;
# 420 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"] ;
# 418 -> 420 ;
# 421 [label="gini = 0.0\nsamples = 3\nvalue = [0, 3]"] ;
# 417 -> 421 ;
# 422 [label="HOHWHT1 <= 49.0\ngini = 0.444\nsamples = 3\nvalue = [2, 1]"] ;
# 410 -> 422 ;
# 423 [label="gini = 0.0\nsamples = 2\nvalue = [2, 0]"] ;
# 422 -> 423 ;
# 424 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"] ;
# 422 -> 424 ;
# 425 [label="gini = 0.0\nsamples = 9\nvalue = [0, 9]"] ;
# 409 -> 425 ;
# 426 [label="CZT24 <= 4.5\ngini = 0.399\nsamples = 2042\nvalue = [561, 1481]"] ;
# 2 -> 426 ;
# 427 [label="avginc <= 155026.5\ngini = 0.485\nsamples = 292\nvalue = [121, 171]"] ;
# 426 -> 427 ;
# 428 [label="DWLTYPE <= 3.5\ngini = 0.472\nsamples = 251\nvalue = [96, 155]"] ;
# 427 -> 428 ;
# 429 [label="rescnt <= 7.5\ngini = 0.486\nsamples = 200\nvalue = [83, 117]"] ;
# 428 -> 429 ;
# 430 [label="BUILTYR <= 3.5\ngini = 0.482\nsamples = 197\nvalue = [80, 117]"] ;
# 429 -> 430 ;
# 431 [label="EXTWLINS <= 1.5\ngini = 0.444\nsamples = 99\nvalue = [33, 66]"] ;
# 430 -> 431 ;
# 432 [label="avginc <= 27500.0\ngini = 0.499\nsamples = 31\nvalue = [16, 15]"] ;
# 431 -> 432 ;
# 433 [label="gini = 0.0\nsamples = 3\nvalue = [0, 3]"] ;
# 432 -> 433 ;
# 434 [label="SQFT <= 8.5\ngini = 0.49\nsamples = 28\nvalue = [16, 12]"] ;
# 432 -> 434 ;
# 435 [label="DWLTYPE <= 1.5\ngini = 0.454\nsamples = 23\nvalue = [15, 8]"] ;
# 434 -> 435 ;
# 436 [label="rescnt <= 3.5\ngini = 0.434\nsamples = 22\nvalue = [15, 7]"] ;
# 435 -> 436 ;
# 437 [label="HOHLAT1 <= 0.5\ngini = 0.484\nsamples = 17\nvalue = [10, 7]"] ;
# 436 -> 437 ;
# 438 [label="NGUTIL <= 2.0\ngini = 0.5\nsamples = 14\nvalue = [7, 7]"] ;
# 437 -> 438 ;
# 439 [label="avginc <= 41250.0\ngini = 0.486\nsamples = 12\nvalue = [5, 7]"] ;
# 438 -> 439 ;
# 440 [label="gini = 0.0\nsamples = 2\nvalue = [0, 2]"] ;
# 439 -> 440 ;
# 441 [label="avginc <= 63587.5\ngini = 0.5\nsamples = 10\nvalue = [5, 5]"] ;
# 439 -> 441 ;
# 442 [label="gini = 0.0\nsamples = 3\nvalue = [3, 0]"] ;
# 441 -> 442 ;
# 443 [label="avginc <= 106250.0\ngini = 0.408\nsamples = 7\nvalue = [2, 5]"] ;
# 441 -> 443 ;
# 444 [label="gini = 0.0\nsamples = 2\nvalue = [0, 2]"] ;
# 443 -> 444 ;
# 445 [label="EDUC <= 4.0\ngini = 0.48\nsamples = 5\nvalue = [2, 3]"] ;
# 443 -> 445 ;
# 446 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"] ;
# 445 -> 446 ;
# 447 [label="BUILTYR <= 2.0\ngini = 0.5\nsamples = 4\nvalue = [2, 2]"] ;
# 445 -> 447 ;
# 448 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"] ;
# 447 -> 448 ;
# 449 [label="rescnt <= 2.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]"] ;
# 447 -> 449 ;
# 450 [label="HOHASN1 <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]"] ;
# 449 -> 450 ;
# 451 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"] ;
# 450 -> 451 ;
# 452 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"] ;
# 450 -> 452 ;
# 453 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"] ;
# 449 -> 453 ;
# 454 [label="gini = 0.0\nsamples = 2\nvalue = [2, 0]"] ;
# 438 -> 454 ;
# 455 [label="gini = 0.0\nsamples = 3\nvalue = [3, 0]"] ;
# 437 -> 455 ;
# 456 [label="gini = 0.0\nsamples = 5\nvalue = [5, 0]"] ;
# 436 -> 456 ;
# 457 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"] ;
# 435 -> 457 ;
# 458 [label="EDUC <= 5.5\ngini = 0.32\nsamples = 5\nvalue = [1, 4]"] ;
# 434 -> 458 ;
# 459 [label="gini = 0.0\nsamples = 3\nvalue = [0, 3]"] ;
# 458 -> 459 ;
# 460 [label="BUILTYR <= 2.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]"] ;
# 458 -> 460 ;
# 461 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"] ;
# 460 -> 461 ;
# 462 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"] ;
# 460 -> 462 ;
# 463 [label="rescnt <= 2.5\ngini = 0.375\nsamples = 68\nvalue = [17, 51]"] ;
# 431 -> 463 ;
# 464 [label="avginc <= 61250.0\ngini = 0.25\nsamples = 41\nvalue = [6, 35]"] ;
# 463 -> 464 ;
# 465 [label="ACEILINS <= 1.5\ngini = 0.083\nsamples = 23\nvalue = [1, 22]"] ;
# 464 -> 465 ;
# 466 [label="gini = 0.0\nsamples = 16\nvalue = [0, 16]"] ;
# 465 -> 466 ;
# 467 [label="rescnt <= 1.5\ngini = 0.245\nsamples = 7\nvalue = [1, 6]"] ;
# 465 -> 467 ;
# 468 [label="gini = 0.0\nsamples = 5\nvalue = [0, 5]"] ;
# 467 -> 468 ;
# 469 [label="EDUC <= 5.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]"] ;
# 467 -> 469 ;
# 470 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"] ;
# 469 -> 470 ;
# 471 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"] ;
# 469 -> 471 ;
# 472 [label="DWLTYPE <= 1.5\ngini = 0.401\nsamples = 18\nvalue = [5, 13]"] ;
# 464 -> 472 ;
# 473 [label="rescnt <= 1.5\ngini = 0.305\nsamples = 16\nvalue = [3, 13]"] ;
# 472 -> 473 ;
# 474 [label="HOHASN1 <= 0.5\ngini = 0.49\nsamples = 7\nvalue = [3, 4]"] ;
# 473 -> 474 ;
# 475 [label="HOHWHT1 <= 0.5\ngini = 0.48\nsamples = 5\nvalue = [3, 2]"] ;
# 474 -> 475 ;
# 476 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"] ;
# 475 -> 476 ;
# 477 [label="EXTWLINS <= 2.5\ngini = 0.5\nsamples = 4\nvalue = [2, 2]"] ;
# 475 -> 477 ;
# 478 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"] ;
# 477 -> 478 ;
# 479 [label="avginc <= 81955.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]"] ;
# 477 -> 479 ;
# 480 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"] ;
# 479 -> 480 ;
# 481 [label="SQFT <= 6.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]"] ;
# 479 -> 481 ;
# 482 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"] ;
# 481 -> 482 ;
# 483 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"] ;
# 481 -> 483 ;
# 484 [label="gini = 0.0\nsamples = 2\nvalue = [0, 2]"] ;
# 474 -> 484 ;
# 485 [label="gini = 0.0\nsamples = 9\nvalue = [0, 9]"] ;
# 473 -> 485 ;
# 486 [label="gini = 0.0\nsamples = 2\nvalue = [2, 0]"] ;
# 472 -> 486 ;
# 487 [label="INCOME <= 2.5\ngini = 0.483\nsamples = 27\nvalue = [11, 16]"] ;
# 463 -> 487 ;
# 488 [label="gini = 0.0\nsamples = 3\nvalue = [3, 0]"] ;
# 487 -> 488 ;
# 489 [label="EXTWLINS <= 2.5\ngini = 0.444\nsamples = 24\nvalue = [8, 16]"] ;
# 487 -> 489 ;
# 490 [label="INCOME <= 10.5\ngini = 0.305\nsamples = 16\nvalue = [3, 13]"] ;
# 489 -> 490 ;
# 491 [label="gini = 0.0\nsamples = 7\nvalue = [0, 7]"] ;
# 490 -> 491 ;
# 492 [label="HOHWHT1 <= 0.5\ngini = 0.444\nsamples = 9\nvalue = [3, 6]"] ;
# 490 -> 492 ;
# 493 [label="rescnt <= 3.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]"] ;
# 492 -> 493 ;
# 494 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"] ;
# 493 -> 494 ;
# 495 [label="gini = 0.0\nsamples = 2\nvalue = [2, 0]"] ;
# 493 -> 495 ;
# 496 [label="SQFT <= 7.5\ngini = 0.278\nsamples = 6\nvalue = [1, 5]"] ;
# 492 -> 496 ;
# 497 [label="gini = 0.0\nsamples = 4\nvalue = [0, 4]"] ;
# 496 -> 497 ;
# 498 [label="HOHIND1 <= 48.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]"] ;
# 496 -> 498 ;
# 499 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"] ;
# 498 -> 499 ;
# 500 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"] ;
# 498 -> 500 ;
# 501 [label="SQFT <= 6.5\ngini = 0.469\nsamples = 8\nvalue = [5, 3]"] ;
# 489 -> 501 ;
# 502 [label="SQFT <= 5.5\ngini = 0.48\nsamples = 5\nvalue = [2, 3]"] ;
# 501 -> 502 ;
# 503 [label="HOHETH <= 5.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]"] ;
# 502 -> 503 ;
# 504 [label="gini = 0.0\nsamples = 2\nvalue = [2, 0]"] ;
# 503 -> 504 ;
# 505 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"] ;
# 503 -> 505 ;
# 506 [label="gini = 0.0\nsamples = 2\nvalue = [0, 2]"] ;
# 502 -> 506 ;
# 507 [label="gini = 0.0\nsamples = 3\nvalue = [3, 0]"] ;
# 501 -> 507 ;
# 508 [label="NGUTIL <= 2.0\ngini = 0.499\nsamples = 98\nvalue = [47, 51]"] ;
# 430 -> 508 ;
# 509 [label="rescnt <= 2.5\ngini = 0.499\nsamples = 91\nvalue = [47, 44]"] ;
# 508 -> 509 ;
# 510 [label="EXTWLINS <= 1.5\ngini = 0.47\nsamples = 45\nvalue = [28, 17]"] ;
# 509 -> 510 ;
# 511 [label="BUILTYR <= 4.5\ngini = 0.475\nsamples = 18\nvalue = [7, 11]"] ;
# 510 -> 511 ;
# 512 [label="INCOME <= 6.0\ngini = 0.48\nsamples = 10\nvalue = [6, 4]"] ;
# 511 -> 512 ;
# 513 [label="gini = 0.0\nsamples = 2\nvalue = [0, 2]"] ;
# 512 -> 513 ;
# 514 [label="INCOME <= 10.5\ngini = 0.375\nsamples = 8\nvalue = [6, 2]"] ;
# 512 -> 514 ;
# 515 [label="avginc <= 77500.0\ngini = 0.48\nsamples = 5\nvalue = [3, 2]"] ;
# 514 -> 515 ;
# 516 [label="EDUC <= 4.5\ngini = 0.375\nsamples = 4\nvalue = [3, 1]"] ;
# 515 -> 516 ;
# 517 [label="gini = 0.5\nsamples = 2\nvalue = [1, 1]"] ;
# 516 -> 517 ;
# 518 [label="gini = 0.0\nsamples = 2\nvalue = [2, 0]"] ;
# 516 -> 518 ;
# 519 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"] ;
# 515 -> 519 ;
# 520 [label="gini = 0.0\nsamples = 3\nvalue = [3, 0]"] ;
# 514 -> 520 ;
# 521 [label="EDUC <= 4.5\ngini = 0.219\nsamples = 8\nvalue = [1, 7]"] ;
# 511 -> 521 ;
# 522 [label="INCOME <= 6.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]"] ;
# 521 -> 522 ;
# 523 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"] ;
# 522 -> 523 ;
# 524 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"] ;
# 522 -> 524 ;
# 525 [label="gini = 0.0\nsamples = 6\nvalue = [0, 6]"] ;
# 521 -> 525 ;
# 526 [label="SQFT <= 5.5\ngini = 0.346\nsamples = 27\nvalue = [21, 6]"] ;
# 510 -> 526 ;
# 527 [label="gini = 0.0\nsamples = 9\nvalue = [9, 0]"] ;
# 526 -> 527 ;
# 528 [label="avginc <= 68338.0\ngini = 0.444\nsamples = 18\nvalue = [12, 6]"] ;
# 526 -> 528 ;
# 529 [label="EDUC <= 4.5\ngini = 0.49\nsamples = 7\nvalue = [3, 4]"] ;
# 528 -> 529 ;
# 530 [label="gini = 0.0\nsamples = 2\nvalue = [0, 2]"] ;
# 529 -> 530 ;
# 531 [label="EDUC <= 5.5\ngini = 0.48\nsamples = 5\nvalue = [3, 2]"] ;
# 529 -> 531 ;
# 532 [label="gini = 0.0\nsamples = 2\nvalue = [2, 0]"] ;
# 531 -> 532 ;
# 533 [label="HOHOTH1 <= 48.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]"] ;
# 531 -> 533 ;
# 534 [label="gini = 0.0\nsamples = 2\nvalue = [0, 2]"] ;
# 533 -> 534 ;
# 535 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"] ;
# 533 -> 535 ;
# 536 [label="BUILTYR <= 4.5\ngini = 0.298\nsamples = 11\nvalue = [9, 2]"] ;
# 528 -> 536 ;
# 537 [label="SQFT <= 6.5\ngini = 0.219\nsamples = 8\nvalue = [7, 1]"] ;
# 536 -> 537 ;
# 538 [label="EXTWLINS <= 2.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]"] ;
# 537 -> 538 ;
# 539 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"] ;
# 538 -> 539 ;
# 540 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"] ;
# 538 -> 540 ;
# 541 [label="gini = 0.0\nsamples = 6\nvalue = [6, 0]"] ;
# 537 -> 541 ;
# 542 [label="SQFT <= 7.0\ngini = 0.444\nsamples = 3\nvalue = [2, 1]"] ;
# 536 -> 542 ;
# 543 [label="gini = 0.0\nsamples = 2\nvalue = [2, 0]"] ;
# 542 -> 543 ;
# 544 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"] ;
# 542 -> 544 ;
# 545 [label="DWLTYPE <= 1.5\ngini = 0.485\nsamples = 46\nvalue = [19, 27]"] ;
# 509 -> 545 ;
# 546 [label="rescnt <= 6.5\ngini = 0.499\nsamples = 38\nvalue = [18, 20]"] ;
# 545 -> 546 ;
# 547 [label="avginc <= 30000.0\ngini = 0.5\nsamples = 35\nvalue = [18, 17]"] ;
# 546 -> 547 ;
# 548 [label="EDUC <= 51.0\ngini = 0.278\nsamples = 6\nvalue = [1, 5]"] ;
# 547 -> 548 ;
# 549 [label="gini = 0.0\nsamples = 5\nvalue = [0, 5]"] ;
# 548 -> 549 ;
# 550 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"] ;
# 548 -> 550 ;
# 551 [label="INCOME <= 6.5\ngini = 0.485\nsamples = 29\nvalue = [17, 12]"] ;
# 547 -> 551 ;
# 552 [label="gini = 0.0\nsamples = 5\nvalue = [5, 0]"] ;
# 551 -> 552 ;
# 553 [label="EDUC <= 5.5\ngini = 0.5\nsamples = 24\nvalue = [12, 12]"] ;
# 551 -> 553 ;
# 554 [label="HOHOTH1 <= 0.5\ngini = 0.459\nsamples = 14\nvalue = [9, 5]"] ;
# 553 -> 554 ;
# 555 [label="HOHLAT1 <= 0.5\ngini = 0.375\nsamples = 12\nvalue = [9, 3]"] ;
# 554 -> 555 ;
# 556 [label="OWNRENT <= 1.5\ngini = 0.198\nsamples = 9\nvalue = [8, 1]"] ;
# 555 -> 556 ;
# 557 [label="gini = 0.0\nsamples = 7\nvalue = [7, 0]"] ;
# 556 -> 557 ;
# 558 [label="ETHNIC <= 1.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]"] ;
# 556 -> 558 ;
# 559 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"] ;
# 558 -> 559 ;
# 560 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"] ;
# 558 -> 560 ;
# 561 [label="rescnt <= 3.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]"] ;
# 555 -> 561 ;
# 562 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"] ;
# 561 -> 562 ;
# 563 [label="gini = 0.0\nsamples = 2\nvalue = [0, 2]"] ;
# 561 -> 563 ;
# 564 [label="gini = 0.0\nsamples = 2\nvalue = [0, 2]"] ;
# 554 -> 564 ;
# 565 [label="OWNRENT <= 1.5\ngini = 0.42\nsamples = 10\nvalue = [3, 7]"] ;
# 553 -> 565 ;
# 566 [label="rescnt <= 3.5\ngini = 0.346\nsamples = 9\nvalue = [2, 7]"] ;
# 565 -> 566 ;
# 567 [label="avginc <= 66250.0\ngini = 0.5\nsamples = 4\nvalue = [2, 2]"] ;
# 566 -> 567 ;
# 568 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"] ;
# 567 -> 568 ;
# 569 [label="SQFT <= 7.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]"] ;
# 567 -> 569 ;
# 570 [label="gini = 0.0\nsamples = 2\nvalue = [2, 0]"] ;
# 569 -> 570 ;
# 571 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"] ;
# 569 -> 571 ;
# 572 [label="gini = 0.0\nsamples = 5\nvalue = [0, 5]"] ;
# 566 -> 572 ;
# 573 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"] ;
# 565 -> 573 ;
# 574 [label="gini = 0.0\nsamples = 3\nvalue = [0, 3]"] ;
# 546 -> 574 ;
# 575 [label="HOHLAT1 <= 49.0\ngini = 0.219\nsamples = 8\nvalue = [1, 7]"] ;
# 545 -> 575 ;
# 576 [label="gini = 0.0\nsamples = 7\nvalue = [0, 7]"] ;
# 575 -> 576 ;
# 577 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"] ;
# 575 -> 577 ;
# 578 [label="gini = 0.0\nsamples = 7\nvalue = [0, 7]"] ;
# 508 -> 578 ;
# 579 [label="gini = 0.0\nsamples = 3\nvalue = [3, 0]"] ;
# 429 -> 579 ;
# 580 [label="HOHOTH1 <= 0.5\ngini = 0.38\nsamples = 51\nvalue = [13, 38]"] ;
# 428 -> 580 ;
# 581 [label="DWLTYPE <= 51.5\ngini = 0.308\nsamples = 42\nvalue = [8, 34]"] ;
# 580 -> 581 ;
# 582 [label="ETHNIC <= 2.5\ngini = 0.204\nsamples = 26\nvalue = [3, 23]"] ;
# 581 -> 582 ;
# 583 [label="avginc <= 106250.0\ngini = 0.153\nsamples = 24\nvalue = [2, 22]"] ;
# 582 -> 583 ;
# 584 [label="ETHNIC <= 1.5\ngini = 0.087\nsamples = 22\nvalue = [1, 21]"] ;
# 583 -> 584 ;
# 585 [label="gini = 0.0\nsamples = 17\nvalue = [0, 17]"] ;
# 584 -> 585 ;
# 586 [label="BUILTYR <= 3.5\ngini = 0.32\nsamples = 5\nvalue = [1, 4]"] ;
# 584 -> 586 ;
# 587 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"] ;
# 586 -> 587 ;
# 588 [label="gini = 0.0\nsamples = 4\nvalue = [0, 4]"] ;
# 586 -> 588 ;
# 589 [label="EDUC <= 5.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]"] ;
# 583 -> 589 ;
# 590 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"] ;
# 589 -> 590 ;
# 591 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"] ;
# 589 -> 591 ;
# 592 [label="rescnt <= 4.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]"] ;
# 582 -> 592 ;
# 593 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"] ;
# 592 -> 593 ;
# 594 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"] ;
# 592 -> 594 ;
# 595 [label="avginc <= 57337.5\ngini = 0.43\nsamples = 16\nvalue = [5, 11]"] ;
# 581 -> 595 ;
# 596 [label="BUILTYR <= 2.5\ngini = 0.5\nsamples = 10\nvalue = [5, 5]"] ;
# 595 -> 596 ;
# 597 [label="gini = 0.0\nsamples = 3\nvalue = [0, 3]"] ;
# 596 -> 597 ;
# 598 [label="SQFT <= 4.5\ngini = 0.408\nsamples = 7\nvalue = [5, 2]"] ;
# 596 -> 598 ;
# 599 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"] ;
# 598 -> 599 ;
# 600 [label="SQFT <= 53.5\ngini = 0.278\nsamples = 6\nvalue = [5, 1]"] ;
# 598 -> 600 ;
# 601 [label="gini = 0.0\nsamples = 5\nvalue = [5, 0]"] ;
# 600 -> 601 ;
# 602 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"] ;
# 600 -> 602 ;
# 603 [label="gini = 0.0\nsamples = 6\nvalue = [0, 6]"] ;
# 595 -> 603 ;
# 604 [label="ACEILINS <= 1.5\ngini = 0.494\nsamples = 9\nvalue = [5, 4]"] ;
# 580 -> 604 ;
# 605 [label="avginc <= 55081.0\ngini = 0.375\nsamples = 4\nvalue = [1, 3]"] ;
# 604 -> 605 ;
# 606 [label="gini = 0.0\nsamples = 3\nvalue = [0, 3]"] ;
# 605 -> 606 ;
# 607 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"] ;
# 605 -> 607 ;
# 608 [label="BUILTYR <= 2.5\ngini = 0.32\nsamples = 5\nvalue = [4, 1]"] ;
# 604 -> 608 ;
# 609 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"] ;
# 608 -> 609 ;
# 610 [label="gini = 0.0\nsamples = 4\nvalue = [4, 0]"] ;
# 608 -> 610 ;
# 611 [label="EXTWLINS <= 2.5\ngini = 0.476\nsamples = 41\nvalue = [25, 16]"] ;
# 427 -> 611 ;
# 612 [label="SQFT <= 9.5\ngini = 0.5\nsamples = 28\nvalue = [14, 14]"] ;
# 611 -> 612 ;
# 613 [label="EDUC <= 5.5\ngini = 0.483\nsamples = 22\nvalue = [9, 13]"] ;
# 612 -> 613 ;
# 614 [label="SQFT <= 8.5\ngini = 0.32\nsamples = 10\nvalue = [2, 8]"] ;
# ...
# 6658 [label="HOHBLK1 <= 0.5\ngini = 0.142\nsamples = 13\nvalue = [1, 12]"] ;
# 6654 -> 6658 ;
# 6659 [label="gini = 0.0\nsamples = 11\nvalue = [0, 11]"] ;
# 6658 -> 6659 ;
# 6660 [label="HOHBLK1 <= 49.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]"] ;
# 6658 -> 6660 ;
# 6661 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"] ;
# 6660 -> 6661 ;
# 6662 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"] ;
# 6660 -> 6662 ;
# 6663 [label="gini = 0.0\nsamples = 7\nvalue = [0, 7]"] ;
# 6617 -> 6663 ;
# 6664 [label="NGUTIL <= 3.5\ngini = 0.331\nsamples = 397\nvalue = [314, 83]"] ;
# 6488 -> 6664 ;
# 6665 [label="SQFT <= 54.0\ngini = 0.279\nsamples = 275\nvalue = [229, 46]"] ;
# 6664 -> 6665 ;
# 6666 [label="CZT24 <= 15.5\ngini = 0.202\nsamples = 158\nvalue = [140, 18]"] ;
# 6665 -> 6666 ;
# 6667 [label="avginc <= 23115.5\ngini = 0.164\nsamples = 144\nvalue = [131, 13]"] ;
# 6666 -> 6667 ;
# 6668 [label="SQFT <= 1.5\ngini = 0.274\nsamples = 61\nvalue = [51, 10]"] ;
# 6667 -> 6668 ;
# 6669 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"] ;
# 6668 -> 6669 ;
# 6670 [label="NGUTIL <= 1.5\ngini = 0.255\nsamples = 60\nvalue = [51, 9]"] ;
# 6668 -> 6670 ;
# 6671 [label="rescnt <= 1.5\ngini = 0.074\nsamples = 26\nvalue = [25, 1]"] ;
# 6670 -> 6671 ;
# 6672 [label="EDUC <= 3.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]"] ;
# 6671 -> 6672 ;
# 6673 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"] ;
# 6672 -> 6673 ;
# 6674 [label="gini = 0.0\nsamples = 2\nvalue = [2, 0]"] ;
# 6672 -> 6674 ;
# 6675 [label="gini = 0.0\nsamples = 23\nvalue = [23, 0]"] ;
# 6671 -> 6675 ;
# 6676 [label="rescnt <= 5.0\ngini = 0.36\nsamples = 34\nvalue = [26, 8]"] ;
# 6670 -> 6676 ;
# 6677 [label="ACEILINS <= 49.5\ngini = 0.305\nsamples = 32\nvalue = [26, 6]"] ;
# 6676 -> 6677 ;
# 6678 [label="CZT24 <= 14.5\ngini = 0.375\nsamples = 24\nvalue = [18, 6]"] ;
# 6677 -> 6678 ;
# 6679 [label="CZT24 <= 13.5\ngini = 0.42\nsamples = 20\nvalue = [14, 6]"] ;
# 6678 -> 6679 ;
# 6680 [label="INCOME <= 2.5\ngini = 0.388\nsamples = 19\nvalue = [14, 5]"] ;
# 6679 -> 6680 ;
# 6681 [label="avginc <= 10000.0\ngini = 0.278\nsamples = 12\nvalue = [10, 2]"] ;
# 6680 -> 6681 ;
# 6682 [label="gini = 0.0\nsamples = 4\nvalue = [4, 0]"] ;
# 6681 -> 6682 ;
# 6683 [label="EDUC <= 1.5\ngini = 0.375\nsamples = 8\nvalue = [6, 2]"] ;
# 6681 -> 6683 ;
# 6684 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"] ;
# 6683 -> 6684 ;
# 6685 [label="SQFT <= 6.5\ngini = 0.245\nsamples = 7\nvalue = [6, 1]"] ;
# 6683 -> 6685 ;
# 6686 [label="gini = 0.0\nsamples = 5\nvalue = [5, 0]"] ;
# 6685 -> 6686 ;
# 6687 [label="CZT24 <= 11.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]"] ;
# 6685 -> 6687 ;
# 6688 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"] ;
# 6687 -> 6688 ;
# 6689 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"] ;
# 6687 -> 6689 ;
# 6690 [label="ETHNIC <= 2.5\ngini = 0.49\nsamples = 7\nvalue = [4, 3]"] ;
# 6680 -> 6690 ;
# 6691 [label="SQFT <= 6.0\ngini = 0.375\nsamples = 4\nvalue = [1, 3]"] ;
# 6690 -> 6691 ;
# 6692 [label="gini = 0.0\nsamples = 3\nvalue = [0, 3]"] ;
# 6691 -> 6692 ;
# 6693 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"] ;
# 6691 -> 6693 ;
# 6694 [label="gini = 0.0\nsamples = 3\nvalue = [3, 0]"] ;
# 6690 -> 6694 ;
# 6695 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"] ;
# 6679 -> 6695 ;
# 6696 [label="gini = 0.0\nsamples = 4\nvalue = [4, 0]"] ;
# 6678 -> 6696 ;
# 6697 [label="gini = 0.0\nsamples = 8\nvalue = [8, 0]"] ;
# 6677 -> 6697 ;
# 6698 [label="gini = 0.0\nsamples = 2\nvalue = [0, 2]"] ;
# 6676 -> 6698 ;
# 6699 [label="rescnt <= 1.5\ngini = 0.07\nsamples = 83\nvalue = [80, 3]"] ;
# 6667 -> 6699 ;
# 6700 [label="INCOME <= 54.0\ngini = 0.245\nsamples = 14\nvalue = [12, 2]"] ;
# 6699 -> 6700 ;
# 6701 [label="HOHLAT1 <= 0.5\ngini = 0.153\nsamples = 12\nvalue = [11, 1]"] ;
# 6700 -> 6701 ;
# 6702 [label="gini = 0.0\nsamples = 10\nvalue = [10, 0]"] ;
# 6701 -> 6702 ;
# 6703 [label="EDUC <= 4.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]"] ;
# 6701 -> 6703 ;
# 6704 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"] ;
# 6703 -> 6704 ;
# 6705 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"] ;
# 6703 -> 6705 ;
# 6706 [label="avginc <= 31531.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]"] ;
# 6700 -> 6706 ;
# 6707 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"] ;
# 6706 -> 6707 ;
# 6708 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"] ;
# 6706 -> 6708 ;
# 6709 [label="avginc <= 106250.0\ngini = 0.029\nsamples = 69\nvalue = [68, 1]"] ;
# 6699 -> 6709 ;
# 6710 [label="gini = 0.0\nsamples = 54\nvalue = [54, 0]"] ;
# 6709 -> 6710 ;
# 6711 [label="INCOME <= 11.5\ngini = 0.124\nsamples = 15\nvalue = [14, 1]"] ;
# 6709 -> 6711 ;
# 6712 [label="rescnt <= 2.5\ngini = 0.32\nsamples = 5\nvalue = [4, 1]"] ;
# 6711 -> 6712 ;
# 6713 [label="SQFT <= 8.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]"] ;
# 6712 -> 6713 ;
# 6714 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"] ;
# 6713 -> 6714 ;
# 6715 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"] ;
# 6713 -> 6715 ;
# 6716 [label="gini = 0.0\nsamples = 3\nvalue = [3, 0]"] ;
# 6712 -> 6716 ;
# 6717 [label="gini = 0.0\nsamples = 10\nvalue = [10, 0]"] ;
# 6711 -> 6717 ;
# 6718 [label="HOHBLK1 <= 48.5\ngini = 0.459\nsamples = 14\nvalue = [9, 5]"] ;
# 6666 -> 6718 ;
# 6719 [label="EDUC <= 5.5\ngini = 0.375\nsamples = 12\nvalue = [9, 3]"] ;
# 6718 -> 6719 ;
# 6720 [label="cecfast <= 8.0\ngini = 0.298\nsamples = 11\nvalue = [9, 2]"] ;
# 6719 -> 6720 ;
# 6721 [label="NGUTIL <= 2.0\ngini = 0.48\nsamples = 5\nvalue = [3, 2]"] ;
# 6720 -> 6721 ;
# 6722 [label="gini = 0.0\nsamples = 3\nvalue = [3, 0]"] ;
# 6721 -> 6722 ;
# 6723 [label="gini = 0.0\nsamples = 2\nvalue = [0, 2]"] ;
# 6721 -> 6723 ;
# 6724 [label="gini = 0.0\nsamples = 6\nvalue = [6, 0]"] ;
# 6720 -> 6724 ;
# 6725 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"] ;
# 6719 -> 6725 ;
# 6726 [label="gini = 0.0\nsamples = 2\nvalue = [0, 2]"] ;
# 6718 -> 6726 ;
# 6727 [label="rescnt <= 2.5\ngini = 0.364\nsamples = 117\nvalue = [89, 28]"] ;
# 6665 -> 6727 ;
# 6728 [label="EDUC <= 3.5\ngini = 0.231\nsamples = 60\nvalue = [52, 8]"] ;
# 6727 -> 6728 ;
# 6729 [label="DWLTYPE <= 1.5\ngini = 0.071\nsamples = 27\nvalue = [26, 1]"] ;
# 6728 -> 6729 ;
# 6730 [label="ACEILINS <= 49.5\ngini = 0.32\nsamples = 5\nvalue = [4, 1]"] ;
# 6729 -> 6730 ;
# 6731 [label="cecfast <= 6.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]"] ;
# 6730 -> 6731 ;
# 6732 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"] ;
# 6731 -> 6732 ;
# 6733 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"] ;
# 6731 -> 6733 ;
# 6734 [label="gini = 0.0\nsamples = 3\nvalue = [3, 0]"] ;
# 6730 -> 6734 ;
# 6735 [label="gini = 0.0\nsamples = 22\nvalue = [22, 0]"] ;
# 6729 -> 6735 ;
# 6736 [label="INCOME <= 6.5\ngini = 0.334\nsamples = 33\nvalue = [26, 7]"] ;
# 6728 -> 6736 ;
# 6737 [label="CZT24 <= 10.5\ngini = 0.457\nsamples = 17\nvalue = [11, 6]"] ;
# 6736 -> 6737 ;
# 6738 [label="gini = 0.0\nsamples = 2\nvalue = [0, 2]"] ;
# 6737 -> 6738 ;
# 6739 [label="EXTWLINS <= 2.5\ngini = 0.391\nsamples = 15\nvalue = [11, 4]"] ;
# 6737 -> 6739 ;
# 6740 [label="gini = 0.0\nsamples = 5\nvalue = [5, 0]"] ;
# 6739 -> 6740 ;
# 6741 [label="DWLTYPE <= 3.5\ngini = 0.48\nsamples = 10\nvalue = [6, 4]"] ;
# 6739 -> 6741 ;
# 6742 [label="EDUC <= 51.0\ngini = 0.278\nsamples = 6\nvalue = [5, 1]"] ;
# 6741 -> 6742 ;
# 6743 [label="gini = 0.0\nsamples = 5\nvalue = [5, 0]"] ;
# 6742 -> 6743 ;
# 6744 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"] ;
# 6742 -> 6744 ;
# 6745 [label="NGUTIL <= 2.0\ngini = 0.375\nsamples = 4\nvalue = [1, 3]"] ;
# 6741 -> 6745 ;
# 6746 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"] ;
# 6745 -> 6746 ;
# 6747 [label="gini = 0.0\nsamples = 3\nvalue = [0, 3]"] ;
# 6745 -> 6747 ;
# 6748 [label="CZT24 <= 15.5\ngini = 0.117\nsamples = 16\nvalue = [15, 1]"] ;
# 6736 -> 6748 ;
# 6749 [label="gini = 0.0\nsamples = 13\nvalue = [13, 0]"] ;
# 6748 -> 6749 ;
# 6750 [label="ACEILINS <= 49.0\ngini = 0.444\nsamples = 3\nvalue = [2, 1]"] ;
# 6748 -> 6750 ;
# 6751 [label="rescnt <= 1.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]"] ;
# 6750 -> 6751 ;
# 6752 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"] ;
# 6751 -> 6752 ;
# 6753 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"] ;
# 6751 -> 6753 ;
# 6754 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"] ;
# 6750 -> 6754 ;
# 6755 [label="ETHNIC <= 2.5\ngini = 0.456\nsamples = 57\nvalue = [37, 20]"] ;
# 6727 -> 6755 ;
# 6756 [label="DWLTYPE <= 3.5\ngini = 0.492\nsamples = 39\nvalue = [22, 17]"] ;
# 6755 -> 6756 ;
# 6757 [label="HOHBLK1 <= 0.5\ngini = 0.413\nsamples = 24\nvalue = [17, 7]"] ;
# 6756 -> 6757 ;
# 6758 [label="rescnt <= 7.0\ngini = 0.465\nsamples = 19\nvalue = [12, 7]"] ;
# 6757 -> 6758 ;
# 6759 [label="rescnt <= 4.5\ngini = 0.415\nsamples = 17\nvalue = [12, 5]"] ;
# 6758 -> 6759 ;
# 6760 [label="cecfast <= 2.5\ngini = 0.496\nsamples = 11\nvalue = [6, 5]"] ;
# 6759 -> 6760 ;
# 6761 [label="gini = 0.0\nsamples = 2\nvalue = [0, 2]"] ;
# 6760 -> 6761 ;
# 6762 [label="EXTWLINS <= 2.5\ngini = 0.444\nsamples = 9\nvalue = [6, 3]"] ;
# 6760 -> 6762 ;
# 6763 [label="gini = 0.0\nsamples = 4\nvalue = [4, 0]"] ;
# 6762 -> 6763 ;
# 6764 [label="INCOME <= 4.0\ngini = 0.48\nsamples = 5\nvalue = [2, 3]"] ;
# 6762 -> 6764 ;
# 6765 [label="gini = 0.0\nsamples = 2\nvalue = [0, 2]"] ;
# 6764 -> 6765 ;
# 6766 [label="EDUC <= 4.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]"] ;
# 6764 -> 6766 ;
# 6767 [label="gini = 0.0\nsamples = 2\nvalue = [2, 0]"] ;
# 6766 -> 6767 ;
# 6768 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"] ;
# 6766 -> 6768 ;
# 6769 [label="gini = 0.0\nsamples = 6\nvalue = [6, 0]"] ;
# 6759 -> 6769 ;
# 6770 [label="gini = 0.0\nsamples = 2\nvalue = [0, 2]"] ;
# 6758 -> 6770 ;
# 6771 [label="gini = 0.0\nsamples = 5\nvalue = [5, 0]"] ;
# 6757 -> 6771 ;
# 6772 [label="avginc <= 99268.5\ngini = 0.444\nsamples = 15\nvalue = [5, 10]"] ;
# 6756 -> 6772 ;
# 6773 [label="CZT24 <= 12.5\ngini = 0.355\nsamples = 13\nvalue = [3, 10]"] ;
# 6772 -> 6773 ;
# 6774 [label="gini = 0.0\nsamples = 5\nvalue = [0, 5]"] ;
# 6773 -> 6774 ;
# 6775 [label="rescnt <= 4.5\ngini = 0.469\nsamples = 8\nvalue = [3, 5]"] ;
# 6773 -> 6775 ;
# 6776 [label="EDUC <= 3.5\ngini = 0.278\nsamples = 6\nvalue = [1, 5]"] ;
# 6775 -> 6776 ;
# 6777 [label="gini = 0.0\nsamples = 3\nvalue = [0, 3]"] ;
# 6776 -> 6777 ;
# 6778 [label="INCOME <= 5.0\ngini = 0.444\nsamples = 3\nvalue = [1, 2]"] ;
# 6776 -> 6778 ;
# 6779 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"] ;
# 6778 -> 6779 ;
# 6780 [label="gini = 0.0\nsamples = 2\nvalue = [0, 2]"] ;
# 6778 -> 6780 ;
# 6781 [label="gini = 0.0\nsamples = 2\nvalue = [2, 0]"] ;
# 6775 -> 6781 ;
# 6782 [label="gini = 0.0\nsamples = 2\nvalue = [2, 0]"] ;
# 6772 -> 6782 ;
# 6783 [label="CZT24 <= 11.5\ngini = 0.278\nsamples = 18\nvalue = [15, 3]"] ;
# 6755 -> 6783 ;
# 6784 [label="INCOME <= 2.5\ngini = 0.469\nsamples = 8\nvalue = [5, 3]"] ;
# 6783 -> 6784 ;
# 6785 [label="EDUC <= 4.0\ngini = 0.375\nsamples = 4\nvalue = [1, 3]"] ;
# 6784 -> 6785 ;
# 6786 [label="gini = 0.0\nsamples = 3\nvalue = [0, 3]"] ;
# 6785 -> 6786 ;
# 6787 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"] ;
# 6785 -> 6787 ;
# 6788 [label="gini = 0.0\nsamples = 4\nvalue = [4, 0]"] ;
# 6784 -> 6788 ;
# 6789 [label="gini = 0.0\nsamples = 10\nvalue = [10, 0]"] ;
# 6783 -> 6789 ;
# 6790 [label="cecfast <= 2.5\ngini = 0.423\nsamples = 122\nvalue = [85, 37]"] ;
# 6664 -> 6790 ;
# 6791 [label="rescnt <= 1.5\ngini = 0.444\nsamples = 9\nvalue = [3, 6]"] ;
# 6790 -> 6791 ;
# 6792 [label="EDUC <= 2.5\ngini = 0.375\nsamples = 4\nvalue = [3, 1]"] ;
# 6791 -> 6792 ;
# 6793 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"] ;
# 6792 -> 6793 ;
# 6794 [label="gini = 0.0\nsamples = 3\nvalue = [3, 0]"] ;
# 6792 -> 6794 ;
# 6795 [label="gini = 0.0\nsamples = 5\nvalue = [0, 5]"] ;
# 6791 -> 6795 ;
# 6796 [label="INCOME <= 4.5\ngini = 0.398\nsamples = 113\nvalue = [82, 31]"] ;
# 6790 -> 6796 ;
# 6797 [label="ETHNIC <= 1.5\ngini = 0.469\nsamples = 56\nvalue = [35, 21]"] ;
# 6796 -> 6797 ;
# 6798 [label="EXTWLINS <= 2.5\ngini = 0.43\nsamples = 48\nvalue = [33, 15]"] ;
# 6797 -> 6798 ;
# 6799 [label="avginc <= 18750.0\ngini = 0.298\nsamples = 22\nvalue = [18, 4]"] ;
# 6798 -> 6799 ;
# 6800 [label="gini = 0.0\nsamples = 13\nvalue = [13, 0]"] ;
# 6799 -> 6800 ;
# 6801 [label="OWNRENT <= 1.5\ngini = 0.494\nsamples = 9\nvalue = [5, 4]"] ;
# 6799 -> 6801 ;
# 6802 [label="CZT24 <= 15.0\ngini = 0.32\nsamples = 5\nvalue = [4, 1]"] ;
# 6801 -> 6802 ;
# 6803 [label="gini = 0.0\nsamples = 4\nvalue = [4, 0]"] ;
# 6802 -> 6803 ;
# 6804 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"] ;
# 6802 -> 6804 ;
# 6805 [label="SQFT <= 3.5\ngini = 0.375\nsamples = 4\nvalue = [1, 3]"] ;
# 6801 -> 6805 ;
# 6806 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"] ;
# 6805 -> 6806 ;
# 6807 [label="gini = 0.0\nsamples = 3\nvalue = [0, 3]"] ;
# 6805 -> 6807 ;
# 6808 [label="DWLTYPE <= 4.5\ngini = 0.488\nsamples = 26\nvalue = [15, 11]"] ;
# 6798 -> 6808 ;
# 6809 [label="cecfast <= 9.5\ngini = 0.444\nsamples = 21\nvalue = [14, 7]"] ;
# 6808 -> 6809 ;
# 6810 [label="gini = 0.0\nsamples = 6\nvalue = [6, 0]"] ;
# 6809 -> 6810 ;
# 6811 [label="rescnt <= 2.5\ngini = 0.498\nsamples = 15\nvalue = [8, 7]"] ;
# 6809 -> 6811 ;
# 6812 [label="ACEILINS <= 49.5\ngini = 0.32\nsamples = 5\nvalue = [1, 4]"] ;
# 6811 -> 6812 ;
# 6813 [label="gini = 0.0\nsamples = 3\nvalue = [0, 3]"] ;
# 6812 -> 6813 ;
# 6814 [label="EDUC <= 4.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]"] ;
# 6812 -> 6814 ;
# 6815 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"] ;
# 6814 -> 6815 ;
# 6816 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"] ;
# 6814 -> 6816 ;
# 6817 [label="SQFT <= 51.0\ngini = 0.42\nsamples = 10\nvalue = [7, 3]"] ;
# 6811 -> 6817 ;
# 6818 [label="gini = 0.0\nsamples = 4\nvalue = [4, 0]"] ;
# 6817 -> 6818 ;
# 6819 [label="HOHETH <= 3.5\ngini = 0.5\nsamples = 6\nvalue = [3, 3]"] ;
# 6817 -> 6819 ;
# 6820 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"] ;
# 6819 -> 6820 ;
# 6821 [label="NGUTIL <= 98.0\ngini = 0.48\nsamples = 5\nvalue = [2, 3]"] ;
# 6819 -> 6821 ;
# 6822 [label="gini = 0.0\nsamples = 2\nvalue = [0, 2]"] ;
# 6821 -> 6822 ;
# 6823 [label="HOHLAT1 <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]"] ;
# 6821 -> 6823 ;
# 6824 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"] ;
# 6823 -> 6824 ;
# 6825 [label="gini = 0.0\nsamples = 2\nvalue = [2, 0]"] ;
# 6823 -> 6825 ;
# 6826 [label="DWLTYPE <= 51.5\ngini = 0.32\nsamples = 5\nvalue = [1, 4]"] ;
# 6808 -> 6826 ;
# 6827 [label="gini = 0.0\nsamples = 4\nvalue = [0, 4]"] ;
# 6826 -> 6827 ;
# 6828 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"] ;
# 6826 -> 6828 ;
# 6829 [label="rescnt <= 7.0\ngini = 0.375\nsamples = 8\nvalue = [2, 6]"] ;
# 6797 -> 6829 ;
# 6830 [label="gini = 0.0\nsamples = 6\nvalue = [0, 6]"] ;
# 6829 -> 6830 ;
# 6831 [label="gini = 0.0\nsamples = 2\nvalue = [2, 0]"] ;
# 6829 -> 6831 ;
# 6832 [label="EDUC <= 1.5\ngini = 0.289\nsamples = 57\nvalue = [47, 10]"] ;
# 6796 -> 6832 ;
# 6833 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"] ;
# 6832 -> 6833 ;
# 6834 [label="cecfast <= 9.5\ngini = 0.27\nsamples = 56\nvalue = [47, 9]"] ;
# 6832 -> 6834 ;
# 6835 [label="avginc <= 57337.5\ngini = 0.408\nsamples = 21\nvalue = [15, 6]"] ;
# 6834 -> 6835 ;
# 6836 [label="rescnt <= 3.0\ngini = 0.142\nsamples = 13\nvalue = [12, 1]"] ;
# 6835 -> 6836 ;
# 6837 [label="gini = 0.0\nsamples = 9\nvalue = [9, 0]"] ;
# 6836 -> 6837 ;
# 6838 [label="INCOME <= 5.5\ngini = 0.375\nsamples = 4\nvalue = [3, 1]"] ;
# 6836 -> 6838 ;
# 6839 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"] ;
# 6838 -> 6839 ;
# 6840 [label="gini = 0.0\nsamples = 3\nvalue = [3, 0]"] ;
# 6838 -> 6840 ;
# 6841 [label="SQFT <= 7.5\ngini = 0.469\nsamples = 8\nvalue = [3, 5]"] ;
# 6835 -> 6841 ;
# 6842 [label="gini = 0.0\nsamples = 4\nvalue = [0, 4]"] ;
# 6841 -> 6842 ;
# 6843 [label="cecfast <= 8.0\ngini = 0.375\nsamples = 4\nvalue = [3, 1]"] ;
# 6841 -> 6843 ;
# 6844 [label="gini = 0.0\nsamples = 3\nvalue = [3, 0]"] ;
# 6843 -> 6844 ;
# 6845 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"] ;
# 6843 -> 6845 ;
# 6846 [label="SEASOCC <= 2.5\ngini = 0.157\nsamples = 35\nvalue = [32, 3]"] ;
# 6834 -> 6846 ;
# 6847 [label="EXTWLINS <= 50.0\ngini = 0.111\nsamples = 34\nvalue = [32, 2]"] ;
# 6846 -> 6847 ;
# 6848 [label="gini = 0.0\nsamples = 20\nvalue = [20, 0]"] ;
# 6847 -> 6848 ;
# 6849 [label="INCOME <= 10.5\ngini = 0.245\nsamples = 14\nvalue = [12, 2]"] ;
# 6847 -> 6849 ;
# 6850 [label="EDUC <= 4.5\ngini = 0.444\nsamples = 6\nvalue = [4, 2]"] ;
# 6849 -> 6850 ;
# 6851 [label="gini = 0.0\nsamples = 4\nvalue = [4, 0]"] ;
# 6850 -> 6851 ;
# 6852 [label="gini = 0.0\nsamples = 2\nvalue = [0, 2]"] ;
# 6850 -> 6852 ;
# 6853 [label="gini = 0.0\nsamples = 8\nvalue = [8, 0]"] ;
# 6849 -> 6853 ;
# 6854 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"] ;
# 6846 -> 6854 ;
# }

# %%
#Feature Importance Table for First Tree
importance = pd.DataFrame({'Feature': X.columns, 'Importance': first_tree.feature_importances_}).sort_values(by = 'Importance',ascending = False)
importance.merge(coldict_clean,how = 'inner', on = 'Feature')
# Out:
#      Feature  Importance                              Definition
# 0      CZT24    0.252498                  title 24 climate zones
# 1    BUILTYR    0.129884                    year residence built
# 2       SQFT    0.088366                  square footage of home
# 3     avginc    0.073038               average continuous income
# 4     rescnt    0.070480                     total num residents
# 5       EDUC    0.049189          Education of head of household
# 6     INCOME    0.048354                  household total income
# 7    DWLTYPE    0.045075                         type of housing
# 8   EXTWLINS    0.043383      exterior (outside) walls insulated
# 9    cecfast    0.043110             Forecast climate zone (CEC)
# 10    NGUTIL    0.037069                                utility
# 11  ACEILINS    0.023720                 attic/ceiling insulated
# 12   OWNRENT    0.021638                whether they own or rent
# 13    HOHETH    0.016624             Head of household ethnicity
# 14   HOHWHT1    0.014210                               Caucasian
# 15    ETHNIC    0.012477                        Primary language
# 16   HOHLAT1    0.007302                         Hispanic/Latino
# 17   HOHASN1    0.006917                  Asian/Pacific Islander
# 18   HOHBLK1    0.006713                        African American
# 19   SEASOCC    0.003611      permanent or partial year resident
# 20   HOHOTH1    0.003598                                   Other
# 21   HOHIND1    0.002744  Head of household 1 is American Indian

# %%
from sklearn.model_selection import RandomizedSearchCV
from scipy.stats import randint

param_dist = {'max_leaf_nodes': randint(3, 100),
              'max_features': randint(2, 22),
              'max_depth': randint(1, 10)}

rnd_search = RandomizedSearchCV(first_tree, param_distributions=param_dist, 
                                cv=10, n_iter=200, random_state = 2)
rnd_search.fit(X_train, y_train)

print(rnd_search.best_score_) 
print(rnd_search.best_params_)
# Out:
# 0.7594230507552048
# {'max_depth': 9, 'max_features': 17, 'max_leaf_nodes': 58}

# %%
#New Decision Tree with tuned parameters from cross validation
opt_tree = DecisionTreeClassifier(max_depth= 9, max_features= 17, max_leaf_nodes= 58, random_state = 2)
opt_tree.fit(X_train, y_train)

print("Number of features: {}".format(opt_tree.tree_.n_features))
print("Number of nodes (internal and terminal): {}".format(opt_tree.tree_.node_count), "\n")

train_score = opt_tree.score(X_train, y_train)
val_score = opt_tree.score(X_val, y_val)

print('Train Score: ', train_score)
print('Validation Score: ', val_score)
# Out:
# Number of features: 22
# Number of nodes (internal and terminal): 115
#
# Train Score:  0.7705129949653015
# Validation Score:  0.7546938775510204

# %%
#View tree
import graphviz
print(tree.export_graphviz(opt_tree, feature_names=X.columns))
# Out:
# digraph Tree {
# node [shape=box] ;
# 0 [label="CZT24 <= 7.5\ngini = 0.486\nsamples = 14698\nvalue = [8565, 6133]"] ;
# 1 [label="CZT24 <= 3.5\ngini = 0.437\nsamples = 5691\nvalue = [1835, 3856]"] ;
# 0 -> 1 [labeldistance=2.5, labelangle=45, headlabel="True"] ;
# 5 [label="CZT24 <= 2.5\ngini = 0.311\nsamples = 1824\nvalue = [351, 1473]"] ;
# 1 -> 5 ;
# 19 [label="CZT24 <= 1.5\ngini = 0.459\nsamples = 497\nvalue = [177, 320]"] ;
# 5 -> 19 ;
# 43 [label="gini = 0.167\nsamples = 76\nvalue = [7, 69]"] ;
# 19 -> 43 ;
# 44 [label="BUILTYR <= 4.5\ngini = 0.481\nsamples = 421\nvalue = [170, 251]"] ;
# 19 -> 44 ;
# 55 [label="gini = 0.383\nsamples = 159\nvalue = [41, 118]"] ;
# 44 -> 55 ;
# 56 [label="cecfast <= 4.5\ngini = 0.5\nsamples = 262\nvalue = [129, 133]"] ;
# 44 -> 56 ;
# 79 [label="gini = 0.498\nsamples = 233\nvalue = [124, 109]"] ;
# 56 -> 79 ;
# 80 [label="gini = 0.285\nsamples = 29\nvalue = [5, 24]"] ;
# 56 -> 80 ;
# 20 [label="gini = 0.228\nsamples = 1327\nvalue = [174, 1153]"] ;
# 5 -> 20 ;
# 6 [label="BUILTYR <= 7.5\ngini = 0.473\nsamples = 3867\nvalue = [1484, 2383]"] ;
# 1 -> 6 ;
# 7 [label="BUILTYR <= 3.5\ngini = 0.422\nsamples = 2611\nvalue = [789, 1822]"] ;
# 6 -> 7 ;
# 29 [label="avginc <= 145932.5\ngini = 0.351\nsamples = 991\nvalue = [225, 766]"] ;
# 7 -> 29 ;
# 47 [label="SQFT <= 4.5\ngini = 0.317\nsamples = 860\nvalue = [170, 690]"] ;
# 29 -> 47 ;
# 75 [label="gini = 0.17\nsamples = 235\nvalue = [22, 213]"] ;
# 47 -> 75 ;
# 76 [label="gini = 0.361\nsamples = 625\nvalue = [148, 477]"] ;
# 47 -> 76 ;
# 48 [label="gini = 0.487\nsamples = 131\nvalue = [55, 76]"] ;
# 29 -> 48 ;
# 30 [label="CZT24 <= 4.5\ngini = 0.454\nsamples = 1620\nvalue = [564, 1056]"] ;
# 7 -> 30 ;
# 49 [label="gini = 0.5\nsamples = 244\nvalue = [119, 125]"] ;
# 30 -> 49 ;
# 50 [label="CZT24 <= 5.5\ngini = 0.438\nsamples = 1376\nvalue = [445, 931]"] ;
# 30 -> 50 ;
# 51 [label="gini = 0.12\nsamples = 94\nvalue = [6, 88]"] ;
# 50 -> 51 ;
# 52 [label="NGUTIL <= 98.0\ngini = 0.45\nsamples = 1282\nvalue = [439, 843]"] ;
# 50 -> 52 ;
# 61 [label="SQFT <= 4.5\ngini = 0.427\nsamples = 969\nvalue = [300, 669]"] ;
# 52 -> 61 ;
# 63 [label="gini = 0.279\nsamples = 185\nvalue = [31, 154]"] ;
# 61 -> 63 ;
# 64 [label="cecfast <= 8.5\ngini = 0.451\nsamples = 784\nvalue = [269, 515]"] ;
# 61 -> 64 ;
# 83 [label="gini = 0.385\nsamples = 296\nvalue = [77, 219]"] ;
# 64 -> 83 ;
# 84 [label="gini = 0.477\nsamples = 488\nvalue = [192, 296]"] ;
# 64 -> 84 ;
# 62 [label="gini = 0.494\nsamples = 313\nvalue = [139, 174]"] ;
# 52 -> 62 ;
# 8 [label="BUILTYR <= 54.5\ngini = 0.494\nsamples = 1256\nvalue = [695, 561]"] ;
# 6 -> 8 ;
# 23 [label="BUILTYR <= 8.5\ngini = 0.475\nsamples = 981\nvalue = [601, 380]"] ;
# 8 -> 23 ;
# 53 [label="SQFT <= 7.5\ngini = 0.497\nsamples = 478\nvalue = [256, 222]"] ;
# 23 -> 53 ;
# 95 [label="gini = 0.499\nsamples = 318\nvalue = [153, 165]"] ;
# 53 -> 95 ;
# 96 [label="gini = 0.459\nsamples = 160\nvalue = [103, 57]"] ;
# 53 -> 96 ;
# 54 [label="INCOME <= 8.5\ngini = 0.431\nsamples = 503\nvalue = [345, 158]"] ;
# 23 -> 54 ;
# 71 [label="gini = 0.493\nsamples = 154\nvalue = [86, 68]"] ;
# 54 -> 71 ;
# 72 [label="gini = 0.383\nsamples = 349\nvalue = [259, 90]"] ;
# 54 -> 72 ;
# 24 [label="ACEILINS <= 1.5\ngini = 0.45\nsamples = 275\nvalue = [94, 181]"] ;
# 8 -> 24 ;
# 57 [label="avginc <= 75780.0\ngini = 0.497\nsamples = 93\nvalue = [50, 43]"] ;
# 24 -> 57 ;
# 85 [label="gini = 0.47\nsamples = 53\nvalue = [20, 33]"] ;
# 57 -> 85 ;
# 86 [label="gini = 0.375\nsamples = 40\nvalue = [30, 10]"] ;
# 57 -> 86 ;
# 58 [label="gini = 0.367\nsamples = 182\nvalue = [44, 138]"] ;
# 24 -> 58 ;
# 2 [label="BUILTYR <= 4.5\ngini = 0.378\nsamples = 9007\nvalue = [6730, 2277]"] ;
# 0 -> 2 [labeldistance=2.5, labelangle=-45, headlabel="False"] ;
# 3 [label="SQFT <= 4.5\ngini = 0.488\nsamples = 3182\nvalue = [1837, 1345]"] ;
# 2 -> 3 ;
# 9 [label="CZT24 <= 9.5\ngini = 0.463\nsamples = 717\nvalue = [261, 456]"] ;
# 3 -> 9 ;
# 33 [label="OWNRENT <= 1.5\ngini = 0.396\nsamples = 382\nvalue = [104, 278]"] ;
# 9 -> 33 ;
# 105 [label="NGUTIL <= 52.0\ngini = 0.475\nsamples = 126\nvalue = [49, 77]"] ;
# 33 -> 105 ;
# 107 [label="gini = 0.448\nsamples = 112\nvalue = [38, 74]"] ;
# 105 -> 107 ;
# 108 [label="gini = 0.337\nsamples = 14\nvalue = [11, 3]"] ;
# 105 -> 108 ;
# 106 [label="gini = 0.337\nsamples = 256\nvalue = [55, 201]"] ;
# 33 -> 106 ;
# 34 [label="DWLTYPE <= 1.5\ngini = 0.498\nsamples = 335\nvalue = [157, 178]"] ;
# 9 -> 34 ;
# 35 [label="gini = 0.425\nsamples = 147\nvalue = [45, 102]"] ;
# 34 -> 35 ;
# 36 [label="gini = 0.482\nsamples = 188\nvalue = [112, 76]"] ;
# 34 -> 36 ;
# 10 [label="CZT24 <= 8.5\ngini = 0.461\nsamples = 2465\nvalue = [1576, 889]"] ;
# 3 -> 10 ;
# 17 [label="avginc <= 58237.5\ngini = 0.497\nsamples = 495\nvalue = [229, 266]"] ;
# 10 -> 17 ;
# 59 [label="HOHLAT1 <= 0.5\ngini = 0.465\nsamples = 267\nvalue = [98, 169]"] ;
# 17 -> 59 ;
# 91 [label="gini = 0.493\nsamples = 180\nvalue = [79, 101]"] ;
# 59 -> 91 ;
# 92 [label="gini = 0.341\nsamples = 87\nvalue = [19, 68]"] ;
# 59 -> 92 ;
# 60 [label="OWNRENT <= 1.5\ngini = 0.489\nsamples = 228\nvalue = [131, 97]"] ;
# 17 -> 60 ;
# 99 [label="SQFT <= 5.5\ngini = 0.482\nsamples = 220\nvalue = [131, 89]"] ;
# 60 -> 99 ;
# 101 [label="gini = 0.444\nsamples = 33\nvalue = [11, 22]"] ;
# 99 -> 101 ;
# 102 [label="gini = 0.46\nsamples = 187\nvalue = [120, 67]"] ;
# 99 -> 102 ;
# 100 [label="gini = 0.0\nsamples = 8\nvalue = [0, 8]"] ;
# 60 -> 100 ;
# 18 [label="avginc <= 49381.5\ngini = 0.432\nsamples = 1970\nvalue = [1347, 623]"] ;
# 10 -> 18 ;
# 25 [label="EXTWLINS <= 1.5\ngini = 0.485\nsamples = 902\nvalue = [530, 372]"] ;
# 18 -> 25 ;
# 67 [label="gini = 0.433\nsamples = 287\nvalue = [196, 91]"] ;
# 25 -> 67 ;
# 68 [label="SQFT <= 9.5\ngini = 0.496\nsamples = 615\nvalue = [334, 281]"] ;
# 25 -> 68 ;
# 109 [label="SQFT <= 5.5\ngini = 0.489\nsamples = 487\nvalue = [280, 207]"] ;
# 68 -> 109 ;
# 111 [label="gini = 0.499\nsamples = 188\nvalue = [90, 98]"] ;
# 109 -> 111 ;
# 112 [label="BUILTYR <= 1.5\ngini = 0.463\nsamples = 299\nvalue = [190, 109]"] ;
# 109 -> 112 ;
# 113 [label="gini = 0.478\nsamples = 38\nvalue = [15, 23]"] ;
# 112 -> 113 ;
# 114 [label="gini = 0.442\nsamples = 261\nvalue = [175, 86]"] ;
# 112 -> 114 ;
# 110 [label="gini = 0.488\nsamples = 128\nvalue = [54, 74]"] ;
# 68 -> 110 ;
# 26 [label="BUILTYR <= 1.5\ngini = 0.36\nsamples = 1068\nvalue = [817, 251]"] ;
# 18 -> 26 ;
# 27 [label="OWNRENT <= 1.5\ngini = 0.495\nsamples = 178\nvalue = [98, 80]"] ;
# 26 -> 27 ;
# 93 [label="gini = 0.484\nsamples = 163\nvalue = [96, 67]"] ;
# 27 -> 93 ;
# 94 [label="gini = 0.231\nsamples = 15\nvalue = [2, 13]"] ;
# 27 -> 94 ;
# 28 [label="OWNRENT <= 1.5\ngini = 0.31\nsamples = 890\nvalue = [719, 171]"] ;
# 26 -> 28 ;
# 41 [label="CZT24 <= 15.5\ngini = 0.278\nsamples = 816\nvalue = [680, 136]"] ;
# 28 -> 41 ;
# 45 [label="gini = 0.247\nsamples = 762\nvalue = [652, 110]"] ;
# 41 -> 45 ;
# 46 [label="gini = 0.499\nsamples = 54\nvalue = [28, 26]"] ;
# 41 -> 46 ;
# 42 [label="gini = 0.499\nsamples = 74\nvalue = [39, 35]"] ;
# 28 -> 42 ;
# 4 [label="BUILTYR <= 54.5\ngini = 0.269\nsamples = 5825\nvalue = [4893, 932]"] ;
# 2 -> 4 ;
# 11 [label="CZT24 <= 15.5\ngini = 0.223\nsamples = 5082\nvalue = [4433, 649]"] ;
# 4 -> 11 ;
# 13 [label="SQFT <= 4.5\ngini = 0.191\nsamples = 4699\nvalue = [4198, 501]"] ;
# 11 -> 13 ;
# 21 [label="BUILTYR <= 7.5\ngini = 0.373\nsamples = 742\nvalue = [558, 184]"] ;
# 13 -> 21 ;
# 31 [label="CZT24 <= 14.5\ngini = 0.453\nsamples = 381\nvalue = [249, 132]"] ;
# 21 -> 31 ;
# 73 [label="SQFT <= 3.5\ngini = 0.47\nsamples = 344\nvalue = [214, 130]"] ;
# 31 -> 73 ;
# 81 [label="gini = 0.5\nsamples = 154\nvalue = [79, 75]"] ;
# 73 -> 81 ;
# 82 [label="gini = 0.411\nsamples = 190\nvalue = [135, 55]"] ;
# 73 -> 82 ;
# 74 [label="gini = 0.102\nsamples = 37\nvalue = [35, 2]"] ;
# 31 -> 74 ;
# 32 [label="gini = 0.247\nsamples = 361\nvalue = [309, 52]"] ;
# 21 -> 32 ;
# 22 [label="BUILTYR <= 7.5\ngini = 0.147\nsamples = 3957\nvalue = [3640, 317]"] ;
# 13 -> 22 ;
# 37 [label="cecfast <= 12.5\ngini = 0.229\nsamples = 1534\nvalue = [1332, 202]"] ;
# 22 -> 37 ;
# 65 [label="OWNRENT <= 1.5\ngini = 0.197\nsamples = 1316\nvalue = [1170, 146]"] ;
# 37 -> 65 ;
# 69 [label="gini = 0.159\nsamples = 1099\nvalue = [1003, 96]"] ;
# 65 -> 69 ;
# 70 [label="CZT24 <= 8.5\ngini = 0.355\nsamples = 217\nvalue = [167, 50]"] ;
# 65 -> 70 ;
# 77 [label="gini = 0.5\nsamples = 38\nvalue = [19, 19]"] ;
# 70 -> 77 ;
# 78 [label="gini = 0.286\nsamples = 179\nvalue = [148, 31]"] ;
# 70 -> 78 ;
# 66 [label="gini = 0.382\nsamples = 218\nvalue = [162, 56]"] ;
# 37 -> 66 ;
# 38 [label="SQFT <= 54.5\ngini = 0.09\nsamples = 2423\nvalue = [2308, 115]"] ;
# 22 -> 38 ;
# 103 [label="gini = 0.077\nsamples = 2310\nvalue = [2217, 93]"] ;
# 38 -> 103 ;
# 104 [label="gini = 0.314\nsamples = 113\nvalue = [91, 22]"] ;
# 38 -> 104 ;
# 14 [label="BUILTYR <= 5.5\ngini = 0.474\nsamples = 383\nvalue = [235, 148]"] ;
# 11 -> 14 ;
# 89 [label="gini = 0.491\nsamples = 74\nvalue = [32, 42]"] ;
# 14 -> 89 ;
# 90 [label="gini = 0.451\nsamples = 309\nvalue = [203, 106]"] ;
# 14 -> 90 ;
# 12 [label="CZT24 <= 9.5\ngini = 0.472\nsamples = 743\nvalue = [460, 283]"] ;
# 4 -> 12 ;
# 15 [label="EXTWLINS <= 2.5\ngini = 0.488\nsamples = 346\nvalue = [146, 200]"] ;
# 12 -> 15 ;
# 39 [label="INCOME <= 5.5\ngini = 0.479\nsamples = 126\nvalue = [76, 50]"] ;
# 15 -> 39 ;
# 87 [label="gini = 0.498\nsamples = 71\nvalue = [33, 38]"] ;
# 39 -> 87 ;
# 88 [label="gini = 0.341\nsamples = 55\nvalue = [43, 12]"] ;
# 39 -> 88 ;
# 40 [label="CZT24 <= 8.5\ngini = 0.434\nsamples = 220\nvalue = [70, 150]"] ;
# 15 -> 40 ;
# 97 [label="gini = 0.32\nsamples = 105\nvalue = [21, 84]"] ;
# 40 -> 97 ;
# 98 [label="gini = 0.489\nsamples = 115\nvalue = [49, 66]"] ;
# 40 -> 98 ;
# 16 [label="gini = 0.331\nsamples = 397\nvalue = [314, 83]"] ;
# 12 -> 16 ;
# }

# %%
importance = pd.DataFrame({'Feature': X.columns, 'Importance': opt_tree.feature_importances_}).sort_values(by = 'Importance',ascending = False)
importance.merge(coldict_clean,how = 'inner', on = 'Feature')
# Out:
#      Feature  Importance                              Definition
# 0      CZT24    0.624782                  title 24 climate zones
# 1    BUILTYR    0.234409                    year residence built
# 2       SQFT    0.065428                  square footage of home
# 3     avginc    0.022837               average continuous income
# 4    OWNRENT    0.014124                whether they own or rent
# 5    cecfast    0.008213             Forecast climate zone (CEC)
# 6   EXTWLINS    0.008010      exterior (outside) walls insulated
# 7    DWLTYPE    0.005364                         type of housing
# 8     NGUTIL    0.005239                                utility
# 9     INCOME    0.005209                  household total income
# 10  ACEILINS    0.004177                 attic/ceiling insulated
# 11   HOHLAT1    0.002210                         Hispanic/Latino
# 12      EDUC    0.000000          Education of head of household
# 13    ETHNIC    0.000000                        Primary language
# 14   HOHASN1    0.000000                  Asian/Pacific Islander
# 15   HOHBLK1    0.000000                        African American
# 16   HOHWHT1    0.000000                               Caucasian
# 17   HOHOTH1    0.000000                                   Other
# 18   SEASOCC    0.000000      permanent or partial year resident
# 19    rescnt    0.000000                     total num residents
# 20    HOHETH    0.000000             Head of household ethnicity
# 21   HOHIND1    0.000000  Head of household 1 is American Indian

# %%
# Bagging
from sklearn.ensemble import BaggingClassifier

bag_tree = BaggingClassifier()
bag_tree.fit(X_train, y_train)

bag_train_score = bag_tree.score(X_train, y_train)
bag_val_score = bag_tree.score(X_val, y_val)

print('Train Score: ', bag_train_score)
print('Validation Score: ', bag_val_score)
# Out:
# Train Score:  0.9839433936590012
# Validation Score:  0.7404081632653061

# %%
#Random Forest
from sklearn.ensemble import RandomForestClassifier

rf_tree = RandomForestClassifier()
rf_tree.fit(X_train, y_train)

rf_train_score = rf_tree.score(X_train, y_train)
rf_val_score = rf_tree.score(X_val, y_val)

print('Train Score: ', rf_train_score)
print('Validation Score: ', rf_val_score)

# %%
#tuning hyperparameters
param_dist = {#'learning_rate': randint(1, 5),
              'max_leaf_nodes': randint(3, 100),
              'max_features': randint(2, 22),
              'max_depth': randint(1, 10),
              'min_samples_leaf': randint(1, 30)}

rnd_rf_search = RandomizedSearchCV(rf_tree, param_distributions=param_dist, 
                                cv=10, n_iter=50, random_state=1)

rnd_rf_search.fit(X_train, y_train)

print(rnd_rf_search.best_params_)

# %%
#tuned random forest

rf_opt_tree = RandomForestClassifier(max_depth = 9, max_features = 11, max_leaf_nodes = 70, min_samples_leaf = 8)
rf_opt_tree.fit(X_train, y_train)

rf_train_score = rf_opt_tree.score(X_train, y_train)
rf_val_score = rf_opt_tree.score(X_val, y_val)

print('Train Score: ', rf_train_score)
print('Validation Score: ', rf_val_score)

y_pred = rf_opt_tree.predict(X_test)


from sklearn.metrics import classification_report, confusion_matrix  
print(confusion_matrix(y_test,y_pred))  
print(classification_report(y_test,y_pred))

# %%
#Random Forest Feature Importance
feature_importance = rf_opt_tree.feature_importances_
feature_importance = feature_importance / feature_importance.max()
rf_feat = pd.DataFrame({'Feature':X_train.columns, 'Importance':feature_importance}).sort_values(by = 'Importance',ascending = False)
rf_feat.head()

# %%
plt.figure(figsize=(7, 7))
plt.barh(width=rf_feat.Importance, y=rf_feat.Feature);
plt.title('Feature Importance (Random Forest)')
plt.show()

# %%
#SVM Model
from sklearn.svm import SVC

svc = SVC()

svc.fit(X_train, y_train.values.ravel())

y_pred = svc.predict(X_test)
print(confusion_matrix(y_test,y_pred))  
print(classification_report(y_test,y_pred))

# %%
#KNN Nearest Neighbors Classifier 
#Hypertuning KNN Nearest Neighbor Classifier 

from sklearn.model_selection import GridSearchCV
from sklearn.neighbors import KNeighborsClassifier 
#create new a knn model
knn = KNeighborsClassifier()
#create dict of all values to test for n_neighbors
param_grid = {'n_neighbors': np.arange(1, 20)}
#use gridsearch to test all values for n_neighbors
knn_gscv = GridSearchCV(knn, param_grid, cv=5)
#fit model to data
knn_gscv.fit(X_train, y_train)

# %%
#Use Optimal Number of Neighbors

knnclassifier = KNeighborsClassifier(n_neighbors=knn_gscv.best_params_['n_neighbors'])

# Train the model using the training sets
knnclassifier.fit(X_train,y_train)

#Predict Output
y_pred= knnclassifier.predict(X_test)

from sklearn.metrics import classification_report, confusion_matrix  
print(confusion_matrix(y_test,y_pred))  
print(classification_report(y_test,y_pred))

# %%
models = [first_tree, opt_tree, bag_tree, rf_tree, rf_opt_tree, svc, knnclassifier]
for i in models:
    print('Test Score: ', i.score(X_test, y_test))

# %% [markdown]
# ## Part 2: PM2.5 Prediction Analysis

# %%
# Head of Household Ethnicity 
#0 = Other, 1 = Native American, 2 = Asian/Pacific-Islander , 3 = African-American, 4 = Hispanic, 5 = Caucasian

survey_clean.loc[survey_clean['HOHOTH1']==1,'HOHOTH1']=0
survey_clean.loc[survey_clean['HOHASN1']==1,'HOHASN1']=2
survey_clean.loc[survey_clean['HOHBLK1']==1,'HOHBLK1']=3
survey_clean.loc[survey_clean['HOHLAT1']==1,'HOHLAT1']=4
survey_clean.loc[survey_clean['HOHWHT1']==1,'HOHWHT1']=5


ETH = survey_clean[['HOHOTH1','HOHIND1','HOHASN1','HOHBLK1','HOHLAT1','HOHWHT1']]
ETH['HOHETH1'] = ETH.sum(axis=1)
ETH.loc[ETH['HOHETH1']>5, 'HOHETH1']=0
#ETH['HOHETH1'].unique()
# Out:
# /srv/app/venv/lib/python3.6/site-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if sys.path[0] == '':
# /srv/app/venv/lib/python3.6/site-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   del sys.path[0]

# %%
#Education 
#In Cal Enviro Screen Data: Percent of population over 25 with less than a high school education (in Cal Enviro Screen)

#In RASS Data: 1 = Elementary, 2 = Some high school, 3=High school graduate, 4 = Some college/trade/vocational school, 5 = College graduate, 6 = Postgraduate degree, 97 = Nan  

# We are going to build a model that classifies based on just Education
# The X training data will consist of one feature, 1 = Education with less than a highschool degree, 2 = Education with more than a highschool degree (Assume those who filled out the survey are 25 or older)

data = survey_clean[['EDUC', 'PAYCOOL']]

data = data[data['EDUC'] != 97]

data['EDUC'] = np.where((data['EDUC'] == 1) | (data['EDUC'] == 2), 1, data['EDUC'])
data['EDUC'] = np.where((data['EDUC'] == 3) | (data['EDUC'] == 4)| (data['EDUC'] == 5)| (data['EDUC'] == 6), 2, data['EDUC'])

# %%
#Add Head of Household Ethnicity into Data 

data['HOHETH'] = ETH['HOHETH1']

#Split the data

# features are Education and Head of Household
features = data[['EDUC', 'HOHETH']]
target = data['PAYCOOL']
# split test set
X2, X2_test, y2, y2_test = train_test_split(features, target, random_state = 1, test_size = .2)

# split between train and validation sets
X2_train, X2_val, y2_train, y2_val = train_test_split(X2, y2, random_state = 1, test_size = 0.25)

# %%
#Visualize the data

#plt.figure(figsize = (10,7))

#colormap = np.array(['red', 'blue'])
#classes = pd.unique(target)


#plt.title('AC Adoption vs. Head of Household Ethnicity and Education')
#plt.xlabel('AC Adoption (1 = Yes, 3 = No)')
#plt.ylabel('Classification Values for HOHETH & EDUC')
#plt.legend()
#plt.show()

# %%
#Simple first decision tree
BuildDecisionTree(X2_train, X2_val, y2_train, y2_val)
# Out:
# Number of features: 2
# Number of nodes (internal and terminal): 23
#
# Train Score:  0.5855249167080173
# Validation Score:  0.5923878375504997
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#                        max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort=False,
#                        random_state=None, splitter='best')

# %% [markdown]
# ## Interpretation and Conclusions (20 points)
# In this section you must relate your modeling and forecasting results to your original research question.  You must
# 1. What do the answers mean? What advice would you give a decision maker on the basis of your results?  How might they allocate their resources differently with the results of your model?  Why should the reader care about your results?
# 2. Discuss caveats and / or reasons your results might be flawed.  No model is perfect, and understanding a model's imperfections is extremely important for the purpose of knowing how to interpret your results.  Often, we know the model output is wrong but we can assign a direction for its bias.  This helps to understand whether or not your answers are conservative.
#
# Shoot for 500-1000 words for this section.
